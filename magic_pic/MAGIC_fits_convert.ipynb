# %% [markdown]
# # Reprocessing data from MAGIC/PIC base

# %%
# We start with some code to access the table at http://vobs.magic.pic.es/fits/
def get_table_from_url(url):
    from bs4 import BeautifulSoup as BS
    import urllib2
    soup = BS(urllib2.urlopen(url).read())
    table = soup.find('table',{'class','mytable'})
    return table

url = 'http://vobs.magic.pic.es/fits/'
table_pic_html = get_table_from_url(url)
# Out:
# /home/chbrandt/.conda/envs/magic_test/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
from IPython.display import HTML
HTML(unicode(table_pic_html))
# Out:
# <table cellspacing="0" class="mytable" id="table_3">
# <tr>
# <th><strong>Source</strong></th>
# <th><strong>Article</strong></th>
# <th><strong>Year</strong></th>
# <th width="20%"><strong>Reference</strong></th>
# <th><strong>Download</strong></th>
# </tr>
# <!--when the paper is not published yet: <td ALIGN="center"><b><FONT COLOR="#808080">FITS</font></b></td>-->
# <!--98-->
# <tr>
# <td><strong> Mrk 421 </strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1412.3576T"><font color="#280099">  Unprecedented study of the broadband emission of Mrk 421 during flaring activity in March 2010 </font></a></td>
# <td align="center">2015</td>
# <td>(2014arXiv1412.3576T)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--97-->
# <tr>
# <td><strong> Crab Nebula </strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1406.6892M"><font color="#280099">  Measurement of the Crab nebula spectrum over three decades in energy with the MAGIC telescopes </font></a></td>
# <td align="center">2015</td>
# <td>(2014arXiv1406.6892M)</td>
# <td align="center"><a href="mfits/base/MAGIC_2015_CrabNebula.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--96-->
# <tr>
# <td><strong> PG 1553+113 </strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1408.1975M"><font color="#280099">  Probing the very-high-energy γ-ray spectral curvature in the blazar PG 1553+113 with the MAGIC telescopes </font></a></td>
# <td align="center">2015</td>
# <td>(2014arXiv1408.1975M)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--95-->
# <tr>
# <td><strong> 1ES 0806+524 </strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2015arXiv150406115M"><font color="#280099">  MAGIC detection of short-term variability of the high-peaked BL Lac object 1ES 0806+524 </font></a></td>
# <td align="center">2015</td>
# <td>(J. Aleksić et al., MNRAS 451, 5258-5269)</td>
# <td align="center"><a href="mfits/base/MAGIC_2015_1ES0806.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--94-->
# <tr>
# <td><strong> HESS J1857+026</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014A%26A...571A..96A"><font color="#280099">   MAGIC reveals a complex morphology within the unidentified gamma-ray source HESS J1857+026 </font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A; 571, A96)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--93-->
# <tr>
# <td><strong> J2001+439</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1409.3389M"><font color="#280099">   First broadband characterization and redshift determination of the VHE blazar MAGIC J2001+439 </font></a></td>
# <td align="center">2014</td>
# <td>(2014arXiv1409.3389M)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--92-->
# <tr>
# <td><strong> Mrk 501</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1410.6391M"><font color="#280099">   Multiwavelength Observations of Mrk 501 in 2008 </font></a></td>
# <td align="center">2014</td>
# <td>(2014arXiv1410.6391M)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--91-->
# <tr>
# <td><strong> 1ES 0033+595</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1410.7059A"><font color="#280099">   Discovery of very high energy gamma-ray emission from the blazar 1ES 0033+595 by the MAGIC telescopes</font></a></td>
# <td align="center">2014</td>
# <td>(2014arXiv1410.7059A)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--90-->
# <tr>
# <td><strong> IC 310</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014Sci...346.1080A"><font color="#280099">   Black Hole lightning due to particle acceleration at sub-horizon scales</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., Science 346, 1080-1084)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_Ic310.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--89-->
# <tr>
# <td><strong> PKS 1424+240</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1401.0464M"><font color="#280099">   MAGIC long-term study of the distant TeV blazar PKS 1424+240 in a multiwavelength context</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A; 567, A135)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_PKS1424+240.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--88-->
# <tr>
# <td><strong> 3C 58</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1405.6074M"><font color="#280099">   Discovery of TeV gamma-ray emission from the pulsar wind nebula 3C 58 by MAGIC</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A; 567, L8)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_3C58.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--87-->
# <tr>
# <td><strong> AE Aquarii</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1407.3707A"><font color="#280099">   MAGIC search for VHE gamma-ray emission from AE Aquarii in a multiwavelength context</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A; 568, A109)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_AEaqr.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--86-->
# <tr>
# <td><strong>  PKS 1510-089</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1401.5646M"><font color="#280099">   MAGIC gamma-ray and multi-frequency observations of flat spectrum radio quasar PKS 1510-089 in early 2012</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A; 569, A46)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--85-->
# <tr>
# <td><strong>  3C 279</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2013arXiv1311.2833A"><font color="#280099">   MAGIC observations &amp; multifrequency properties of the Flat Spectrum Radio Quasar 3C 279 in 2011</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A; 567, A41)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_3C279.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--84-->
# <tr>
# <td><strong>  4C +55.17</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014MNRAS.440..530A"><font color="#280099">   Search for very high energy gamma-rays from the z=0.896 Quasar 4C +55.17 with MAGIC Telescopes</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., MNRAS 440, 530)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_4C+5517.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--83-->
# <tr>
# <td><strong>   Crab Pulsar</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014A%26A...565L..12A"><font color="#280099">   Detection of bridge emission above 50 GeV from the Crab Pulsar with MAGIC Telescopes</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A; 565, L12)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_CrabPulsar.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--82-->
# <tr>
# <td><strong>   NGC 1275</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014A%26A...564A...5A"><font color="#280099">   Contemporaneous observations of the radio galaxy NGC 1275 from radio to very high energy gamma-rays</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A; 564, A5)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_NGC1275.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--81-->
# <tr>
# <td><strong>   1ES 1727+50</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014A%26A...563A..90A"><font color="#280099">   Discovery of very high energy gamma emission from the blazar 1ES 1727+502 with MAGIC Telescopes</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A; 563, A90)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--80-->
# <tr>
# <td><strong>   4C +21.35</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014ApJ...786..157A"><font color="#280099">   Multifre

# %%
# This table now is parsed to get the columns
def get_table_fields(table):

    def get_doi_url(url):
        # The url of the reference ("aurl").
        from bs4 import BeautifulSoup as BS
        import urllib2
        import re
        _ads = 'adsabs'
        _cds = 'cdsads'
        _axv = 'arxiv'
        if (_ads in url or _cds in url or _axv in url):
            soup = BS(urllib2.urlopen (url))
            trs = soup.findAll('tr')
            filter(lambda x: 'doi' in x.get_text().lower(), trs)
            tr = filter(lambda x: 'doi' in x.get_text().lower(), trs)[0]
            doi = tr.get_text()
            url = 'http://dx.doi.org/'
            url += re.sub('DOI:','',re.sub('\n','',doi))
        return url

    def process_row(row):
        cells = row.findAll('td')
        if len(cells)==5:
            # Object source name(s) (can be more then one comma separated)
            src = cells[0].find(text=True)
            src = src.strip()
            # Article reference (url), usually a ref to ads
            art = cells[1].find('a',href=True)
            aurl = art['href']
            durl = get_doi_url(aurl)
            # We skip year of publication (third column)
            # as well as bibcode reference (fourth column)
            #ref = cells[3].find(text=True).encode('utf8')
            # FITS file link for downloading it in the near future
            fits = cells[4]
            file = fits.find('a',href=True)
            try:
                file = file['href']
            except:
                file = None
            furl = url+file if file!=None else '_NULL_'
            return (src,durl,file)
        return None
    
    magic_table = {'SOURCE':[], 'DOI':[], 'FITS':[]}
    for row in table.findAll('tr'):
        vals = process_row(row)
        if vals is not None:
            src,durl,file = vals
            magic_table['SOURCE'].append(src)
            magic_table['DOI'].append(durl)
            magic_table['FITS'].append(file)
    return magic_table
    
table_pic_dict = get_table_fields(table_pic_html)

del table_pic_html
#tf = table_filtered
#for i in range(len(tf['source'])):
#    print("%s : %s : %s"%(tf['source'][i],tf['doi'][i],tf['fits'][i]))

# %%
def print_describe(table,include='all'):
    print table.describe(include=include)
    print "\n-> Has Nil?"
    hows_nil = table.isnull().any()
    print hows_nil
    for c in hows_nil.index:
        if not hows_nil[c]: continue
        print "\n-> Indexes where column '{}' is null:".format(c)
        print table[table[c].isnull()].index.values

# %%
try:
    table_pic_dict = table_pic.copy()
    del table_pic
except:
    pass

import pandas as pd
table_pic = pd.DataFrame(table_pic_dict)

del table_pic_dict

print_describe(table_pic)
# Out:
#                                                    DOI  \
# count                                               99
# unique                                              99
# top     http://dx.doi.org/10.1088/0004-637X/705/2/1624
# freq                                                 1
#
#                                        FITS         SOURCE
# count                                    67             99
# unique                                   67             68
# top     mfits/base/MAGIC_2010_CygnusX3.fits  Markarian 421
# freq                                      1              6
#
# -> Has Nil?
# DOI       False
# FITS       True
# SOURCE    False
# dtype: bool
#
# -> Indexes where column 'FITS' is null:
# [ 0  2  4  5  6  7 12 17 18 28 29 33 34 35 36 37 41 42 43 49 50 53 57 67 73
#  83 84 88 90 93 96 98]

# %%
# Now we want to download the fits files
def download_fits(url,out):
    import wget
    filename = wget.download(url,out=out)
    return filename

def clean_dir(dir,ext="*"):
    import os
    from glob import glob
    if not os.path.exists(dir):
        os.mkdir(dir)
        return True
    if os.path.isdir(dir):
        files = glob(os.path.join(dir,ext))
        for f in files:
            os.remove(f)
        return True
    return False
    
fits_download_dir = 'FITS_pic/'
clean_dir(fits_download_dir)

#files_list = table_pic.FITS.dropna()
#furls = [ url+f for f,_ in files_list ]
furls = url + table_pic.FITS.dropna()
#del files_list

#try:
#    from IPython.parallel import Client
#    ipc = Client()
#    dview = ipc[:]
#    print "-> Parallel mode"
#    ret = dview.map_sync(download_fits, furls,[fits_dir]*len(furls))
#except:
#    print "-> Serial mode"
#    ret = map(download_fits, furls,[fits_dir]*len(furls))

#print '\nTotal: {} files downloaded\n'.format(len(ret))
#for i,f in enumerate(ret):
#    f,s = files_list[i]
#    print 'Source: {}\t,file: {}\t, to {}'.format(s,f,ret[i])

#for i in range(len(table_cols['source'])):
#    src = table_cols['source'][i]
#    file = table_cols['fits'][i]
#    if not file is None:
#        print("Downloading %s"%(file))
#        download_fits(url+file,fits_dir)
#    else:
#        print("File for source %s not available."%(src))

fits_download = furls.apply(lambda f: download_fits(f,fits_download_dir))
table_pic['FITS'] = fits_download

del fits_download,furls

print_describe(table_pic)
# Out:
#                                                    DOI  \
# count                                               99
# unique                                              99
# top     http://dx.doi.org/10.1088/0004-637X/705/2/1624
# freq                                                 1
#
#                                    FITS         SOURCE
# count                                67             99
# unique                               67             68
# top     FITS_pic//MAGIC_2009_OJ287.fits  Markarian 421
# freq                                  1              6
#
# -> Has Nil?
# DOI       False
# FITS       True
# SOURCE    False
# dtype: bool
#
# -> Indexes where column 'FITS' is null:
# [ 0  2  4  5  6  7 12 17 18 28 29 33 34 35 36 37 41 42 43 49 50 53 57 67 73
#  83 84 88 90 93 96 98]

# %%
# Now we can process the fits files themselves.
# He start noting that we want the SPECTRUM Data Unit(s)
#  available (or not) in the fits files; discard the other DU.
# Things we want to do:
# - get the OBJECT name
# - get the each object position
# - get the observation date
# - transform the data vectors (x) to frequency(Hz) and (y) to flux(erg/s/cm2)
# Then we should follow the following workflow:
# - open the fits file
# - find the necessary data unit (SPECTRUM)
# - open its header
#  - get some keywords from the header
# - open its data; data here are vectors
#  - it can be from 2 to 4 vectors
#   - energy
#   - flux
#   - Denergy
#   - Dflux
#  - convert the ?energy vectors to 'Hz' units
#  - convert the ?flux vectors to 'erg/s/cm2' units

# Here we just define the functions we'll need..

def read_file(filename):
    from astropy.io import fits
    try:
        hdulist = fits.open(filename)
    except:
        hdulist = None
    return hdulist
    
def select_dataUnits(hdulist,du_name='SPECTRUM'):
    dui = [ i for i,du in enumerate(hdulist) if du_name in du.name ]
    dus = [ hdulist[ii] for ii in dui ]
    _du = filter(lambda x:du_name in x.name, hdulist)
    assert dus == _du
    return (dus,dui)
    
def read_header(spec,table):
    assert isinstance(table,dict)
    def read_keyword(header,table,word):
        table[word] = header.get(word, None)
    header = spec.header
    read_keyword(header,table, 'EXTNAME')
    read_keyword(header,table, 'OBJECT')
    read_keyword(header,table, 'DATE-OBS')
    read_keyword(header,table, 'SRCPOS1')
    read_keyword(header,table, 'SRCPOS2')

def attempt_fix_objectname(table):
    assert table['OBJECT'] is None
    import re
    _fn = table['filename'][:-5]
    objname = re.sub('.*/MAGIC_20[0-9][0-9]_','',_fn)
    table['OBJECT'] = objname
    print '*** OBJECT name got from file name.'


def resolve_name(name):
    from astropy.coordinates import get_icrs_coordinates as get_coords
    try:
        icrs = get_coords(name)
        pos = (icrs.ra.value,icrs.dec.value)
    except:
        pos = None
    return pos

def read_data(spec,table):
    assert isinstance(table,dict)
    cols = zip(spec.columns.names,spec.columns.units)
    for n in ['energy','Denergy','flux','Dflux']:
        table[n+'_unit'] = None
        table[n] = None
    for n,u in cols:
        if (n == 'energy' or n == 'Denergy' or n == 'flux' or n == 'Dflux'):
            table[n+'_unit'] = u
            table[n] = spec.data[n]
        else:
            print "Different field:",n

def transf_data(table):
    from astropy import units
    Unit = units.Unit
    import numpy as np
    uEn = Unit('Hz')
    uFn = Unit('erg s-1 cm-2')
    uEc = Unit('TeV')
    conv = {Unit('ph TeV s-1 cm-2') : lambda x,y: (x/Unit('ph')).to(uFn),
            Unit('ph TeV-1 s-1 cm-2') : lambda x,y: ((y.to(uEc)**2)*(x/Unit('ph'))).to(uFn),
            Unit('ph s-1 cm-2') : lambda x,y: None}
    uE = Unit(table['energy_unit'])
    vE = np.array(table['energy'],np.float)
    vE = vE * uE
    vEn = vE.to(uEn, equivalencies=units.spectral())
    uF = Unit(table['flux_unit'])
    vF = np.array(table['flux'],np.float)
    vF = vF * uF
    vFn = conv[uF](vF,vE)
    if vFn is None:
        print "vFn is None!?!:",str(uF)
        return False
    table['energy_unit'] = uEn.to_string(units.format.CDS)
    table['energy'] = vEn.value
    table['flux_unit'] = uFn.to_string(units.format.CDS)
    table['flux'] = vFn.value
    if table['Denergy'] is not None:
        uDE = Unit(table['Denergy_unit'])
        vDE = np.array(table['Denergy'],np.float)
        vDE = vDE * uDE
        vDEn = vDE.to(uEn, equivalencies=units.spectral())
        table['Denergy_unit'] = uEn.to_string(units.format.CDS)
        table['Denergy'] = vDEn.value
    else:
        uDE = Unit('')
        vDEn = np.asarray([-999]*len(vE))
        table['Denergy_unit'] = uDE.to_string()
        table['Denergy'] = vDEn
    if table['Dflux'] is not None:
        uDF = Unit(table['Dflux_unit'])
        vDF = np.array(table['Dflux'],np.float)
        vDF = vDF * uDF
        vDFn = conv[uDF](vDF,vE) # Notice we use the energy bin/value of the measurement.
        table['Dflux_unit'] = uFn.to_string(units.format.CDS)
        table['Dflux'] = vDFn.value
    else:
        uDF = Unit('')
        vDFn = np.asarray([-999]*len(vE))
        table['Dflux_unit'] = uDF.to_string()
        table['Dflux'] = vDFn
    return True

def proc_fits_file(fn,source):
    out = []
    from collections import OrderedDict
    table = OrderedDict()
    table['filename'] = None
    table['EXTNAME'] = None
    table['OBJECT'] = None
    table['SRCPOS1'] = None
    table['SRCPOS2'] = None
    table['DATE-OBS'] = None
    table['energy'] = None
    table['energy_unit'] = None
    table['Denergy'] = None
    table['Denergy_unit'] = None
    table['flux'] = None
    table['flux_unit'] = None
    table['Dflux'] = None
    table['Dflux_unit'] = None
    
    table['filename'] = fn
    print "\nProcessing file:",fn,

    hdulist = read_file(fn)
    if hdulist is None:
        print " ..failed: to open." 
        return None
    
    spectra,specdui = select_dataUnits(hdulist)
    if not len(spectra):
        print " ..failed: no SPECTRUM" 
        return None
    print
    
    for i,spec in enumerate(spectra):
        read_header(spec,table)
        #table['EXTNAME'] += '+'+str(specdui[i])
        if table['OBJECT'] is None:
            attempt_fix_objectname(table)
        pos = resolve_name(table['OBJECT'])
        if pos is None:
            pos = resolve_name(source)
            if pos is None:
                pos = (None,None)
            else:
                table['OBJECT'] = source
                print '*** NOP, No good either! Using PIC source.'
        if table['SRCPOS1'] is None or table['SRCPOS2'] is None:
            table['SRCPOS1'],table['SRCPOS2'] = pos
        read_data(spec,table)
        ret = transf_data(table)
        if ret is not True:
            continue
        #filename = write_file(table)
        #print "-> output file",filename,"created."
        out.append(table.copy())
    return out

# %%
table_pic['PROC'] = table_pic.apply(lambda x: proc_fits_file(x.FITS,x.SOURCE), axis=1)
# Out:
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2015_CrabNebula.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2015_1ES0806.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2014_Ic310.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2014_PKS1424+240.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2014_3C58.fits
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2014_AEaqr.fits  ..failed: no SPECTRUM
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2014_3C279.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2014_4C+5517.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2014_CrabPulsar.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2014_NGC1275.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2014_IC310.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2014_Segue1.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2014_GRB090102.fits
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2013_1ES2344+514.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2013_J1644+57.fits
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2013_Magnetars.fits
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
#
# Processing file: FITS_pic//MAGIC_2012_1ES1215.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2012_M87.fits
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2012_PKS2155.fits
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2012_Perseus.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2012_W51.fits
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2012_B32247.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2011_CrabPulsar_mono.fits  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2011_ScorpiusX1.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2011_Segue1.fits  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2011_PKS1222.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2011_3C66A.fits  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2010_IC310.fits
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2010_MilagroSNR_G65.fits
#
# Processing file: FITS_pic//MAGIC_2010_CygnusX3.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2010_Mrk421_Mrk501.fits  ..failed: no SPECTRUM
#
# Processing file: FITS_pic//MAGIC_2011_Blazars.fits
# *** OBJECT name got from file name.
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
# vFn is None!?!: ph / (cm2 s)
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2010_Mrk421_mw2006.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2010_PG1553_mw2008.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2009_LSI61303_correlated.fits  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2009_Mrk501_mw2006.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2010_Perseus.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2009_S50716.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2009_OJ287.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2009_M13.fits
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2009_Mrk421_mw_outburst.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2009_3C454.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2009_3C66A.fits
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2009_Willman.fits  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2009_Mrk421_flare.fits  ..failed: no SPECTRUM
#
# Processing file: FITS_pic//MAGIC_2008_WRBinSys.fits
#
# Processing file: FITS_pic//MAGIC_2008_3C279.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2009_LSI61303.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2008_M87.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2008_LSI61303_mw.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2008_BLLac.fits  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2008_1ES1959_mw.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2008_Draco.fits  ..failed: no SPECTRUM
#
# Processing file: FITS_pic//MAGIC_2008_TeV2032.fits  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2008_Crab.fits  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2007_1ES1011.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2007_CassiopeiaA.fits
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2007_IC443.fits
# *** OBJECT name got from file name.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2007_BLLacertae.fits  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2007_CygnusX1.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: FITS_pic//MAGIC_2007_Mrk421.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2007_Arp220.fits  ..failed: to open.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2006_Mrk180.fits
# *** OBJECT name got from file name.
# *** OBJECT name got from file name.
#
# Processing file: FITS_pic//MAGIC_2006_LSI61303.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2006_HESS1834.fits  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2006_HESS1813.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: nan  ..failed: to open.
#
# Processing file: FITS_pic//MAGIC_2006_GC.fits
# *** OBJECT name got from file name.
# *** NOP, No good either! Using PIC source.
#
# Processing file: nan  ..failed: to open.

# %%
def fix_degeneracy(group):
    row = group.irow(0)
    columns = row.to_dict()
    ddf = {}
    dtabs = row['PROC']
    ddf['PROC'] = dtabs
    del columns['PROC']
    ddf['OBJECT'] = [ d['OBJECT'] for d in dtabs ]
    ddf['RA'] = [ d['SRCPOS1'] for d in dtabs ]
    ddf['DEC'] = [ d['SRCPOS2'] for d in dtabs ]
    for c in columns: ddf[c] = [row[c]]*len(dtabs)
    return pd.DataFrame(ddf)

table_proc = table_pic.dropna().groupby('DOI',group_keys=False).apply(fix_degeneracy).reset_index(drop=True)

#import os
#from glob import glob
#fits_list = glob(os.path.join(fits_download_dir,'*.fits'))
#out_list = []

#import random
#n = random.randint(0,len(fits_list))
#inps_list = fits_list

#for fn in inps_list:
#    tables = proc_fits_file(fn)
#    if tables is None:
#        print "Oops, something went wrong."
#        continue
#    for table in tables:
#        print("There we go.. %s processing succeed." % (fn))
#        for k,v in table.iteritems():
#            print"\t",k,v
#        out_list.append(table)
#
#print len(out_list)




#ret_par = ret_ser = None
#try:
#    print aaa
#    from IPython.parallel import Client
#    ipc = Client()
#    #lview = ipc.load_balanced_view()
#    lview = ipc[:]
#    lview.block = True
#    print "-> Parallel mode"
#    ret_par = lview.map_sync(proc_fits_file,fits_list)
#except:
#    print "-> Serial mode"
#    ret_ser = map(proc_fits_file,fits_list)
#
#print ret_par
#print ret_ser
# Out:
# /home/chbrandt/.conda/envs/magic_test/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: irow(i) is deprecated. Please use .iloc[i]
#   app.launch_new_instance()

# %%
def dict_to_table(dict_tab):
    from astropy.table import Table,Column
    from astropy.units import Unit
    tab = dict_tab
    h_keys = ['filename','EXTNAME','OBJECT','SRCPOS1','SRCPOS2','DATE-OBS']
    t_cols = ['energy','Denergy','flux','Dflux']
    cols = []
    t = Table()
    for cname in t_cols:
        cdata = tab[cname]
        cunit = Unit(tab[cname+'_unit'])
        c = Column(data=cdata,name=cname,unit=cunit)
        cols.append(c)
    for c in cols:
        t.add_column(c)
    for kword in h_keys:
        t.meta[kword.upper()] = tab[kword]
    return t


table_proc['SPECTRUM'] = table_proc.PROC.apply(dict_to_table)

def write_table(table,odir):
    import os,re
    filename = os.path.basename(table.meta['FILENAME'])
    extname = '_' + table.meta['EXTNAME'] + '.fits'
    filename = os.path.join(odir,re.sub('.fits',extname,filename))
    table.write(filename,format='fits')
    return filename

outdir = 'FITS_out/'
clean_dir(outdir)

table_proc['FITS'] = table_proc.SPECTRUM.apply(lambda d:write_table(d,outdir))
# Out:
# WARNING: UnitsWarning: The unit 'erg' has been deprecated in the FITS standard. Suggested: cm2 g s-2. [astropy.units.format.utils]
# WARNING:astropy:UnitsWarning: The unit 'erg' has been deprecated in the FITS standard. Suggested: cm2 g s-2.

# %%
pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',10)
pd.set_option('display.width',100)
#del table_proc['PROC']
#del table_proc['SPECTRUM']

#print table_proc.describe(include='all')
print table_proc
# Out:
#            DEC                                                DOI  \
# 0    22.014460      http://dx.doi.org/10.1016/j.jheap.2015.01.002
# 1    22.014460      http://dx.doi.org/10.1016/j.jheap.2015.01.002
# 2    18.811129      http://dx.doi.org/10.1051/0004-6361/200811326
# 3    18.811129      http://dx.doi.org/10.1051/0004-6361/200811326
# 4    18.811129      http://dx.doi.org/10.1051/0004-6361/200811326
# 5    11.190102      http://dx.doi.org/10.1051/0004-6361/200913607
# 6    38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 7    38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 8    38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 9    38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 10   38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 11   38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 12   38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 13   38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 14   38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 15   12.391123      http://dx.doi.org/10.1051/0004-6361/201117827
# 16    2.144386      http://dx.doi.org/10.1051/0004-6361/201117967
# 17    2.144386      http://dx.doi.org/10.1051/0004-6361/201117967
# 18   41.511695      http://dx.doi.org/10.1051/0004-6361/201118502
# 19   41.511695      http://dx.doi.org/10.1051/0004-6361/201118502
# 20   22.014500      http://dx.doi.org/10.1051/0004-6361/201218796
# 21  -30.225600      http://dx.doi.org/10.1051/0004-6361/201218796
# 22   14.509170      http://dx.doi.org/10.1051/0004-6361/201218846
# 23   30.116843      http://dx.doi.org/10.1051/0004-6361/201219133
# 24   30.116843      http://dx.doi.org/10.1051/0004-6361/201219133
# 25   61.750900      http://dx.doi.org/10.1051/0004-6361/201220275
# 26   58.879000      http://dx.doi.org/10.1051/0004-6361/201220275
# 27   51.704967      http://dx.doi.org/10.1051/0004-6361/201220714
#
52.316181             http://dx.doi.org/10.1093/mnras/stv895
# 123  20.108511           http://dx.doi.org/10.1093/pasj/61.5.1011
# 124  20.108511           http://dx.doi.org/10.1093/pasj/61.5.1011
# 125  61.229337          http://dx.doi.org/10.1126/science.1128177
# 126  41.324767          http://dx.doi.org/10.1126/science.1256183
# 127  41.324767          http://dx.doi.org/10.1126/science.1256183
# 128  -5.789312  http://www.sciencemag.org/content/320/5884/175...
# 129  -5.789312  http://www.sciencemag.org/content/320/5884/175...
# 130  -5.789312  http://www.sciencemag.org/content/320/5884/175...
#
#                                                   FITS              OBJECT  \
# 0         FITS_out/MAGIC_2015_CrabNebula_SPECTRUM.fits          CrabNebula
# 1       FITS_out/MAGIC_2015_CrabNebula_SPECTRUM_1.fits          CrabNebula
# 2              FITS_out/MAGIC_2009_3C454_SPECTRUM.fits               3C454
# 3            FITS_out/MAGIC_2009_3C454_SPECTRUM_1.fits               3C454
# 4            FITS_out/MAGIC_2009_3C454_SPECTRUM_2.fits               3C454
# 5      FITS_out/MAGIC_2010_PG1553_mw2008_SPECTRUM.fits         PG 1553+113
# 6      FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM.fits       Markarian 421
# 7    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_1.fits       Markarian 421
# 8    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_2.fits       Markarian 421
# 9    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_3.fits       Markarian 421
# 10   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_4.fits       Markarian 421
# 11   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_5.fits       Markarian 421
# 12   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_6.fits       Markarian 421
# 13   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_7.fits       Markarian 421
# 14   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_8.fits       Markarian 421
# 15               FITS_out/MAGIC_2012_M87_SPECTRUM.fits                 M87
# 16            FITS_out/MAGIC_2012_B32247_SPECTRUM.fits              B32247
# 17          FITS_out/MAGIC_2012_B32247_SPECTRUM_1.fits              B32247
# 18           FITS_out/MAGIC_2012_Perseus_SPECTRUM.fits             Perseus
# 19         FITS_out/MAGIC_2012_Perseus_SPECTRUM_1.fits             Perseus
# 20           FITS_out/MAGIC_2012_PKS2155_SPECTRUM.fits         Crab Nebula
# 21         FITS_out/MAGIC_2012_PKS2155_SPECTRUM_1.fits        PKS 2155-304
# 22               FITS_out/MAGIC_2012_W51_SPECTRUM.fits                 W51
# 23           FITS_out/MAGIC_2012_1ES1215_SPECTRUM.fits        1ES 1215+303
# 24         FITS_out/MAGIC_2012_1ES1215_SPECTRUM_1.fits        1ES 1215+303
# 25       FITS_out/MAGIC_2013_Magnetars_SPECTRUM_1.fits          4U 0142+61
# 26       FITS_out/MAGIC_2013_Magnetars_SPECTRUM_3.fits         1E 2259+586
# 27       FITS_out/MAGIC_2013_1ES2344+514_SPECTRUM.fits         1ES2344+514
# 28     FITS_out/MAGIC_2013_1ES2344+514_SPECTRUM_1.fits         1ES2344+514
# 29     FITS_out/MAGIC_2013_1ES2344+514_SPECTRUM_2.fits         1ES2344+514
# 30     FITS_out/MAGIC_2013_1ES2344+514_SPECTRUM_3.fits         1ES2344+514
# 31          FITS_out/MAGIC_2013_J1644+57_SPECTRUM.fits            J1644+57
# 32             FITS_out/MAGIC_2014_IC310_SPECTRUM.fits               IC310
# 33           FITS_out/MAGIC_2014_IC310_SPECTRUM_1.fits               IC310
# 34           FITS_out/MAGIC_2014_IC310_SPECTRUM_2.fits               IC310
# 35           FITS_out/MAGIC_2014_IC310_SPECTRUM_3.fits               IC310
# 36           FITS_out/MAGIC_2014_NGC1275_SPECTRUM.fits             NGC1275
# 37         FITS_out/MAGIC_2014_NGC1275_SPECTRUM_1.fits             NGC1275
# 38             FITS_out/MAGIC_2014_3C279_SPECTRUM.fits               3C279
# 39           FITS_out/MAGIC_2014_3C279_SPECTRUM_1.fits               3C279
# 40       FITS_out/MAGIC_2014_PKS1424+240_SPECTRUM.fits         PKS1424+240
# 41     FITS_out/MAGIC_2014_PKS1424+240_SPECTRUM_1.fits         PKS1424+240
# 42     FITS_out/MAGIC_2014_PKS1424+240_SPECTRUM_2.fits         PKS1424+240
# 43     FITS_out/MAGIC_2014_PKS1424+240_SPECTRUM_3.fits         PKS1424+240
# 44        FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM.fits         Crab Pulsar
# 45      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_1.fits         Crab Pulsar
# 46      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_2.fits         Crab Pulsar
# 47      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_3.fits         Crab Pulsar
# 48      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_4.fits         Crab Pulsar
# 49      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_5.fits         Crab Pulsar
# 50      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_6.fits         Crab Pulsar
# 51      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_7.fits         Crab Pulsar
# 52      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_8.fits         Crab Pulsar
# 53              FITS_out/MAGIC_2014_3C58_SPECTRUM.fits                3C58
# 54       FITS_out/MAGIC_2007_CassiopeiaA_SPECTRUM.fits         CassiopeiaA
# 55          FITS_out/MAGIC_2006_HESS1813_SPECTRUM.fits      HESS J1813-178
# 56                FITS_out/MAGIC_2006_GC_SPECTRUM.fits     Galactic Center
# 57            FITS_out/MAGIC_2006_Mrk180_SPECTRUM.fits              Mrk180
# 58          FITS_out/MAGIC_2006_Mrk180_SPECTRUM_1.fits              Mrk180
# 59            FITS_out/MAGIC_2007_Mrk421_SPECTRUM.fits              Mrk421
# 60          FITS_out/MAGIC_2007_Mrk421_SPECTRUM_1.fits              Mrk421
# 61             FITS_out/MAGIC_2007_IC443_SPECTRUM.fits               IC443
# 62          FITS_out/MAGIC_2007_CygnusX1_SPECTRUM.fits          Cygnus X-1
# 63        FITS_out/MAGIC_2007_CygnusX1_SPECTRUM_1.fits          Cygnus X-1
# 64           FITS_out/MAGIC_2007_1ES1011_SPECTRUM.fits         1ES1011+496
# 65         FITS_out/MAGIC_2007_1ES1011_SPECTRUM_1.fits         1ES1011+496
# 66        FITS_out/MAGIC_2008_1ES1959_mw_SPECTRUM.fits         1ES1959+650
# 67       FITS_out/MAGIC_2008_LSI61303_mw_SPECTRUM.fits        LS I +61 303
# 68     FITS_out/MAGIC_2008_LSI61303_mw_SPECTRUM_1.fits        LS I +61 303
# 69               FITS_out/MAGIC_2008_M87_SPECTRUM.fits                 M87
# 70             FITS_out/MAGIC_2008_M87_SPECTRUM_1.fits                 M87
# 71             FITS_out/MAGIC_2008_M87_SPECTRUM_2.fits                 M87
# 72          FITS_out/MAGIC_2008_WRBinSys_SPECTRUM.fits              WR 147
# 73        FITS_out/MAGIC_2008_WRBinSys_SPECTRUM_1.fits              WR 146
# 74             FITS_out/MAGIC_2009_3C66A_SPECTRUM.fits               3C66A
# 75          FITS_out/MAGIC_2009_LSI61303_SPECTRUM.fits        LS I +61 303
# 76        FITS_out/MAGIC_2009_LSI61303_SPECTRUM_1.fits        LS I +61 303
# 77               FITS_out/MAGIC_2009_M13_SPECTRUM.fits                 M13
# 78   FITS_out/MAGIC_2009_Mrk421_mw_outburst_SPECTRU...       Markarian 421
# 79            FITS_out/MAGIC_2009_S50716_SPECTRUM.fits         S5 0716+714
# 80          FITS_out/MAGIC_2009_S50716_SPECTRUM_1.fits         S5 0716+714
# 81     FITS_out/MAGIC_2009_Mrk501_mw2006_SPECTRUM.fits       Markarian 501
# 82           FITS_out/MAGIC_2010_Perseus_SPECTRUM.fits             Perseus
# 83         FITS_out/MAGIC_2010_Perseus_SPECTRUM_1.fits             Perseus
# 84         FITS_out/MAGIC_2010_Perseus_SPECTRUM_2.fits             Perseus
# 85         FITS_out/MAGIC_2010_Perseus_SPECTRUM_3.fits             Perseus
# 86          FITS_out/MAGIC_2010_CygnusX3_SPECTRUM.fits          Cygnus X-3
# 87        FITS_out/MAGIC_2010_CygnusX3_SPECTRUM_1.fits          Cygnus X-3
# 88        FITS_out/MAGIC_2010_CygnusX3_SPECTRUM_2.fits          Cygnus X-3
# 89    FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM.fits   1FGL J1954.3+2836
# 90   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_1....   1FGL J1954.3+2836
# 91   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_2....   1FGL J1954.3+2836
# 92   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_3....   1FGL J1954.3+2836
# 93   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_4....   1FGL J1958.6+2845
# 94   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_5....  1FGL J1958.63+2845
# 95   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_6....  1FGL J1958.63+2845
# 96   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_7....  1FGL J1958.63+2845
# 97           FITS_out/MAGIC_2011_Blazars_SPECTRUM.fits             Blazars
# 98            FITS_out/MAGIC_2014_Segue1_SPECTRUM.fits             Segue 1
# 99          FITS_out/MAGIC_2014_Segue1_SPECTRUM_1.fits             Segue 1
# 100         FITS_out/MAGIC_2014_Segue1_SPECTRUM_2.fits             Segue 1
# 101         FITS_out/MAGIC_2014_Segue1_SPECTRUM_3.fits             Segue 1
# 102         FITS_out/MAGIC_2014_Segue1_SPECTRUM_4.fits             Segue 1
# 103         FITS_out/MAGIC_2014_Segue1_SPECTRUM_5.fits             Segue 1
# 104         FITS_out/MAGIC_2014_Segue1_SPECTRUM_6.fits             Segue 1
# 105         FITS_out/MAGIC_2014_Segue1_SPECTRUM_7.fits             Segue 1
# 106         FITS_out/MAGIC_2014_Segue1_SPECTRUM_8.fits             Segue 1
# 107         FITS_out/MAGIC_2014_Segue1_SPECTRUM_9.fits             Segue 1
# 108        FITS_out/MAGIC_2014_Segue1_SPECTRUM_10.fits             Segue 1
# 109        FITS_out/MAGIC_2014_Segue1_SPECTRUM_11.fits             Segue 1
# 110        FITS_out/MAGIC_2014_Segue1_SPECTRUM_12.fits             Segue 1
# 111        FITS_out/MAGIC_2014_Segue1_SPECTRUM_13.fits             Segue 1
# 112            FITS_out/MAGIC_2010_IC310_SPECTRUM.fits               IC310
# 113          FITS_out/MAGIC_2011_PKS1222_SPECTRUM.fits         PKS 1222+21
# 114        FITS_out/MAGIC_2011_PKS1222_SPECTRUM_1.fits         PKS 1222+21
# 115       FITS_out/MAGIC_2011_ScorpiusX1_SPECTRUM.fits          ScorpiusX1
# 116     FITS_out/MAGIC_2011_ScorpiusX1_SPECTRUM_1.fits          ScorpiusX1
# 117        FITS_out/MAGIC_2014_GRB090102_SPECTRUM.fits           GRB090102
# 118          FITS_out/MAGIC_2014_4C+5517_SPECTRUM.fits           4C +55.17
# 119          FITS_out/MAGIC_2015_1ES0806_SPECTRUM.fits        1ES 0806+524
# 120        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_1.fits        1ES 0806+524
# 121        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_2.fits        1ES 0806+524
# 122        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_3.fits        1ES 0806+524
# 123            FITS_out/MAGIC_2009_OJ287_SPECTRUM.fits               OJ287
# 124          FITS_out/MAGIC_2009_OJ287_SPECTRUM_1.fits               OJ287
# 125         FITS_out/MAGIC_2006_LSI61303_SPECTRUM.fits        LS I +61 303
# 126            FITS_out/MAGIC_2014_Ic310_SPECTRUM.fits               Ic310
# 127          FITS_out/MAGIC_2014_Ic310_SPECTRUM_1.fits               Ic310
# 128            FITS_out/MAGIC_2008_3C279_SPECTRUM.fits               3C279
# 129          FITS_out/MAGIC_2008_3C279_SPECTRUM_1.fits               3C279
# 130          FITS_out/MAGIC_2008_3C279_SPECTRUM_2.fits               3C279
#
#                                                   PROC          RA  \
# 0    {u'filename': u'FITS_pic//MAGIC_2015_CrabNebul...   83.633212
# 1    {u'filename': u'FITS_pic//MAGIC_2015_CrabNebul...   83.633212
# 2    {u'filename': u'FITS_pic//MAGIC_2009_3C454.fit...  342.894735
# 3    {u'filename': u'FITS_pic//MAGIC_2009_3C454.fit...  342.894735
# 4    {u'filename': u'FITS_pic//MAGIC_2009_3C454.fit...  342.894735
# 5    {u'filename': u'FITS_pic//MAGIC_2010_PG1553_mw...  238.929350
# 6    {u'filename': u'FITS_pic//MAGIC_2010_Mrk421_mw...  166.113808
# 7    {u'filename': u'FITS_pic//MAGIC_2010_Mrk421_mw...  166.113808
# 8    {u'filename': u'FITS_pic//MAGIC_2010_Mrk421_mw...  166.113808
# 9    {u'filename': u'FITS_pic//MAGIC_2010_Mrk421_mw...  166.113808
# 10   {u'filename': u'FITS_pic//MAGIC_2010_Mrk421_mw...  166.113808
# 11   {u'filename': u'FITS_pic//MAGIC_2010_Mrk421_mw...  166.113808
# 12   {u'filename': u'FITS_pic//MAGIC_2010_Mrk421_mw...  166.113808
# 13   {u'filename': u'FITS_pic//MAGIC_2010_Mrk421_mw...  166.113808
# 14   {u'filename': u'FITS_pic//MAGIC_2010_Mrk421_mw...  166.113808
# 15   {u'filename': u'FITS_pic//MAGIC_2012_M87.fits'...  187.705931
# 16   {u'filename': u'FITS_pic//MAGIC_2012_B32247.fi...  347.343870
# 17   {u'filename': u'FITS_pic//MAGIC_2012_B32247.fi...  347.343870
# 18   {u'filename': u'FITS_pic//MAGIC_2012_Perseus.f...   49.950667
# 19   {u'filename': u'FITS_pic//MAGIC_2012_Perseus.f...   49.950667
# 20   {u'filename': u'FITS_pic//MAGIC_2012_PKS2155.f...   83.633100
# 21   {u'filename': u'FITS_pic//MAGIC_2012_PKS2155.f...  329.716900
# 22   {u'filename': u'FITS_pic//MAGIC_2012_W51.fits'...  290.925000
# 23   {u'filename': u'FITS_pic//MAGIC_2012_1ES1215.f...  184.467008
# 24   {u'filename': u'FITS_pic//MAGIC_2012_1ES1215.f...  184.467008
# 25   {u'filename': u'FITS_pic//MAGIC_2013_Magnetars...   26.593400
# 26   {u'filename': u'FITS_pic//MAGIC_2013_Magnetars...  345.284600
# 27   {u'filename': u'FITS_pic//MAGIC_2013_1ES2344+5...  356.770153
# 28   {u'filename': u'FITS_pic//MAGIC_2013_1ES2344+5...  356.770153
# 29   {u'filename': u'FITS_pic//MAGIC_2013_1ES2344+5...  356.770153
# 30   {u'filename': u'FITS_pic//MAGIC_2013_1ES2344+5...  356.770153
# 31   {u'filename': u'FITS_pic//MAGIC_2013_J1644+57....         NaN
# 32   {u'filename': u'FITS_pic//MAGIC_2014_IC310.fit...   49.179271
# 33   {u'filename': u'FITS_pic//MAGIC_2014_IC310.fit...   49.179271
# 34   {u'filename': u'FITS_pic//MAGIC_2014_IC310.fit...   49.179271
# 35   {u'filename': u'FITS_pic//MAGIC_2014_IC310.fit...   49.179271
# 36   {u'filename': u'FITS_pic//MAGIC_2014_NGC1275.f...   49.950667
# 37   {u'filename': u'FITS_pic//MAGIC_2014_NGC1275.f...   49.950667
# 38   {u'filename': u'FITS_pic//MAGIC_2014_3C279.fit...  194.046527
# 39   {u'filename': u'FITS_pic//MAGIC_2014_3C279.fit...  194.046527
# 40   {u'filename': u'FITS_pic//MAGIC_2014_PKS1424+2...  216.751632
# 41   {u'filename': u'FITS_pic//MAGIC_2014_PKS1424+2...  216.751632
# 42   {u'filename': u'FITS_pic//MAGIC_2014_PKS1424+2...  216.751632
# 43   {u'filename': u'FITS_pic//MAGIC_2014_PKS1424+2...  216.751632
# 44   {u'filename': u'FITS_pic//MAGIC_2014_CrabPulsa...   83.633076
# 45   {u'filename': u'FITS_pic//MAGIC_2014_CrabPulsa...   83.633076
# 46   {u'filename': u'FITS_pic//MAGIC_2014_CrabPulsa...   83.633076
# 47   {u'filename': u'FITS_pic//MAGIC_2014_CrabPulsa...   83.633076
# 48   {u'filename': u'FITS_pic//MAGIC_2014_CrabPulsa...   83.633076
# 49   {u'filename': u'FITS_pic//MAGIC_2014_CrabPulsa...   83.633076
# 50   {u'filename': u'FITS_pic//MAGIC_2014_CrabPulsa...   83.633076
# 51   {u'filename': u'FITS_pic//MAGIC_2014_CrabPulsa...   83.633076
# 52   {u'filename': u'FITS_pic//MAGIC_2014_CrabPulsa...   83.633076
# 53   {u'filename': u'FITS_pic//MAGIC_2014_3C58.fits...   31.404300
# 54   {u'filename': u'FITS_pic//MAGIC_2007_Cassiopei...  350.866417
# 55   {u'filename': u'FITS_pic//MAGIC_2006_HESS1813....  273.362920
# 56   {u'filename': u'FITS_pic//MAGIC_2006_GC.fits',...  266.416833
# 57   {u'filename': u'FITS_pic//MAGIC_2006_Mrk180.fi...  174.110035
# 58   {u'filename': u'FITS_pic//MAGIC_2006_Mrk180.fi...  174.110035
# 59   {u'filename': u'FITS_pic//MAGIC_2007_Mrk421.fi...  166.113808
# 60   {u'filename': u'FITS_pic//MAGIC_2007_Mrk421.fi...  166.113808
# 61   {u'filename': u'FITS_pic//MAGIC_2007_IC443.fit...   94.511250
# 62   {u'filename': u'FITS_pic//MAGIC_2007_CygnusX1....  299.590316
# 63   {u'filename': u'FITS_pic//MAGIC_2007_CygnusX1....  299.590316
# 64   {u'filename': u'FITS_pic//MAGIC_2007_1ES1011.f...  153.767249
# 65   {u'filename': u'FITS_pic//MAGIC_2007_1ES1011.f...  153.767249
# 66   {u'filename': u'FITS_pic//MAGIC_2008_1ES1959_m...  299.999384
# 67   {u'filename': u'FITS_pic//MAGIC_2008_LSI61303_...   40.131938
# 68   {u'filename': u'FITS_pic//MAGIC_2008_LSI61303_...   40.131938
# 69   {u'filename': u'FITS_pic//MAGIC_2008_M87.fits'...  187.705931
# 70   {u'filename': u'FITS_pic//MAGIC_2008_M87.fits'...  187.705931
# 71   {u'filename': u'FITS_pic//MAGIC_2008_M87.fits'...  187.705931
# 72   {u'filename': u'FITS_pic//MAGIC_2008_WRBinSys....  309.181500
# 73   {u'filename': u'FITS_pic//MAGIC_2008_WRBinSys....  308.946000
# 74   {u'filename': u'FITS_pic//MAGIC_2009_3C66A.fit...   35.665050
# 75   {u'filename': u'FITS_pic//MAGIC_2009_LSI61303....   40.131938
# 76   {u'filename': u'FITS_pic//MAGIC_2009_LSI61303....   40.131938
# 77   {u'filename': u'FITS_pic//MAGIC_2009_M13.fits'...  250.423475
# 78   {u'filename': u'FITS_pic//MAGIC_2009_Mrk421_mw...  166.113808
# 79   {u'filename': u'FITS_pic//MAGIC_2009_S50716.fi...  110.472702
# 80   {u'filename': u'FITS_pic//MAGIC_2009_S50716.fi...  110.472702
# 81   {u'filename': u'FITS_pic//MAGIC_2009_Mrk501_mw...  253.467569
# 82   {u'filename': u'FITS_pic//MAGIC_2010_Perseus.f...   49.950667
# 83   {u'filename': u'FITS_pic//MAGIC_2010_Perseus.f...   49.950667
# 84   {u'filename': u'FITS_pic//MAGIC_2010_Perseus.f...   49.950667
# 85   {u'filename': u'FITS_pic//MAGIC_2010_Perseus.f...   49.950667
# 86   {u'filename': u'FITS_pic//MAGIC_2010_CygnusX3....  308.107417
# 87   {u'filename': u'FITS_pic//MAGIC_2010_CygnusX3....  308.107417
# 88   {u'filename': u'FITS_pic//MAGIC_2010_CygnusX3....  308.107417
# 89   {u'filename': u'FITS_pic//MAGIC_2010_MilagroSN...  298.580000
# 90   {u'filename': u'FITS_pic//MAGIC_2010_MilagroSN...  298.580000
# 91   {u'filename': u'FITS_pic//MAGIC_2010_MilagroSN...  298.580000
# 92   {u'filename': u'FITS_pic//MAGIC_2010_MilagroSN...  298.580000
# 93   {u'filename': u'FITS_pic//MAGIC_2010_MilagroSN...  299.667900
# 94   {u'filename': u'FITS_pic//MAGIC_2010_MilagroSN...  299.667900
# 95   {u'filename': u'FITS_pic//MAGIC_2010_MilagroSN...  299.667900
# 96   {u'filename': u'FITS_pic//MAGIC_2010_MilagroSN...  299.667900
# 97   {u'filename': u'FITS_pic//MAGIC_2011_Blazars.f...         NaN
# 98   {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 99   {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 100  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 101  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 102  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 103  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 104  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 105  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 106  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 107  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 108  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 109  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 110  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 111  {u'filename': u'FITS_pic//MAGIC_2014_Segue1.fi...  151.763330
# 112  {u'filename': u'FITS_pic//MAGIC_2010_IC310.fit...   49.179271
# 113  {u'filename': u'FITS_pic//MAGIC_2011_PKS1222.f...  186.226920
# 114  {u'filename': u'FITS_pic//MAGIC_2011_PKS1222.f...  186.226920
# 115  {u'filename': u'FITS_pic//MAGIC_2011_ScorpiusX...         NaN
# 116  {u'filename': u'FITS_pic//MAGIC_2011_ScorpiusX...         NaN
# 117  {u'filename': u'FITS_pic//MAGIC_2014_GRB090102...  128.247917
# 118  {u'filename': u'FITS_pic//MAGIC_2014_4C+5517.f...  149.409094
# 119  {u'filename': u'FITS_pic//MAGIC_2015_1ES0806.f...  122.454945
# 120  {u'filename': u'FITS_pic//MAGIC_2015_1ES0806.f...  122.454945
# 121  {u'filename': u'FITS_pic//MAGIC_2015_1ES0806.f...  122.454945
# 122  {u'filename': u'FITS_pic//MAGIC_2015_1ES0806.f...  122.454945
# 123  {u'filename': u'FITS_pic//MAGIC_2009_OJ287.fit...  133.703646
# 124  {u'filename': u'FITS_pic//MAGIC_2009_OJ287.fit...  133.703646
# 125  {u'filename': u'FITS_pic//MAGIC_2006_LSI61303....   40.131938
# 126  {u'filename': u'FITS_pic//MAGIC_2014_Ic310.fit...   49.179271
# 127  {u'filename': u'FITS_pic//MAGIC_2014_Ic310.fit...   49.179271
# 128  {u'filename': u'FITS_pic//MAGIC_2008_3C279.fit...  194.046527
# 129  {u'filename': u'FITS_pic//MAGIC_2008_3C279.fit...  194.046527
# 130  {u'filename': u'FITS_pic//MAGIC_2008_3C279.fit...  194.046527
#
#                                           SOURCE  \
# 0                                    Crab Nebula
# 1                                    Crab Nebula
# 2                                       3C 454.3
# 3                                       3C 454.3
# 4                                       3C 454.3
# 5                                    PG 1553+113
# 6                                  Markarian 421
# 7                                  Markarian 421
# 8                                  Markarian 421
# 9                                  Markarian 421
# 10                                 Markarian 421
# 11                                 Markarian 421
# 12                                 Markarian 421
# 13                                 Markarian 421
# 14                                 Markarian 421
# 15                                           M87
# 16                                   B3 2247+381
# 17                                   B3 2247+381
# 18                               Perseus Cluster
# 19                               Perseus Cluster
# 20                                  PKS 2155-304
# 21                                  PKS 2155-304
# 22                                           W51
# 23                                  1ES 1215+303
# 24                                  1ES 1215+303
# 25                      4U 0142+61, 1ES 2259+586
# 26                      4U 0142+61, 1ES 2259+586
# 27                                  1ES 2344+514
# 28                                  1ES 2344+514
# 29                                  1ES 2344+514
# 30                                  1ES 2344+514
# 31                                Swift J1644+57
# 32                                        IC 310
# 33                                        IC 310
# 34                                        IC 310
# 35                                        IC 310
# 36                                      NGC 1275
# 37                                      NGC 1275
# 38                                        3C 279
# 39                                        3C 279
# 40                                  PKS 1424+240
# 41                                  PKS 1424+240
# 42                                  PKS 1424+240
# 43                                  PKS 1424+240
# 44                                   Crab Pulsar
# 45                                   Crab Pulsar
# 46                                   Crab Pulsar
# 47                                   Crab Pulsar
# 48                                   Crab Pulsar
# 49                                   Crab Pulsar
# 50                                   Crab Pulsar
# 51                                   Crab Pulsar
# 52                                   Crab Pulsar
# 53                                         3C 58
# 54                                  Cassiopeia A
# 55                                HESS J1813-178
# 56                               Galactic Center
# 57                                 Markarian 180
# 58                                 Markarian 180
# 59                                 Markarian 421
# 60                                 Markarian 421
# 61                                        IC 443
# 62                                    Cygnus X-1
# 63                                    Cygnus X-1
# 64                                   1ES1011+496
# 65                                   1ES1011+496
# 66                                   1ES1959+650
# 67                                  LS I +61 303
# 68                                  LS I +61 303
# 69                                           M87
# 70                                           M87
# 71                                           M87
# 72                              WR Binary System
# 73                              WR Binary System
# 74                                      3C 66A/B
# 75                                  LS I +61 303
# 76                                  LS I +61 303
# 77                                           M13
# 78                                 Markarian 421
# 79                                   S5 0716+714
# 80                                   S5 0716+714
# 81                                 Markarian 501
# 82                               Perseus Cluster
# 83                               Perseus Cluster
# 84                               Perseus Cluster
# 85                               Perseus Cluster
# 86                                    Cygnus X-3
# 87                                    Cygnus X-3
# 88                                    Cygnus X-3
# 89          1FGL J1954.3+2836, 1FGL J1958.6+2845
# 90          1FGL J1954.3+2836, 1FGL J1958.6+2845
# 91          1FGL J1954.3+2836, 1FGL J1958.6+2845
# 92          1FGL J1954.3+2836, 1FGL J1958.6+2845
# 93          1FGL J1954.3+2836, 1FGL J1958.6+2845
# 94          1FGL J1954.3+2836, 1FGL J1958.6+2845
# 95          1FGL J1954.3+2836, 1FGL J1958.6+2845
# 96          1FGL J1954.3+2836, 1FGL J1958.6+2845
# 97   1ES 0333+595, RGB J117+202, B2 1215+30, ...
# 98                                       Segue 1
# 99                                       Segue 1
# 100                                      Segue 1
# 101                                      Segue 1
# 102                                      Segue 1
# 103                                      Segue 1
# 104                                      Segue 1
# 105                                      Segue 1
# 106                                      Segue 1
# 107                                      Segue 1
# 108                                      Segue 1
# 109                                      Segue 1
# 110                                      Segue 1
# 111                                      Segue 1
# 112                                       IC 310
# 113                                  PKS 1222+21
# 114                                  PKS 1222+21
# 115                                 Scorpius X-1
# 116                                 Scorpius X-1
# 117                                   GRB 090102
# 118                                    4C +55.17
# 119                                 1ES 0806+524
# 120                                 1ES 0806+524
# 121                                 1ES 0806+524
# 122                                 1ES 0806+524
# 123                                       OJ 287
# 124                                       OJ 287
# 125                                 LS I +61 303
# 126                                       IC 310
# 127                                       IC 310
# 128                                       3C 279
# 129                                       3C 279
# SPECTRUM    False
# dtype: bool
#
# -> Indexes where column 'DEC' is null:
# [ 31  97 115 116]
#
# -> Indexes where column 'RA' is null:
# [ 31  97 115 116]

# %%
table_final = table_proc.dropna()[['OBJECT','RA','DEC','DOI','FITS']]

# %%
print_describe(table_final)
# Out:
#          OBJECT          RA         DEC                                              DOI  \
# count       127  127.000000  127.000000                                              127
# unique       47         NaN         NaN                                               49
# top     Segue 1         NaN         NaN  http://dx.doi.org/10.1088/1475-7516/2014/02/008
# freq         14         NaN         NaN                                               14
# mean        NaN  173.857049   31.384582                                              NaN
# std         NaN   97.863248   19.723954                                              NaN
# min         NaN   26.593400  -30.225600                                              NaN
# 25%         NaN   83.633088   18.811129                                              NaN
# 50%         NaN  166.113808   30.116843                                              NaN
# 75%         NaN  251.945522   41.511695                                              NaN
# max         NaN  356.770153   71.343434                                              NaN
#
#                                                      FITS
# count                                                 127
# unique                                                127
# top     FITS_out/MAGIC_2009_Mrk421_mw_outburst_SPECTRU...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
# -> Has Nil?
# OBJECT    False
# RA        False
# DEC       False
# DOI       False
# FITS      False
# dtype: bool

# %%
print table_final
# Out:
#                  OBJECT          RA        DEC                                                DOI  \
# 0            CrabNebula   83.633212  22.014460      http://dx.doi.org/10.1016/j.jheap.2015.01.002
# 1            CrabNebula   83.633212  22.014460      http://dx.doi.org/10.1016/j.jheap.2015.01.002
# 2                 3C454  342.894735  18.811129      http://dx.doi.org/10.1051/0004-6361/200811326
# 3                 3C454  342.894735  18.811129      http://dx.doi.org/10.1051/0004-6361/200811326
# 4                 3C454  342.894735  18.811129      http://dx.doi.org/10.1051/0004-6361/200811326
# 5           PG 1553+113  238.929350  11.190102      http://dx.doi.org/10.1051/0004-6361/200913607
# 6         Markarian 421  166.113808  38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 7         Markarian 421  166.113808  38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 8         Markarian 421  166.113808  38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 9         Markarian 421  166.113808  38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 10        Markarian 421  166.113808  38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 11        Markarian 421  166.113808  38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 12        Markarian 421  166.113808  38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 13        Markarian 421  166.113808  38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 14        Markarian 421  166.113808  38.208833      http://dx.doi.org/10.1051/0004-6361/200913945
# 15                  M87  187.705931  12.391123      http://dx.doi.org/10.1051/0004-6361/201117827
# 16               B32247  347.343870   2.144386      http://dx.doi.org/10.1051/0004-6361/201117967
# 17               B32247  347.343870   2.144386      http://dx.doi.org/10.1051/0004-6361/201117967
# 18              Perseus   49.950667  41.511695      http://dx.doi.org/10.1051/0004-6361/201118502
# 19              Perseus   49.950667  41.511695      http://dx.doi.org/10.1051/0004-6361/201118502
# 20          Crab Nebula   83.633100  22.014500      http://dx.doi.org/10.1051/0004-6361/201218796
# 21         PKS 2155-304  329.716900 -30.225600      http://dx.doi.org/10.1051/0004-6361/201218796
# 22                  W51  290.925000  14.509170      http://dx.doi.org/10.1051/0004-6361/201218846
# 23         1ES 1215+303  184.467008  30.116843      http://dx.doi.org/10.1051/0004-6361/201219133
# 24         1ES 1215+303  184.467008  30.116843      http://dx.doi.org/10.1051/0004-6361/201219133
# 25           4U 0142+61   26.593400  61.750900      http://dx.doi.org/10.1051/0004-6361/201220275
# 26          1E 2259+586  345.284600  58.879000      http://dx.doi.org/10.1051/0004-6361/201220275
# 27          1ES2344+514  356.770153  51.704967      http://dx.doi.org/10.1051/0004-6361/201220714
# 28          1ES2344+514  356.770153  51.704967      http://dx.doi.org/10.1051/0004-6361/201220714
# 29          1ES2344+514  356.770153  51.704967      http://dx.doi.org/10.1051/0004-6361/201220714
# 30          1ES2344+514  356.770153  51.704967      http://dx.doi.org/10.1051/0004-6361/201220714
# 32                IC310   49.179271  41.324767      http://dx.doi.org/10.1051/0004-6361/201321938
#
.511695      http://dx.doi.org/10.1088/0004-637X/710/1/634
# 83              Perseus   49.950667  41.511695      http://dx.doi.org/10.1088/0004-637X/710/1/634
# 84              Perseus   49.950667  41.511695      http://dx.doi.org/10.1088/0004-637X/710/1/634
# 85              Perseus   49.950667  41.511695      http://dx.doi.org/10.1088/0004-637X/710/1/634
# 86           Cygnus X-3  308.107417  40.957750      http://dx.doi.org/10.1088/0004-637X/721/1/843
# 87           Cygnus X-3  308.107417  40.957750      http://dx.doi.org/10.1088/0004-637X/721/1/843
# 88           Cygnus X-3  308.107417  40.957750      http://dx.doi.org/10.1088/0004-637X/721/1/843
# 89    1FGL J1954.3+2836  298.580000  28.601100     http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 90    1FGL J1954.3+2836  298.580000  28.601100     http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 91    1FGL J1954.3+2836  298.580000  28.601100     http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 92    1FGL J1954.3+2836  298.580000  28.601100     http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 93    1FGL J1958.6+2845  299.667900  28.765000     http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 94   1FGL J1958.63+2845  299.667900  28.765000     http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 95   1FGL J1958.63+2845  299.667900  28.765000     http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 96   1FGL J1958.63+2845  299.667900  28.765000     http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 98              Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 99              Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 100             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 101             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 102             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 103             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 104             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 105             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 106             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 107             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 108             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 109             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 110             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 111             Segue 1  151.763330  16.073610    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 112               IC310   49.179271  41.324767     http://dx.doi.org/10.1088/2041-8205/723/2/L207
# 113         PKS 1222+21  186.226920  21.379562       http://dx.doi.org/10.1088/2041-8205/730/1/L8
# 114         PKS 1222+21  186.226920  21.379562       http://dx.doi.org/10.1088/2041-8205/730/1/L8
# 117           GRB090102  128.247917  33.107139            http://dx.doi.org/10.1093/mnras/stt2041
# 118           4C +55.17  149.409094  55.382704             http://dx.doi.org/10.1093/mnras/stu227
# 119        1ES 0806+524  122.454945  52.316181             http://dx.doi.org/10.1093/mnras/stv895
# 120        1ES 0806+524  122.454945  52.316181             http://dx.doi.org/10.1093/mnras/stv895
# 121        1ES 0806+524  122.454945  52.316181             http://dx.doi.org/10.1093/mnras/stv895
# 122        1ES 0806+524  122.454945  52.316181             http://dx.doi.org/10.1093/mnras/stv895
# 123               OJ287  133.703646  20.108511           http://dx.doi.org/10.1093/pasj/61.5.1011
# 124               OJ287  133.703646  20.108511           http://dx.doi.org/10.1093/pasj/61.5.1011
# 125        LS I +61 303   40.131938  61.229337          http://dx.doi.org/10.1126/science.1128177
# 126               Ic310   49.179271  41.324767          http://dx.doi.org/10.1126/science.1256183
# 127               Ic310   49.179271  41.324767          http://dx.doi.org/10.1126/science.1256183
# 128               3C279  194.046527  -5.789312  http://www.sciencemag.org/content/320/5884/175...
# 129               3C279  194.046527  -5.789312  http://www.sciencemag.org/content/320/5884/175...
# 130               3C279  194.046527  -5.789312  http://www.sciencemag.org/content/320/5884/175...
#
#                                                   FITS
# 0         FITS_out/MAGIC_2015_CrabNebula_SPECTRUM.fits
# 1       FITS_out/MAGIC_2015_CrabNebula_SPECTRUM_1.fits
# 2              FITS_out/MAGIC_2009_3C454_SPECTRUM.fits
# 3            FITS_out/MAGIC_2009_3C454_SPECTRUM_1.fits
# 4            FITS_out/MAGIC_2009_3C454_SPECTRUM_2.fits
# 5      FITS_out/MAGIC_2010_PG1553_mw2008_SPECTRUM.fits
# 6      FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM.fits
# 7    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_1.fits
# 8    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_2.fits
# 9    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_3.fits
# 10   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_4.fits
# 11   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_5.fits
# 12   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_6.fits
# 13   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_7.fits
# 14   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_8.fits
# 15               FITS_out/MAGIC_2012_M87_SPECTRUM.fits
# 16            FITS_out/MAGIC_2012_B32247_SPECTRUM.fits
# 17          FITS_out/MAGIC_2012_B32247_SPECTRUM_1.fits
# 18           FITS_out/MAGIC_2012_Perseus_SPECTRUM.fits
# 19         FITS_out/MAGIC_2012_Perseus_SPECTRUM_1.fits
# 20           FITS_out/MAGIC_2012_PKS2155_SPECTRUM.fits
# 21         FITS_out/MAGIC_2012_PKS2155_SPECTRUM_1.fits
# 22               FITS_out/MAGIC_2012_W51_SPECTRUM.fits
# 23           FITS_out/MAGIC_2012_1ES1215_SPECTRUM.fits
# 24         FITS_out/MAGIC_2012_1ES1215_SPECTRUM_1.fits
# 25       FITS_out/MAGIC_2013_Magnetars_SPECTRUM_1.fits
# 26       FITS_out/MAGIC_2013_Magnetars_SPECTRUM_3.fits
# 27       FITS_out/MAGIC_2013_1ES2344+514_SPECTRUM.fits
# 28     FITS_out/MAGIC_2013_1ES2344+514_SPECTRUM_1.fits
# 29     FITS_out/MAGIC_2013_1ES2344+514_SPECTRUM_2.fits
# 30     FITS_out/MAGIC_2013_1ES2344+514_SPECTRUM_3.fits
# 32             FITS_out/MAGIC_2014_IC310_SPECTRUM.fits
# 33           FITS_out/MAGIC_2014_IC310_SPECTRUM_1.fits
# 34           FITS_out/MAGIC_2014_IC310_SPECTRUM_2.fits
# 35           FITS_out/MAGIC_2014_IC310_SPECTRUM_3.fits
# 36           FITS_out/MAGIC_2014_NGC1275_SPECTRUM.fits
# 37         FITS_out/MAGIC_2014_NGC1275_SPECTRUM_1.fits
# 38             FITS_out/MAGIC_2014_3C279_SPECTRUM.fits
# 39           FITS_out/MAGIC_2014_3C279_SPECTRUM_1.fits
# 40       FITS_out/MAGIC_2014_PKS1424+240_SPECTRUM.fits
# 41     FITS_out/MAGIC_2014_PKS1424+240_SPECTRUM_1.fits
# 42     FITS_out/MAGIC_2014_PKS1424+240_SPECTRUM_2.fits
# 43     FITS_out/MAGIC_2014_PKS1424+240_SPECTRUM_3.fits
# 44        FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM.fits
# 45      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_1.fits
# 46      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_2.fits
# 47      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_3.fits
# 48      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_4.fits
# 49      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_5.fits
# 50      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_6.fits
# 51      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_7.fits
# 52      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_8.fits
# 53              FITS_out/MAGIC_2014_3C58_SPECTRUM.fits
# 54       FITS_out/MAGIC_2007_CassiopeiaA_SPECTRUM.fits
# 55          FITS_out/MAGIC_2006_HESS1813_SPECTRUM.fits
# 56                FITS_out/MAGIC_2006_GC_SPECTRUM.fits
# 57            FITS_out/MAGIC_2006_Mrk180_SPECTRUM.fits
# 58          FITS_out/MAGIC_2006_Mrk180_SPECTRUM_1.fits
# 59            FITS_out/MAGIC_2007_Mrk421_SPECTRUM.fits
# 60          FITS_out/MAGIC_2007_Mrk421_SPECTRUM_1.fits
# 61             FITS_out/MAGIC_2007_IC443_SPECTRUM.fits
# 62          FITS_out/MAGIC_2007_CygnusX1_SPECTRUM.fits
# 63        FITS_out/MAGIC_2007_CygnusX1_SPECTRUM_1.fits
# 64           FITS_out/MAGIC_2007_1ES1011_SPECTRUM.fits
# 65         FITS_out/MAGIC_2007_1ES1011_SPECTRUM_1.fits
# 66        FITS_out/MAGIC_2008_1ES1959_mw_SPECTRUM.fits
# 67       FITS_out/MAGIC_2008_LSI61303_mw_SPECTRUM.fits
# 68     FITS_out/MAGIC_2008_LSI61303_mw_SPECTRUM_1.fits
# 69               FITS_out/MAGIC_2008_M87_SPECTRUM.fits
# 70             FITS_out/MAGIC_2008_M87_SPECTRUM_1.fits
# 71             FITS_out/MAGIC_2008_M87_SPECTRUM_2.fits
# 72          FITS_out/MAGIC_2008_WRBinSys_SPECTRUM.fits
# 73        FITS_out/MAGIC_2008_WRBinSys_SPECTRUM_1.fits
# 74             FITS_out/MAGIC_2009_3C66A_SPECTRUM.fits
# 75          FITS_out/MAGIC_2009_LSI61303_SPECTRUM.fits
# 76        FITS_out/MAGIC_2009_LSI61303_SPECTRUM_1.fits
# 77               FITS_out/MAGIC_2009_M13_SPECTRUM.fits
# 78   FITS_out/MAGIC_2009_Mrk421_mw_outburst_SPECTRU...
# 79            FITS_out/MAGIC_2009_S50716_SPECTRUM.fits
# 80          FITS_out/MAGIC_2009_S50716_SPECTRUM_1.fits
# 81     FITS_out/MAGIC_2009_Mrk501_mw2006_SPECTRUM.fits
# 82           FITS_out/MAGIC_2010_Perseus_SPECTRUM.fits
# 83         FITS_out/MAGIC_2010_Perseus_SPECTRUM_1.fits
# 84         FITS_out/MAGIC_2010_Perseus_SPECTRUM_2.fits
# 85         FITS_out/MAGIC_2010_Perseus_SPECTRUM_3.fits
# 86          FITS_out/MAGIC_2010_CygnusX3_SPECTRUM.fits
# 87        FITS_out/MAGIC_2010_CygnusX3_SPECTRUM_1.fits
# 88        FITS_out/MAGIC_2010_CygnusX3_SPECTRUM_2.fits
# 89    FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM.fits
# 90   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_1....
# 91   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_2....
# 92   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_3....
# 93   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_4....
# 94   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_5....
# 95   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_6....
# 96   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_7....
# 98            FITS_out/MAGIC_2014_Segue1_SPECTRUM.fits
# 99          FITS_out/MAGIC_2014_Segue1_SPECTRUM_1.fits
# 100         FITS_out/MAGIC_2014_Segue1_SPECTRUM_2.fits
# 101         FITS_out/MAGIC_2014_Segue1_SPECTRUM_3.fits
# 102         FITS_out/MAGIC_2014_Segue1_SPECTRUM_4.fits
# 103         FITS_out/MAGIC_2014_Segue1_SPECTRUM_5.fits
# 104         FITS_out/MAGIC_2014_Segue1_SPECTRUM_6.fits
# 105         FITS_out/MAGIC_2014_Segue1_SPECTRUM_7.fits
# 106         FITS_out/MAGIC_2014_Segue1_SPECTRUM_8.fits
# 107         FITS_out/MAGIC_2014_Segue1_SPECTRUM_9.fits
# 108        FITS_out/MAGIC_2014_Segue1_SPECTRUM_10.fits
# 109        FITS_out/MAGIC_2014_Segue1_SPECTRUM_11.fits
# 110        FITS_out/MAGIC_2014_Segue1_SPECTRUM_12.fits
# 111        FITS_out/MAGIC_2014_Segue1_SPECTRUM_13.fits
# 112            FITS_out/MAGIC_2010_IC310_SPECTRUM.fits
# 113          FITS_out/MAGIC_2011_PKS1222_SPECTRUM.fits
# 114        FITS_out/MAGIC_2011_PKS1222_SPECTRUM_1.fits
# 117        FITS_out/MAGIC_2014_GRB090102_SPECTRUM.fits
# 118          FITS_out/MAGIC_2014_4C+5517_SPECTRUM.fits
# 119          FITS_out/MAGIC_2015_1ES0806_SPECTRUM.fits
# 120        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_1.fits
# 121        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_2.fits
# 122        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_3.fits
# 123            FITS_out/MAGIC_2009_OJ287_SPECTRUM.fits
# 124          FITS_out/MAGIC_2009_OJ287_SPECTRUM_1.fits
# 125         FITS_out/MAGIC_2006_LSI61303_SPECTRUM.fits
# 126            FITS_out/MAGIC_2014_Ic310_SPECTRUM.fits
# 127          FITS_out/MAGIC_2014_Ic310_SPECTRUM_1.fits
# 128            FITS_out/MAGIC_2008_3C279_SPECTRUM.fits
# 129          FITS_out/MAGIC_2008_3C279_SPECTRUM_1.fits
# 130          FITS_out/MAGIC_2008_3C279_SPECTRUM_2.fits

# %%
table_final.to_csv('table_final_clean.csv')
