# %% [markdown]
# # Reprocessing data from MAGIC/PIC base

# %%
# We start with some code to access the table at http://vobs.magic.pic.es/fits/
def get_table_from_url(url):
    from bs4 import BeautifulSoup as BS
    import urllib2
    soup = BS(urllib2.urlopen(url).read())
    table = soup.find('table',{'class','mytable'})
    return table

url = 'http://vobs.magic.pic.es/fits/'
table_pic_html = get_table_from_url(url)

# %%
from IPython.display import HTML
HTML(unicode(table_pic_html))
# Out:
# <table cellspacing="0" class="mytable" id="table_3">
# <tr>
# <th><strong>Source</strong></th>
# <th><strong>Article</strong></th>
# <th><strong>Year</strong></th>
# <th width="20%"><strong>Reference</strong></th>
# <th><strong>Download</strong></th>
# </tr>
# <!--when the paper is not published yet: <td ALIGN="center"><b><FONT COLOR="#808080">FITS</font></b></td>-->
# <!--98-->
# <tr>
# <td><strong> Mrk 421 </strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1412.3576T"><font color="#280099">  Unprecedented study of the broadband emission of Mrk 421 during flaring activity in March 2010 </font></a></td>
# <td align="center">2015</td>
# <td>(2014arXiv1412.3576T)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--97-->
# <tr>
# <td><strong> Crab Nebula </strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1406.6892M"><font color="#280099">  Measurement of the Crab nebula spectrum over three decades in energy with the MAGIC telescopes </font></a></td>
# <td align="center">2015</td>
# <td>(2014arXiv1406.6892M)</td>
# <td align="center"><a href="mfits/base/MAGIC_2015_CrabNebula.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--96-->
# <tr>
# <td><strong> PG 1553+113 </strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1408.1975M"><font color="#280099">  Probing the very-high-energy γ-ray spectral curvature in the blazar PG 1553+113 with the MAGIC telescopes </font></a></td>
# <td align="center">2015</td>
# <td>(2014arXiv1408.1975M)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--95-->
# <tr>
# <td><strong> 1ES 0806+524 </strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2015arXiv150406115M"><font color="#280099">  MAGIC detection of short-term variability of the high-peaked BL Lac object 1ES 0806+524 </font></a></td>
# <td align="center">2015</td>
# <td>(J. Aleksić et al., MNRAS 451, 5258-5269)</td>
# <td align="center"><a href="mfits/base/MAGIC_2015_1ES0806.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--94-->
# <tr>
# <td><strong> HESS J1857+026</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014A%26A...571A..96A"><font color="#280099">   MAGIC reveals a complex morphology within the unidentified gamma-ray source HESS J1857+026 </font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A 571, A96)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--93-->
# <tr>
# <td><strong> J2001+439</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1409.3389M"><font color="#280099">   First broadband characterization and redshift determination of the VHE blazar MAGIC J2001+439 </font></a></td>
# <td align="center">2014</td>
# <td>(2014arXiv1409.3389M)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--92-->
# <tr>
# <td><strong> Mrk 501</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1410.6391M"><font color="#280099">   Multiwavelength Observations of Mrk 501 in 2008 </font></a></td>
# <td align="center">2014</td>
# <td>(2014arXiv1410.6391M)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--91-->
# <tr>
# <td><strong> 1ES 0033+595</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1410.7059A"><font color="#280099">   Discovery of very high energy gamma-ray emission from the blazar 1ES 0033+595 by the MAGIC telescopes</font></a></td>
# <td align="center">2014</td>
# <td>(2014arXiv1410.7059A)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--90-->
# <tr>
# <td><strong> IC 310</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014Sci...346.1080A"><font color="#280099">   Black Hole lightning due to particle acceleration at sub-horizon scales</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., Science 346, 1080-1084)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_Ic310.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--89-->
# <tr>
# <td><strong> PKS 1424+240</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1401.0464M"><font color="#280099">   MAGIC long-term study of the distant TeV blazar PKS 1424+240 in a multiwavelength context</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A 567, A135)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_PKS1424+240.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--88-->
# <tr>
# <td><strong> 3C 58</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1405.6074M"><font color="#280099">   Discovery of TeV gamma-ray emission from the pulsar wind nebula 3C 58 by MAGIC</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A 567, L8)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_3C58.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--87-->
# <tr>
# <td><strong> AE Aquarii</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1407.3707A"><font color="#280099">   MAGIC search for VHE gamma-ray emission from AE Aquarii in a multiwavelength context</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A 568, A109)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_AEaqr.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--86-->
# <tr>
# <td><strong>  PKS 1510-089</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014arXiv1401.5646M"><font color="#280099">   MAGIC gamma-ray and multi-frequency observations of flat spectrum radio quasar PKS 1510-089 in early 2012</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A 569, A46)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--85-->
# <tr>
# <td><strong>  3C 279</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2013arXiv1311.2833A"><font color="#280099">   MAGIC observations &amp; multifrequency properties of the Flat Spectrum Radio Quasar 3C 279 in 2011</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A 567, A41)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_3C279.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--84-->
# <tr>
# <td><strong>  4C +55.17</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014MNRAS.440..530A"><font color="#280099">   Search for very high energy gamma-rays from the z=0.896 Quasar 4C +55.17 with MAGIC Telescopes</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., MNRAS 440, 530)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_4C+5517.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--83-->
# <tr>
# <td><strong>   Crab Pulsar</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014A%26A...565L..12A"><font color="#280099">   Detection of bridge emission above 50 GeV from the Crab Pulsar with MAGIC Telescopes</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A 565, L12)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_CrabPulsar.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--82-->
# <tr>
# <td><strong>   NGC 1275</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014A%26A...564A...5A"><font color="#280099">   Contemporaneous observations of the radio galaxy NGC 1275 from radio to very high energy gamma-rays</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A 564, A5)</td>
# <td align="center"><a href="mfits/base/MAGIC_2014_NGC1275.fits"><font color="#000000">FITS</font></a></td>
# </tr>
# <!--81-->
# <tr>
# <td><strong>   1ES 1727+50</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014A%26A...563A..90A"><font color="#280099">   Discovery of very high energy gamma emission from the blazar 1ES 1727+502 with MAGIC Telescopes</font></a></td>
# <td align="center">2014</td>
# <td>(J. Aleksić et al., A&amp;A 563, A90)</td>
# <td align="center"><b><font color="#808080">FITS</font></b></td>
# </tr>
# <!--80-->
# <tr>
# <td><strong>   4C +21.35</strong></td>
# <td><a href="http://cdsads.u-strasbg.fr/abs/2014ApJ...786..157A"><font color="#280099">   Multifrequency st

# %%
# This table now is parsed to get the columns
def get_table_fields(table):

    def get_doi_url(url):
        # The url of the reference ("aurl").
        from bs4 import BeautifulSoup as BS
        import urllib2
        import re
        _ads = 'adsabs'
        _cds = 'cdsads'
        _axv = 'arxiv'
        if (_ads in url or _cds in url or _axv in url):
            soup = BS(urllib2.urlopen (url))
            trs = soup.findAll('tr')
            filter(lambda x: 'doi' in x.get_text().lower(), trs)
            tr = filter(lambda x: 'doi' in x.get_text().lower(), trs)[0]
            doi = tr.get_text()
            url = 'http://dx.doi.org/'
            url += re.sub('DOI:','',re.sub('\n','',doi))
        return url

    def process_row(row):
        cells = row.findAll('td')
        if len(cells)==5:
            # Object source name(s) (can be more then one comma separated)
            src = cells[0].find(text=True)
            src = src.strip()
            # Article reference (url), usually a ref to ads
            art = cells[1].find('a',href=True)
            aurl = art['href']
            durl = get_doi_url(aurl)
            # We skip year of publication (third column)
            # as well as bibcode reference (fourth column)
            #ref = cells[3].find(text=True).encode('utf8')
            # FITS file link for downloading it in the near future
            fits = cells[4]
            file = fits.find('a',href=True)
            try:
                file = file['href']
            except:
                file = None
            furl = url+file if file!=None else '_NULL_'
            return (src,durl,file)
        return None
    
    magic_table = {'SOURCE':[], 'DOI':[], 'FITS':[]}
    for row in table.findAll('tr'):
        vals = process_row(row)
        if vals is not None:
            src,durl,file = vals
            magic_table['SOURCE'].append(src)
            magic_table['DOI'].append(durl)
            magic_table['FITS'].append(file)
    return magic_table
    
table_pic_dict = get_table_fields(table_pic_html)

del table_pic_html
#tf = table_filtered
#for i in range(len(tf['source'])):
#    print("%s : %s : %s"%(tf['source'][i],tf['doi'][i],tf['fits'][i]))

# %%
def print_describe(table,include='all'):
    print table.describe(include=include)
    print "\n-> Has Nil?"
    hows_nil = table.isnull().any()
    print hows_nil
    for c in hows_nil.index:
        if not hows_nil[c]: continue
        print "\n-> Indexes where column '{}' is null:".format(c)
        print table[table[c].isnull()].index.values

# %%
import pandas as pd
table_pic = pd.DataFrame(table_pic_dict)

del table_pic_dict
print_describe(table_pic)
# Out:
#                                                    DOI  \
# count                                               99
# unique                                              99
# top     http://dx.doi.org/10.1088/0004-637X/705/2/1624
# freq                                                 1
#
#                                        FITS         SOURCE
# count                                    67             99
# unique                                   67             68
# top     mfits/base/MAGIC_2010_CygnusX3.fits  Markarian 421
# freq                                      1              6
#
# -> Has Nil?
# DOI       False
# FITS       True
# SOURCE    False
# dtype: bool
#
# -> Indexes where column 'FITS' is null:
# [ 0  2  4  5  6  7 12 17 18 28 29 33 34 35 36 37 41 42 43 49 50 53 57 67 73
#  83 84 88 90 93 96 98]

# %%
# Now we want to download the fits files
def download_fits(url,out):
    import wget
    filename = wget.download(url,out=out)
    return filename

def create_dir(dir):
    import os
    if not os.path.exists(dir):
        try:
            os.mkdir(dir)
        except:
            return False
    return True

def clean_dir(dir,ext="*"):
    import os
    from glob import glob
    create_dir(dir)
    if os.path.isdir(dir):
        files = glob(os.path.join(dir,ext))
        for f in files:
            os.remove(f)
        return True
    return False
    
def read_md5sum_file(md5txt='md5sum.txt'):
    md5_hashs,md5_files = [],[]
    with open(md5txt,'r') as mdf:
        for line in mdf.readline():
            _h,_f = line.split()
            md5_hashs.append(_h.strip())
            md5_files.append(_f.strip())
    md5 = dict(zip(md5_files,md5_hashs))
    return md5

def create_md5sum_file(files_list,md5txt='md5sum.txt',dir=None):
    import hashlib
    md5 = {}
    for f in files_list:
        fname = os.path.join(dir,f) if dir else f
        h = None
        with open(fname,'rb') as fp:
            h = hashlib.md5(fp.read()).hexdigest()
        md5.update({f:h})
    fname = os.path.join(dir,md5txt) if dir else md5txt
    with open(fname,'w') as fp:
        for file,hash in md5.iteritems():
            fp.write("%s    %s\n"%(hash,file))
    return md5

def read_dir_content(dir,ext='*.fits'):
    from glob import glob
    dir_files_list = glob(os.path.join(dir,ext))
    return [ os.path.basename(f) for f in dir_files_list ]

def is_exist_files(dir,files_list):
    import os
    # First we see if there is a file list (md5sum) to look for
    def check_md5sum(files_list,md5_file='md5sum.txt'):
        if os.path.isfile(md5_file):
            md5 = read_md5sum_file(md5_file)
            md5_files_list = md5.keys()
            leng_inters = len(set(md5_files_list).intersection(files_list))
            return leng_inters == len(files_list)
        # If there is *no* md5-file, return *None*
        return None
    # Also, check if the files are actually there (inside the dir)
    def check_glob(files_list,dir):
        files_ext = '*.fits'
        dir_files_list = read_dir_content(dir,files_ext)
        leng_matches = sum(map(lambda v: v in dir_files_list, files_list))
        return leng_matches == len(files_list)
    
    md5_file = 'md5sum.txt'
    md5_check = check_md5sum(files_list,md5_file)
    if md5_check in (True,False):
        return md5_check
    glob_check = check_glob(files_list,dir)
    if glob_check:
        create_md5sum_file(files_list,dir=dir)
    return glob_check


fits_download_dir = 'FITS_pic/'

FORCE_CLEAN = False
if FORCE_CLEAN:
    clean_dir(fits_download_dir)
else:
    create_dir(fits_download_dir)

import os
assert os.path.isdir(fits_download_dir),"FITS files dir do not exist!"

fits_files = table_pic.FITS.dropna().apply(os.path.basename)
if is_exist_files(fits_download_dir,fits_files):
    print("FITS files exist locally. Passing by download step..")
    fits_local = fits_files.apply(lambda f: os.path.join(fits_download_dir,f))
else:
    print("FITS files do not exist locally. Downloading them...")
    furls = url + table_pic.FITS.dropna()
    fits_local = furls.apply(lambda f: download_fits(f,fits_download_dir))
    md5s = create_md5sum_file(fits_files,dir=fits_download_dir)
    del furls

table_pic['FITS_local'] = fits_local

del fits_local,fits_files

print_describe(table_pic)
# Out:
# FITS files exist locally. Passing by download step..
#                                                    DOI  \
# count                                               99
# unique                                              99
# top     http://dx.doi.org/10.1088/0004-637X/705/2/1624
# freq                                                 1
#
#                                        FITS         SOURCE  \
# count                                    67             99
# unique                                   67             68
# top     mfits/base/MAGIC_2010_CygnusX3.fits  Markarian 421
# freq                                      1              6
#
#                                FITS_local
# count                                  67
# unique                                 67
# top     FITS_pic/MAGIC_2010_CygnusX3.fits
# freq                                    1
#
# -> Has Nil?
# DOI           False
# FITS           True
# SOURCE        False
# FITS_local     True
# dtype: bool
#
# -> Indexes where column 'FITS' is null:
# [ 0  2  4  5  6  7 12 17 18 28 29 33 34 35 36 37 41 42 43 49 50 53 57 67 73
#  83 84 88 90 93 96 98]
#
# -> Indexes where column 'FITS_local' is null:
# [ 0  2  4  5  6  7 12 17 18 28 29 33 34 35 36 37 41 42 43 49 50 53 57 67 73
#  83 84 88 90 93 96 98]

# %% [markdown]
# #### Header keywords
#  Primarily, regarding particularly MAGIC data, we should take a look at their [FITS format for MAGIC data](http://vobs.magic.pic.es/fits/mfits/tdas/tdas-fits.pdf) document, chapter 4. There we'll find the following list of keywords:
#
# __FITS standard__, _highlighted by MAGIC_:
#  * AUTHOR
#  * DATE
#  * DATE-OBS
#  * EXTNAME
#  * OBJECT
#  * ORIGIN
#  * TELESCOP
#
# __MAGIC__, _to describe extension content_:
#  * CONFLEVE
#  * EFFICIEN
#  * EMAX
#  * EMIN
#  * PERIOD
#  * PHIMAX
#  * PHIMIN
#  * REFPAPER
#  * SIZEMIN
#  * SIZEMAX
#  * TOBS
#  * ZMIN
#  * ZMAX
#  * TZERO
#  * VERSION
#
# __MAGIC__, _SPECTRUM extension_:
#  * ISINTEGR : 'F' means density flux; 'I' means integrated flux.
#
# On the other hand, there is the [FITS standard](http://heasarc.gsfc.nasa.gov/docs/fcg/standard_dict.html) and the [FITS commons](http://heasarc.gsfc.nasa.gov/docs/fcg/common_dict.html) set of keywords.
#
#
# ```
# This data dictionary lists the 53 keywords currently defined in the
# FITS Standard:
#
# (blank)  CROTAn   EQUINOX  NAXISn   TBCOLn   TUNITn
# AUTHOR   CRPIXn   EXTEND   OBJECT   TDIMn    TZEROn
# BITPIX   CRVALn   EXTLEVEL OBSERVER TDISPn   XTENSION
# BLANK    CTYPEn   EXTNAME  ORIGIN   TELESCOP
# BLOCKED  DATAMAX  EXTVER   PCOUNT   TFIELDS
# BSCALE   DATAMIN  GCOUNT   PSCALn   TFORMn
# BUNIT    DATE     GROUPS   PTYPEn   THEAP
# BZERO    DATE-OBS HISTORY  PZEROn   TNULLn
# CDELTn   END      INSTRUME REFERENC TSCALn
# COMMENT  EPOCH    NAXIS    SIMPLE   TTYPEn
# ```
#
# ```
#      Dictionary of Commonly Used FITS Keywords
#
# This data dictionary contains FITS keywords that have been widely used
# within the astronomical community.  It is recommended that these
# keywords only be used as defined here.  These keywords may be grouped
# within the following 7 broad categories:
#
# 1. Keywords that describe the data or the FITS file itself:
#
#     TITLE FILENAME FILETYPE ROOTNAME
#     PROGRAM CREATOR CONFIGUR
#     NEXTEND HDUNAME HDUVER HDULEVEL
#     TLMINn TLMAXn TDMINn TDMAXn TDBINn
#     TSORTKEY PROGRAM CREATOR CONFIGUR
#     HDUCLASS HDUDOC HDUVERS HDUCLASn
#
# 2.  Keywords that describe the observation:
#
#     SUNANGLE MOONANGL
#     RA DEC RA_NOM DEC_NOM
#     RA_OBJ DEC_OBJ RA_PNT DEC_PNT PA_PNT
#     RA_SCX DEC_SCX RA_SCY DEC_SXY RA_SCZ DEC_SCZ
#     ORIENTAT AIRMASS LATITUDE
#     OBJNAME OBS_ID
#
# 3.  Keywords that describe the instrument that took the data:
#
#     OBS_MODE DATAMODE
#     APERTURE DETNAM FILTER FILTERn GRATING GRATINGn
#     SATURATE
#
# 4.  Keywords that give the date or duration of the observation:
#
#     TIME-OBS TIME-END DATE-END
#     EXPOSURE EXPTIME TELAPSE ELAPTIME ONTIME LIVETIME
#
# 5.  Keywords that denote non-standard FITS keyword format conventions:
#
#     HIERARCH INHERIT CONTINUE
#
# 6.  File checksum keywords:
#
#     CHECKSUM DATASUM CHECKVER
#
# 7.  Hierarchical file grouping keywords:
#
#     GRPNAME GRPIDn GRPLCn
# ```
#
# ---
#
# #### Improvement
#
#  * Given all those lists of keywords, I will just add `RA` and `DEC`.

# %%
# The following keywords may not be seen in the Extended BinTableHDU header, but inside the PrimaryHDU' header.
# That's because the MAGIC data handling system decided to not repeat unnecessarily such data.
# See the 'General Keywords' section (4.1) of the document 'FITS Format for MAGIC data', version 0.2.
#
MAGIC_FITS_STANDARD_KEYWORDS = [
    'AUTHOR',
    'DATE',
    'DATE-OBS',
    'EXTNAME',
    'OBJECT',
    'ORIGIN',
    'TELESCOP']
MAGIC_FITS_EXTENSION_KEYWORDS = [
    'CONFLEVE',
    'EFFICIEN',
    'EMAX',
    'EMIN',
    'PERIOD',
    'PHIMAX',
    'PHIMIN',
    'REFPAPER',
    'SIZEMIN',
    'SIZEMAX',
    'TOBS',
    'ZMIN',
    'ZMAX',
    'TZERO',
    'VERSION']
# These keywords will be used to update the SPECTRUM extensions with *all* of them
FITS_KEYWORDS = MAGIC_FITS_STANDARD_KEYWORDS + MAGIC_FITS_EXTENSION_KEYWORDS

# %%
# Now we can process the fits files themselves.
# He start noting that we want the SPECTRUM Data Unit(s)
#  available (or not) in the fits files; discard the other DU.
# Things we want to do:
# - get the OBJECT name
# - get the each object position
# - get the observation date
# - transform the data vectors (x) to frequency(Hz) and (y) to flux(erg/s/cm2)
# Then we should follow the following workflow:
# - open the fits file
# - find the necessary data unit (SPECTRUM)
# - open its header
#  - get some keywords from the header
# - open its data; data here are vectors
#  - it can be from 2 to 4 vectors
#   - energy
#   - flux
#   - Denergy
#   - Dflux
#  - convert the ?energy vectors to 'Hz' units
#  - convert the ?flux vectors to 'erg/s/cm2' units

# Here we just define the functions we'll need..

def read_file(filename):
    from astropy.io import fits
    try:
        hdulist = fits.open(filename)
    except:
        hdulist = None
    return hdulist
    
def select_dataUnits(hdulist,du_name='SPECTRUM'):
    dui = [ i for i,du in enumerate(hdulist) if du_name in du.name ]
    dus = [ hdulist[ii] for ii in dui ]
    _du = filter(lambda x:du_name in x.name, hdulist)
    assert dus == _du
    return (dus,dui)
    
def read_header(spec,table):
    assert isinstance(table,dict)
    def read_keyword(header,table,word):
        table[word] = header.get(word, None)
    header = spec.header
    read_keyword(header,table, 'EXTNAME')
    read_keyword(header,table, 'OBJECT')
    read_keyword(header,table, 'DATE-OBS')
    read_keyword(header,table, 'SRCPOS1')
    read_keyword(header,table, 'SRCPOS2')

def attempt_fix_objectname(header):
    assert header['OBJECT'] is None
    import re
    _fn = header['FILENAME'][:-5]
    objname = re.sub('.*/MAGIC_20[0-9][0-9]_','',_fn)
    table['OBJECT'] = objname
    print '*** OBJECT name got from file name.'


def resolve_name(name):
    from astropy.coordinates import get_icrs_coordinates as get_coords
    try:
        icrs = get_coords(name)
        pos = (icrs.ra.value,icrs.dec.value)
    except:
        pos = None
    return pos

def read_data(spec,table):
    assert isinstance(table,dict)
    cols = zip(spec.columns.names,spec.columns.units)
    for n in ['energy','Denergy','flux','Dflux']:
        table[n+'_unit'] = None
        table[n] = None
    for n,u in cols:
        if (n == 'energy' or n == 'Denergy' or n == 'flux' or n == 'Dflux'):
            table[n+'_unit'] = u
            table[n] = spec.data[n]
        else:
            print "Different field:",n

def transf_data(table):
    from astropy import units
    Unit = units.Unit
    import numpy as np
    units.set_enabled_equivalencies(units.spectral())
    uEn = Unit('Hz')
    uFn = Unit('erg s-1 cm-2')
    uEc = Unit('TeV')
    conv = {Unit('ph TeV s-1 cm-2') : lambda x,y: (x/Unit('ph')).to(uFn),
            Unit('ph TeV-1 s-1 cm-2') : lambda x,y: ((y.to(uEc)**2)*(x/Unit('ph'))).to(uFn),
            Unit('ph s-1 cm-2') : lambda x,y: None,
            Unit('GeV') : lambda x: x.to(uEn, equivalencies=units.spectral())}

    vE = table['energy']
    uE = vE.unit
    vEn = conv[uE](vE)

    vF = table['flux']
    uF = vF.unit
    vFn = conv[uF](vF,vE)

    if vFn is None:
        print "vFn is None!?!:",str(uF)
        return False
    
    table['energy'] = vEn
    table['energy'].unit = vEn.unit
    table['flux'] = vFn
    table['flux'].unit = vFn.unit

    if 'Denergy' in table.colnames:
        vDE = table['Denergy']
        uDE = vDE.unit
        vDEn = conv[uDE](vDE)
        table['Denergy'] = vDEn
        table['Denergy'].unit = vDEn.unit
    else:
        uDE = Unit('')
        nullval = -999
        vDEn = np.asarray([nullval]*len(vE),dtype=int)
        table['Denergy'] = vDEn
        table['Denergy'].unit = uDE
        table['Denergy'].null = nullval

    if 'Dflux' in table.colnames:
        vDF = table['Dflux']
        uDF = vDF.unit
        vDFn = conv[uDF](vDF,vE) # Notice we use the energy bin/value of the measurement.
        table['Dflux'] = vDFn
        table['Dflux'].unit = vDFn.unit
    else:
        uDF = Unit('')
        nullval = -999
        vDFn = np.asarray([nullval]*len(vE),dtype=int)
        table['Dflux'] = vDFn
        table['Denergy'].unit = uDF
        table['Denergy'].null = nullval
    return True

def merge_header_keywords(header_p,header_s):
    # Extension's header has the highest priority; keywords there
    # should not be overwritten. Relevant keywords are the ones in:
    # 'FITS_KEYWORDS'
    f_header = {'COMMENT':[]}
    _kw = list(set(header_p.keys()).intersection(FITS_KEYWORDS))
    for k in _kw:
        f_header.update({k : header_p[k]})
    if 'COMMENT' in header_p.keys():
        f_header['COMMENT'].extend(header_p['COMMENT'])
    _kw = list(set(header_s.keys()).intersection(FITS_KEYWORDS))
    for k in _kw:
        f_header.update({k : header_s[k]})
    if 'COMMENT' in header_s.keys():
        f_header['COMMENT'].extend(header_s['COMMENT'])
    return f_header
    
def proc_fits_file(fn,source):
    out = []
    print "----------------------------------------------------------------------"
    print "\nProcessing file:",fn,

    hdulist = read_file(fn)
    if hdulist is None:
        print " ..failed: to open." 
        return None
    
    spectra,spec_du_i = select_dataUnits(hdulist)
    if not len(spec_du_i):
        print " ..failed: no SPECTRUM" 
        return None
    
    # First of all, let me see the contents of the first header
    phdu_header = hdulist[0].header
    print('PrimaryHDU header:')
    for key,value in phdu_header.items():
        print('{0} = {1}'.format(key, value))
    print("")

    for i,i_du in enumerate(spec_du_i):
        
        # Read the extension directly into an astropy.table
        from astropy.table import Table
        
        table = Table.read(fn,hdu=i_du)
        #print('Extension table metadata:')
        #for key, value in table.meta.items():
        #    print('{0} = {1}'.format(key, value))
        #print("")

        spec = hdulist[i_du]
        #print('Extension SPECTRUM header:')
        #for key,value in spec.header.items():
        #    print('{0} = {1}'.format(key, value))
        #print("")
        
        header_new = merge_header_keywords(phdu_header,table.meta)
        #print('New header dictionary:')
        #for key,value in header_new.items():
        #    print('{0} = {1}'.format(key, value))
        #print("")
        
        if not 'OBJECT' in header_new.keys():
            print("No 'OBJECT defined for this table. Passing by...")
            continue
            
        if ('SRCPOS1' in table.meta.keys()) and ('SRCPOS2' in table.meta.keys()):
            pos = table.meta['SRCPOS1'],table.meta['SRCPOS2']
        elif ('SRCPOS1' in phdu_header.keys()) and ('SRCPOS2' in phdu_header.keys()):
            pos = phdu_header['SRCPOS1'],phdu_header['SRCPOS2']
        else:
            pos = resolve_name(header_new['OBJECT'])
        if pos is None:
            pos = resolve_name(source)
            if pos is None:
                pos = (None,None)
            else:
                header_new['OBJECT'] = source
                print '*** NOP, No good either! Using PIC source.',source

        header_new['RA'],header_new['DEC'] = pos
        #for key,value in header_new.items():
        #    print('{0} = {1}'.format(key, value))
        #print("")
        
        table.meta.update(header_new)
    
        ret = transf_data(table)
        if ret is not True:
            continue
        out.append(table.copy())
    return out

#for i in range(len(table_pic)):
#    specs_list = proc_fits_file(table_pic.FITS_local[i],table_pic.SOURCE[i])
#assert False

# %%
table_pic['SPECTRUM'] = table_pic.apply(lambda x: proc_fits_file(x.FITS_local,x.SOURCE), axis=1)
# Out:
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2015_CrabNebula.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2015-07-16T13:08:09
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# VERSION = 0.1
# OBJECT = Crab Nebula
# TELESCOP = MAGIC-Stereo
# DATE-OBS = 2009-10
# TOBS = 69.0
# REFPAPER = 2014arXiv1406.6892M
# COMMENT = This is a MAGIC fits file containing the results of the observations of
# COMMENT = Crab Nebula -measurements over 3 decades; data from Oct 2009 to April 20
# COMMENT = 11-.  Please consider it as VERY PRELIMINAR
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2009-10
# TOBS = 69.0
# EMIN = 50.0
# EMAX = 30000.0
# COMMENT = ['Spectral energy distribution measured from 69hr of Crab Nebula observati', 'ons taken between Oct 2009 and April 2011, from 50 GeV to 30 TeV']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 14
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2009-10
# TOBS = 69.0
# EMIN = 50.0
# EMAX = 30000.0
# COMMENT = Spectral energy distribution measured from 69hr of Crab Nebula observati
# COMMENT = ons taken between Oct 2009 and April 2011, from 50 GeV to 30 TeV
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the results of the observations of', 'Crab Nebula -measurements over 3 decades; data from Oct 2009 to April 20', '11-.  Please consider it as VERY PRELIMINAR', 'Spectral energy distribution measured from 69hr of Crab Nebula observati', 'ons taken between Oct 2009 and April 2011, from 50 GeV to 30 TeV']
# ORIGIN = MAGIC
# OBJECT = Crab Nebula
# TOBS = 69.0
# AUTHOR = MAGIC Coll.
# EMAX = 30000.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = 2014arXiv1406.6892M
# EXTNAME = SPECTRUM
# DATE-OBS = 2009-10
# VERSION = 0.1
# EMIN = 50.0
# DATE = 2015-07-16T13:08:09
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the results of the observations of', 'Crab Nebula -measurements over 3 decades; data from Oct 2009 to April 20', '11-.  Please consider it as VERY PRELIMINAR', 'Spectral energy distribution measured from 69hr of Crab Nebula observati', 'ons taken between Oct 2009 and April 2011, from 50 GeV to 30 TeV']
# ORIGIN = MAGIC
# OBJECT = Crab Nebula
# TOBS = 69.0
# AUTHOR = MAGIC Coll.
# EMAX = 30000.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = 2014arXiv1406.6892M
# EXTNAME = SPECTRUM
# DATE-OBS = 2009-10
# VERSION = 0.1
# RA = 83.633083
# EMIN = 50.0
# DATE = 2015-07-16T13:08:09
# DEC = 22.0145
#
# Extension table metadata:
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# DATE-OBS = 2009-10
# TOBS = 69.0
# EMIN = 50.0
# EMAX = 30000.0
# COMMENT = ['Differential energy spectrum of the Crab Nebula obtained from 69hr taken', ' between Oct 2009 and April 2011, from 50 GeV to 30 TeV']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 14
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# DATE-OBS = 2009-10
# TOBS = 69.0
# EMIN = 50.0
# EMAX = 30000.0
# COMMENT = Differential energy spectrum of the Crab Nebula obtained from 69hr taken
# COMMENT =  between Oct 2009 and April 2011, from 50 GeV to 30 TeV
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the results of the observations of', 'Crab Nebula -measurements over 3 decades; data from Oct 2009 to April 20', '11-.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum of the Crab Nebula obtained from 69hr taken', ' between Oct 2009 and April 2011, from 50 GeV to 30 TeV']
# ORIGIN = MAGIC
# OBJECT = Crab Nebula
# TOBS = 69.0
# AUTHOR = MAGIC Coll.
# EMAX = 30000.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = 2014arXiv1406.6892M
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2009-10
# VERSION = 0.1
# EMIN = 50.0
# DATE = 2015-07-16T13:08:09
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the results of the observations of', 'Crab Nebula -measurements over 3 decades; data from Oct 2009 to April 20', '11-.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum of the Crab Nebula obtained from 69hr taken', ' between Oct 2009 and April 2011, from 50 GeV to 30 TeV']
# ORIGIN = MAGIC
# OBJECT = Crab Nebula
# TOBS = 69.0
# AUTHOR = MAGIC Coll.
# EMAX = 30000.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = 2014arXiv1406.6892M
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2009-10
# VERSION = 0.1
# RA = 83.633083
# EMIN = 50.0
# DATE = 2015-07-16T13:08:09
# DEC = 22.0145
#
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2015_1ES0806.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2015-07-14T13:37:35
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# VERSION = 0.1
# OBJECT = 1ES 0806+524
# TELESCOP = MAGIC-Stereo
# DATE-OBS = 2011-01
# TOBS = 16.1
# ZMIN = 23.0
# ZMAX = 46.0
# REFPAPER = J. Aleksic et al., MNRAS 451,5258-5269 (2015)
# COMMENT = This is a MAGIC fits file containing the result of the observations of 1
# COMMENT = ES 0806+524.  Please consider it as VERY PRELIMINAR
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2011-01
# TOBS = 16.1
# COMMENT = ['Observed differential energy spectrum from 16.1 h of 1ES 0806+524 observ', 'ations during high-state']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 5
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2011-01
# TOBS = 16.1
# COMMENT = Observed differential energy spectrum from 16.1 h of 1ES 0806+524 observ
# COMMENT = ations during high-state
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 1', 'ES 0806+524.  Please consider it as VERY PRELIMINAR', 'Observed differential energy spectrum from 16.1 h of 1ES 0806+524 observ', 'ations during high-state']
# ORIGIN = MAGIC
# OBJECT = 1ES 0806+524
# ZMAX = 46.0
# TOBS = 16.1
# AUTHOR = MAGIC Coll.
# ZMIN = 23.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., MNRAS 451,5258-5269 (2015)
# EXTNAME = SPECTRUM
# DATE-OBS = 2011-01
# VERSION = 0.1
# DATE = 2015-07-14T13:37:35
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 1', 'ES 0806+524.  Please consider it as VERY PRELIMINAR', 'Observed differential energy spectrum from 16.1 h of 1ES 0806+524 observ', 'ations during high-state']
# ORIGIN = MAGIC
# OBJECT = 1ES 0806+524
# ZMAX = 46.0
# TOBS = 16.1
# AUTHOR = MAGIC Coll.
# ZMIN = 23.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., MNRAS 451,5258-5269 (2015)
# EXTNAME = SPECTRUM
# DATE-OBS = 2011-01
# VERSION = 0.1
# RA = 122.454944708
# DATE = 2015-07-14T13:37:35
# DEC = 52.31618075
#
# Extension table metadata:
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# DATE-OBS = 2011-01
# TOBS = 16.1
# COMMENT = ['Deabsorbed differential energy spectrum from 16.1 h of 1ES 0806+524 obse', 'rvations during high-state']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 5
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# DATE-OBS = 2011-01
# TOBS = 16.1
# COMMENT = Deabsorbed differential energy spectrum from 16.1 h of 1ES 0806+524 obse
# COMMENT = rvations during high-state
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 1', 'ES 0806+524.  Please consider it as VERY PRELIMINAR', 'Deabsorbed differential energy spectrum from 16.1 h of 1ES 0806+524 obse', 'rvations during high-state']
# ORIGIN = MAGIC
# OBJECT = 1ES 0806+524
# ZMAX = 46.0
# TOBS = 16.1
# AUTHOR = MAGIC Coll.
# ZMIN = 23.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., MNRAS 451,5258-5269 (2015)
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2011-01
# VERSION = 0.1
# DATE = 2015-07-14T13:37:35
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 1', 'ES 0806+524.  Please consider it as VERY PRELIMINAR', 'Deabsorbed differential energy spectrum from 16.1 h of 1ES 0806+524 obse', 'rvations during high-state']
# ORIGIN = MAGIC
# OBJECT = 1ES 0806+524
# ZMAX = 46.0
# TOBS = 16.1
# AUTHOR = MAGIC Coll.
# ZMIN = 23.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., MNRAS 451,5258-5269 (2015)
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2011-01
# VERSION = 0.1
# RA = 122.454944708
# DATE = 2015-07-14T13:37:35
# DEC = 52.31618075
#
# Extension table metadata:
# EXTNAME = SPECTRUM_2
# ISINTEGR = F
# DATE-OBS = 2011-01
# TOBS = 16.1
# COMMENT = ['Observed differential energy spectrum from 16.1 h of 1ES 0806+524 observ', 'ations during low-state']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 5
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_2
# ISINTEGR = F
# DATE-OBS = 2011-01
# TOBS = 16.1
# COMMENT = Observed differential energy spectrum from 16.1 h of 1ES 0806+524 observ
# COMMENT = ations during low-state
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 1', 'ES 0806+524.  Please consider it as VERY PRELIMINAR', 'Observed differential energy spectrum from 16.1 h of 1ES 0806+524 observ', 'ations during low-state']
# ORIGIN = MAGIC
# OBJECT = 1ES 0806+524
# ZMAX = 46.0
# TOBS = 16.1
# AUTHOR = MAGIC Coll.
# ZMIN = 23.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., MNRAS 451,5258-5269 (2015)
# EXTNAME = SPECTRUM_2
# DATE-OBS = 2011-01
# VERSION = 0.1
# DATE = 2015-07-14T13:37:35
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 1', 'ES 0806+524.  Please consider it as VERY PRELIMINAR', 'Observed differential energy spectrum from 16.1 h of 1ES 0806+524 observ', 'ations during low-state']
# ORIGIN = MAGIC
# OBJECT = 1ES 0806+524
# ZMAX = 46.0
# TOBS = 16.1
# AUTHOR = MAGIC Coll.
# ZMIN = 23.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., MNRAS 451,5258-5269 (2015)
# EXTNAME = SPECTRUM_2
# DATE-OBS = 2011-01
# VERSION = 0.1
# RA = 122.454944708
# DATE = 2015-07-14T13:37:35
# DEC = 52.31618075
#
# Extension table metadata:
# EXTNAME = SPECTRUM_3
# ISINTEGR = F
# DATE-OBS = 2011-01
# TOBS = 16.1
# COMMENT = ['Deabsorbed differential energy spectrum from 16.1 h of 1ES 0806+524 obse', 'rvations during low-state']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 5
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_3
# ISINTEGR = F
# DATE-OBS = 2011-01
# TOBS = 16.1
# COMMENT = Deabsorbed differential energy spectrum from 16.1 h of 1ES 0806+524 obse
# COMMENT = rvations during low-state
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 1', 'ES 0806+524.  Please consider it as VERY PRELIMINAR', 'Deabsorbed differential energy spectrum from 16.1 h of 1ES 0806+524 obse', 'rvations during low-state']
# ORIGIN = MAGIC
# OBJECT = 1ES 0806+524
# ZMAX = 46.0
# TOBS = 16.1
# AUTHOR = MAGIC Coll.
# ZMIN = 23.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., MNRAS 451,5258-5269 (2015)
# EXTNAME = SPECTRUM_3
# DATE-OBS = 2011-01
# VERSION = 0.1
# DATE = 2015-07-14T13:37:35
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 1', 'ES 0806+524.  Please consider it as VERY PRELIMINAR', 'Deabsorbed differential energy spectrum from 16.1 h of 1ES 0806+524 obse', 'rvations during low-state']
# ORIGIN = MAGIC
# OBJECT = 1ES 0806+524
# ZMAX = 46.0
# TOBS = 16.1
# AUTHOR = MAGIC Coll.
# ZMIN = 23.0
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., MNRAS 451,5258-5269 (2015)
# EXTNAME = SPECTRUM_3
# DATE-OBS = 2011-01
# VERSION = 0.1
# RA = 122.454944708
# DATE = 2015-07-14T13:37:35
# DEC = 52.31618075
#
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2014_Ic310.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2014-11-18T15:47:29
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# VERSION = 0.1
# OBJECT = IC 310
# TELESCOP = MAGIC-Stereo
# DATE-OBS = 2012-11-13
# TOBS = 3.7
# REFPAPER = DOI:10.1126/science.1256183
# COMMENT = This is a MAGIC fits file containing the result of the observations of I
# COMMENT = C 310 -flare of the night Nov 12/13, 2012-.  Please consider it as VERY
# COMMENT = PRELIMINAR
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2012-11-13
# TOBS = 3.7
# COMMENT = ['Average spectral energy distribution measured from 3.7 h of IC 310 obser', 'vations for the night of November 12/13, 2012 from 70GeV to 8.3TeV']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 10
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2012-11-13
# TOBS = 3.7
# COMMENT = Average spectral energy distribution measured from 3.7 h of IC 310 obser
# COMMENT = vations for the night of November 12/13, 2012 from 70GeV to 8.3TeV
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of I', 'C 310 -flare of the night Nov 12/13, 2012-.  Please consider it as VERY', 'PRELIMINAR', 'Average spectral energy distribution measured from 3.7 h of IC 310 obser', 'vations for the night of November 12/13, 2012 from 70GeV to 8.3TeV']
# ORIGIN = MAGIC
# OBJECT = IC 310
# TOBS = 3.7
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-Stereo
# REFPAPER = DOI:10.1126/science.1256183
# EXTNAME = SPECTRUM
# DATE-OBS = 2012-11-13
# VERSION = 0.1
# DATE = 2014-11-18T15:47:29
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of I', 'C 310 -flare of the night Nov 12/13, 2012-.  Please consider it as VERY', 'PRELIMINAR', 'Average spectral energy distribution measured from 3.7 h of IC 310 obser', 'vations for the night of November 12/13, 2012 from 70GeV to 8.3TeV']
# ORIGIN = MAGIC
# OBJECT = IC 310
# TOBS = 3.7
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-Stereo
# REFPAPER = DOI:10.1126/science.1256183
# EXTNAME = SPECTRUM
# DATE-OBS = 2012-11-13
# VERSION = 0.1
# RA = 49.1792708
# DATE = 2014-11-18T15:47:29
# DEC = 41.3247667
#
# Extension table metadata:
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# DATE-OBS = 2012-11-13
# TOBS = 3.7
# COMMENT = ['Average spectral energy distribution corrected fot EBL absorption from 3', '.7 h of IC 310 observations for the night of November 12/13, 2012']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 10
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# DATE-OBS = 2012-11-13
# TOBS = 3.7
# COMMENT = Average spectral energy distribution corrected fot EBL absorption from 3
# COMMENT = .7 h of IC 310 observations for the night of November 12/13, 2012
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of I', 'C 310 -flare of the night Nov 12/13, 2012-.  Please consider it as VERY', 'PRELIMINAR', 'Average spectral energy distribution corrected fot EBL absorption from 3', '.7 h of IC 310 observations for the night of November 12/13, 2012']
# ORIGIN = MAGIC
# OBJECT = IC 310
# TOBS = 3.7
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-Stereo
# REFPAPER = DOI:10.1126/science.1256183
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2012-11-13
# VERSION = 0.1
# DATE = 2014-11-18T15:47:29
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of I', 'C 310 -flare of the night Nov 12/13, 2012-.  Please consider it as VERY', 'PRELIMINAR', 'Average spectral energy distribution corrected fot EBL absorption from 3', '.7 h of IC 310 observations for the night of November 12/13, 2012']
# ORIGIN = MAGIC
# OBJECT = IC 310
# TOBS = 3.7
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-Stereo
# REFPAPER = DOI:10.1126/science.1256183
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2012-11-13
# VERSION = 0.1
# RA = 49.1792708
# DATE = 2014-11-18T15:47:29
# DEC = 41.3247667
#
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2014_PKS1424+240.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2014-07-18T16:58:40
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# VERSION = 0.1
# OBJECT = PKS 1424+240
# TOBS = 33.6
# ZMIN = 4.0
# ZMAX = 36.0
# COMMENT = PKS 1424+240 observational campaign with MAGIC can be split in three sam
# COMMENT = ples:
# COMMENT = Sample 1:  April 2009 - Jun 2009, EOT = 12.5 h, MAGIC I
# COMMENT = Sample 2: Mar 2010 - Apr 2010, EOT = 11.6 h, MAGIC SYSTEM
# COMMENT = Sample 3: Apr 2011 - May 2011, EOT = 9.5 h, MAGIC SYSTEM
# REFPAPER = (2014arXiv1401.0464M)
# COMMENT = This is a MAGIC fits file containing the result of the observations of P
# COMMENT = KS 1424+240.  Please consider it as VERY PRELIMINAR
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2009-10
# TOBS = 12.5
# EMIN = 150.0
# COMMENT = ['Differential energy spectrum above 150 GeV from 12.5 h of PKS 1424+240 o', 'bservations during the first campaing (Apr 2009-Jun 2009)']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 4
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2009-10
# TOBS = 12.5
# EMIN = 150.0
# COMMENT = Differential energy spectrum above 150 GeV from 12.5 h of PKS 1424+240 o
# COMMENT = bservations during the first campaing (Apr 2009-Jun 2009)
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'PKS 1424+240 observational campaign with MAGIC can be split in three sam', 'ples:', 'Sample 1:  April 2009 - Jun 2009, EOT = 12.5 h, MAGIC I', 'Sample 2: Mar 2010 - Apr 2010, EOT = 11.6 h, MAGIC SYSTEM', 'Sample 3: Apr 2011 - May 2011, EOT = 9.5 h, MAGIC SYSTEM', 'This is a MAGIC fits file containing the result of the observations of P', 'KS 1424+240.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum above 150 GeV from 12.5 h of PKS 1424+240 o', 'bservations during the first campaing (Apr 2009-Jun 2009)']
# ORIGIN = MAGIC
# ZMAX = 36.0
# TOBS = 12.5
# AUTHOR = MAGIC Coll.
# ZMIN = 4.0
# OBJECT = PKS 1424+240
# REFPAPER = (2014arXiv1401.0464M)
# EXTNAME = SPECTRUM
# DATE-OBS = 2009-10
# VERSION = 0.1
# EMIN = 150.0
# DATE = 2014-07-18T16:58:40
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'PKS 1424+240 observational campaign with MAGIC can be split in three sam', 'ples:', 'Sample 1:  April 2009 - Jun 2009, EOT = 12.5 h, MAGIC I', 'Sample 2: Mar 2010 - Apr 2010, EOT = 11.6 h, MAGIC SYSTEM', 'Sample 3: Apr 2011 - May 2011, EOT = 9.5 h, MAGIC SYSTEM', 'This is a MAGIC fits file containing the result of the observations of P', 'KS 1424+240.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum above 150 GeV from 12.5 h of PKS 1424+240 o', 'bservations during the first campaing (Apr 2009-Jun 2009)']
# ORIGIN = MAGIC
# ZMAX = 36.0
# TOBS = 12.5
# AUTHOR = MAGIC Coll.
# ZMIN = 4.0
# OBJECT = PKS 1424+240
# REFPAPER = (2014arXiv1401.0464M)
# EXTNAME = SPECTRUM
# DATE-OBS = 2009-10
# VERSION = 0.1
# RA = 216.751632458
# EMIN = 150.0
# DATE = 2014-07-18T16:58:40
# DEC = 23.800010444
#
# Extension table metadata:
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# DATE-OBS = 2010-08
# TOBS = 11.6
# EMIN = 150.0
# COMMENT = ['Differential energy spectrum above 150GeV from 11.6 h of PKS 1424+240 ob', 'servations during the second campaing (Mar 2010-Apr 2010)']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 3
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# DATE-OBS = 2010-08
# TOBS = 11.6
# EMIN = 150.0
# COMMENT = Differential energy spectrum above 150GeV from 11.6 h of PKS 1424+240 ob
# COMMENT = servations during the second campaing (Mar 2010-Apr 2010)
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'PKS 1424+240 observational campaign with MAGIC can be split in three sam', 'ples:', 'Sample 1:  April 2009 - Jun 2009, EOT = 12.5 h, MAGIC I', 'Sample 2: Mar 2010 - Apr 2010, EOT = 11.6 h, MAGIC SYSTEM', 'Sample 3: Apr 2011 - May 2011, EOT = 9.5 h, MAGIC SYSTEM', 'This is a MAGIC fits file containing the result of the observations of P', 'KS 1424+240.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum above 150GeV from 11.6 h of PKS 1424+240 ob', 'servations during the second campaing (Mar 2010-Apr 2010)']
# ORIGIN = MAGIC
# ZMAX = 36.0
# TOBS = 11.6
# AUTHOR = MAGIC Coll.
# ZMIN = 4.0
# OBJECT = PKS 1424+240
# REFPAPER = (2014arXiv1401.0464M)
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2010-08
# VERSION = 0.1
# EMIN = 150.0
# DATE = 2014-07-18T16:58:40
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'PKS 1424+240 observational campaign with MAGIC can be split in three sam', 'ples:', 'Sample 1:  April 2009 - Jun 2009, EOT = 12.5 h, MAGIC I', 'Sample 2: Mar 2010 - Apr 2010, EOT = 11.6 h, MAGIC SYSTEM', 'Sample 3: Apr 2011 - May 2011, EOT = 9.5 h, MAGIC SYSTEM', 'This is a MAGIC fits file containing the result of the observations of P', 'KS 1424+240.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum above 150GeV from 11.6 h of PKS 1424+240 ob', 'servations during the second campaing (Mar 2010-Apr 2010)']
# ORIGIN = MAGIC
# ZMAX = 36.0
# TOBS = 11.6
# AUTHOR = MAGIC Coll.
# ZMIN = 4.0
# OBJECT = PKS 1424+240
# REFPAPER = (2014arXiv1401.0464M)
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2010-08
# VERSION = 0.1
# RA = 216.751632458
# EMIN = 150.0
# DATE = 2014-07-18T16:58:40
# DEC = 23.800010444
#
# Extension table metadata:
# EXTNAME = SPECTRUM_2
# ISINTEGR = F
# DATE-OBS = 2010-08
# TOBS = 9.5
# EMIN = 150.0
# COMMENT = ['Differential energy spectrum above 150GeV from 9.5 h of PKS 1424+240 obs', 'ervations during the third campaing (Apr 2011-May 2011)']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 5
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_2
# ISINTEGR = F
# DATE-OBS = 2010-08
# TOBS = 9.5
# EMIN = 150.0
# COMMENT = Differential energy spectrum above 150GeV from 9.5 h of PKS 1424+240 obs
# COMMENT = ervations during the third campaing (Apr 2011-May 2011)
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'PKS 1424+240 observational campaign with MAGIC can be split in three sam', 'ples:', 'Sample 1:  April 2009 - Jun 2009, EOT = 12.5 h, MAGIC I', 'Sample 2: Mar 2010 - Apr 2010, EOT = 11.6 h, MAGIC SYSTEM', 'Sample 3: Apr 2011 - May 2011, EOT = 9.5 h, MAGIC SYSTEM', 'This is a MAGIC fits file containing the result of the observations of P', 'KS 1424+240.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum above 150GeV from 9.5 h of PKS 1424+240 obs', 'ervations during the third campaing (Apr 2011-May 2011)']
# ORIGIN = MAGIC
# ZMAX = 36.0
# TOBS = 9.5
# AUTHOR = MAGIC Coll.
# ZMIN = 4.0
# OBJECT = PKS 1424+240
# REFPAPER = (2014arXiv1401.0464M)
# EXTNAME = SPECTRUM_2
# DATE-OBS = 2010-08
# VERSION = 0.1
# EMIN = 150.0
# DATE = 2014-07-18T16:58:40
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'PKS 1424+240 observational campaign with MAGIC can be split in three sam', 'ples:', 'Sample 1:  April 2009 - Jun 2009, EOT = 12.5 h, MAGIC I', 'Sample 2: Mar 2010 - Apr 2010, EOT = 11.6 h, MAGIC SYSTEM', 'Sample 3: Apr 2011 - May 2011, EOT = 9.5 h, MAGIC SYSTEM', 'This is a MAGIC fits file containing the result of the observations of P', 'KS 1424+240.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum above 150GeV from 9.5 h of PKS 1424+240 obs', 'ervations during the third campaing (Apr 2011-May 2011)']
# ORIGIN = MAGIC
# ZMAX = 36.0
# TOBS = 9.5
# AUTHOR = MAGIC Coll.
# ZMIN = 4.0
# OBJECT = PKS 1424+240
# REFPAPER = (2014arXiv1401.0464M)
# EXTNAME = SPECTRUM_2
# DATE-OBS = 2010-08
# VERSION = 0.1
# RA = 216.751632458
# EMIN = 150.0
# DATE = 2014-07-18T16:58:40
# DEC = 23.800010444
#
# Extension table metadata:
# EXTNAME = SPECTRUM_3
# ISINTEGR = F
# DATE-OBS = 2010-08
# TOBS = 9.5
# EMIN = 150.0
# COMMENT = ['Differential upper limits above 150GeV from 9.5 h of PKS 1424+240 observ', 'ations during the third campaing (Apr 2011-May 2011)']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 16
# NAXIS2 = 1
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 2
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_3
# ISINTEGR = F
# DATE-OBS = 2010-08
# TOBS = 9.5
# EMIN = 150.0
# COMMENT = Differential upper limits above 150GeV from 9.5 h of PKS 1424+240 observ
# COMMENT = ations during the third campaing (Apr 2011-May 2011)
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'PKS 1424+240 observational campaign with MAGIC can be split in three sam', 'ples:', 'Sample 1:  April 2009 - Jun 2009, EOT = 12.5 h, MAGIC I', 'Sample 2: Mar 2010 - Apr 2010, EOT = 11.6 h, MAGIC SYSTEM', 'Sample 3: Apr 2011 - May 2011, EOT = 9.5 h, MAGIC SYSTEM', 'This is a MAGIC fits file containing the result of the observations of P', 'KS 1424+240.  Please consider it as VERY PRELIMINAR', 'Differential upper limits above 150GeV from 9.5 h of PKS 1424+240 observ', 'ations during the third campaing (Apr 2011-May 2011)']
# ORIGIN = MAGIC
# ZMAX = 36.0
# TOBS = 9.5
# AUTHOR = MAGIC Coll.
# ZMIN = 4.0
# OBJECT = PKS 1424+240
# REFPAPER = (2014arXiv1401.0464M)
# EXTNAME = SPECTRUM_3
# DATE-OBS = 2010-08
# VERSION = 0.1
# EMIN = 150.0
# DATE = 2014-07-18T16:58:40
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'PKS 1424+240 observational campaign with MAGIC can be split in three sam', 'ples:', 'Sample 1:  April 2009 - Jun 2009, EOT = 12.5 h, MAGIC I', 'Sample 2: Mar 2010 - Apr 2010, EOT = 11.6 h, MAGIC SYSTEM', 'Sample 3: Apr 2011 - May 2011, EOT = 9.5 h, MAGIC SYSTEM', 'This is a MAGIC fits file containing the result of the observations of P', 'KS 1424+240.  Please consider it as VERY PRELIMINAR', 'Differential upper limits above 150GeV from 9.5 h of PKS 1424+240 observ', 'ations during the third campaing (Apr 2011-May 2011)']
# ORIGIN = MAGIC
# ZMAX = 36.0
# TOBS = 9.5
# AUTHOR = MAGIC Coll.
# ZMIN = 4.0
# OBJECT = PKS 1424+240
# REFPAPER = (2014arXiv1401.0464M)
# EXTNAME = SPECTRUM_3
# DATE-OBS = 2010-08
# VERSION = 0.1
# RA = 216.751632458
# EMIN = 150.0
# DATE = 2014-07-18T16:58:40
# DEC = 23.800010444
#
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2014_3C58.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2014-07-25T11:04:14
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# VERSION = 0.1
# OBJECT = 3C58
# TELESCOP = MAGIC-SYSTEM
# DATE-OBS = 2013-08-04
# TOBS = 81.0
# ZMIN = 36.0
# ZMAX = 52.0
# REFPAPER = J. Aleksic et al., A&A 567 (2013) L8
# COMMENT = This is a MAGIC fits file containing the result of the observations of 3
# COMMENT = C58.  Please conside it as VERY PRELIMINAR
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# ISINTEGR = F
# EMIN = 0.1
# EMAX = 20000.0
# COMMENT = ['Differential energy spectrum between 0.1 GeV and 20 TeV from 81 h of 3C5', '8 observations.']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 32
# NAXIS2 = 4
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 4
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Denergy
# TFORM3 = 1D
# TUNIT3 = GeV
# TTYPE4 = Dflux
# TFORM4 = 1D
# TUNIT4 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# ISINTEGR = F
# EMIN = 0.1
# EMAX = 20000.0
# COMMENT = Differential energy spectrum between 0.1 GeV and 20 TeV from 81 h of 3C5
# COMMENT = 8 observations.
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 3', 'C58.  Please conside it as VERY PRELIMINAR', 'Differential energy spectrum between 0.1 GeV and 20 TeV from 81 h of 3C5', '8 observations.']
# ORIGIN = MAGIC
# OBJECT = 3C58
# ZMAX = 52.0
# TOBS = 81.0
# AUTHOR = MAGIC Coll.
# EMAX = 20000.0
# ZMIN = 36.0
# TELESCOP = MAGIC-SYSTEM
# REFPAPER = J. Aleksic et al., A&A 567 (2013) L8
# EXTNAME = SPECTRUM
# DATE-OBS = 2013-08-04
# VERSION = 0.1
# EMIN = 0.1
# DATE = 2014-07-25T11:04:14
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 3', 'C58.  Please conside it as VERY PRELIMINAR', 'Differential energy spectrum between 0.1 GeV and 20 TeV from 81 h of 3C5', '8 observations.']
# ORIGIN = MAGIC
# OBJECT = 3C58
# ZMAX = 52.0
# TOBS = 81.0
# AUTHOR = MAGIC Coll.
# EMAX = 20000.0
# ZMIN = 36.0
# TELESCOP = MAGIC-SYSTEM
# REFPAPER = J. Aleksic et al., A&A 567 (2013) L8
# EXTNAME = SPECTRUM
# DATE-OBS = 2013-08-04
# VERSION = 0.1
# RA = 31.4043
# EMIN = 0.1
# DATE = 2014-07-25T11:04:14
# DEC = 64.8283
#
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2014_AEaqr.fits  ..failed: no SPECTRUM
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2014_3C279.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2014-07-18T08:13:24
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# VERSION = 0.1
# OBJECT = 3C 279
# TELESCOP = MAGIC-SYSTEM
# DATE-OBS = 2011-02
# TOBS = 17.85
# ZMIN = 35.0
# ZMAX = 45.0
# EMIN = 125.0
# EMAX = 500.0
# COMMENT = 3C279 observational campaign with MAGIC can be split in two samples:
# COMMENT = Sample 1:  Feb 2011 - Apr 2011, observation time = 20.00 h
# COMMENT = Sample 2: Jun 2011,  observation time = 10.00 h
# REFPAPER = J. Aleksic et al., A&A 567, A41
# COMMENT = This is a MAGIC fits file containing the result of the observations of 3
# COMMENT = C 279.  Please conside it as VERY PRELIMINAR
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# ISINTEGR = F
# CONFLEVE = 95.0
# DATE-OBS = 2011-02
# COMMENT = ['Differential upper limits of 3C279 observations during the first campaig', 'n (Feb 2011-Apr 2011)']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 16
# NAXIS2 = 2
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 2
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# ISINTEGR = F
# CONFLEVE = 95.0
# DATE-OBS = 2011-02
# COMMENT = Differential upper limits of 3C279 observations during the first campaig
# COMMENT = n (Feb 2011-Apr 2011)
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", '3C279 observational campaign with MAGIC can be split in two samples:', 'Sample 1:  Feb 2011 - Apr 2011, observation time = 20.00 h', 'Sample 2: Jun 2011,  observation time = 10.00 h', 'This is a MAGIC fits file containing the result of the observations of 3', 'C 279.  Please conside it as VERY PRELIMINAR', 'Differential upper limits of 3C279 observations during the first campaig', 'n (Feb 2011-Apr 2011)']
# ORIGIN = MAGIC
# OBJECT = 3C 279
# ZMAX = 45.0
# TOBS = 17.85
# AUTHOR = MAGIC Coll.
# CONFLEVE = 95.0
# EMAX = 500.0
# ZMIN = 35.0
# TELESCOP = MAGIC-SYSTEM
# REFPAPER = J. Aleksic et al., A&A 567, A41
# EXTNAME = SPECTRUM
# DATE-OBS = 2011-02
# VERSION = 0.1
# EMIN = 125.0
# DATE = 2014-07-18T08:13:24
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", '3C279 observational campaign with MAGIC can be split in two samples:', 'Sample 1:  Feb 2011 - Apr 2011, observation time = 20.00 h', 'Sample 2: Jun 2011,  observation time = 10.00 h', 'This is a MAGIC fits file containing the result of the observations of 3', 'C 279.  Please conside it as VERY PRELIMINAR', 'Differential upper limits of 3C279 observations during the first campaig', 'n (Feb 2011-Apr 2011)']
# ORIGIN = MAGIC
# OBJECT = 3C 279
# ZMAX = 45.0
# TOBS = 17.85
# AUTHOR = MAGIC Coll.
# CONFLEVE = 95.0
# EMAX = 500.0
# ZMIN = 35.0
# TELESCOP = MAGIC-SYSTEM
# REFPAPER = J. Aleksic et al., A&A 567, A41
# EXTNAME = SPECTRUM
# DATE-OBS = 2011-02
# VERSION = 0.1
# RA = 194.046527375
# EMIN = 125.0
# DATE = 2014-07-18T08:13:24
# DEC = -5.789312417
#
# Extension table metadata:
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# CONFLEVE = 95.0
# DATE-OBS = 2011-06
# COMMENT = ['Differential upper limits of 3C 279 observations during the second campa', 'ign (Jun 2011)']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 16
# NAXIS2 = 2
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 2
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# CONFLEVE = 95.0
# DATE-OBS = 2011-06
# COMMENT = Differential upper limits of 3C 279 observations during the second campa
# COMMENT = ign (Jun 2011)
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", '3C279 observational campaign with MAGIC can be split in two samples:', 'Sample 1:  Feb 2011 - Apr 2011, observation time = 20.00 h', 'Sample 2: Jun 2011,  observation time = 10.00 h', 'This is a MAGIC fits file containing the result of the observations of 3', 'C 279.  Please conside it as VERY PRELIMINAR', 'Differential upper limits of 3C 279 observations during the second campa', 'ign (Jun 2011)']
# ORIGIN = MAGIC
# OBJECT = 3C 279
# ZMAX = 45.0
# TOBS = 17.85
# AUTHOR = MAGIC Coll.
# CONFLEVE = 95.0
# EMAX = 500.0
# ZMIN = 35.0
# TELESCOP = MAGIC-SYSTEM
# REFPAPER = J. Aleksic et al., A&A 567, A41
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2011-06
# VERSION = 0.1
# EMIN = 125.0
# DATE = 2014-07-18T08:13:24
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", '3C279 observational campaign with MAGIC can be split in two samples:', 'Sample 1:  Feb 2011 - Apr 2011, observation time = 20.00 h', 'Sample 2: Jun 2011,  observation time = 10.00 h', 'This is a MAGIC fits file containing the result of the observations of 3', 'C 279.  Please conside it as VERY PRELIMINAR', 'Differential upper limits of 3C 279 observations during the second campa', 'ign (Jun 2011)']
# ORIGIN = MAGIC
# OBJECT = 3C 279
# ZMAX = 45.0
# TOBS = 17.85
# AUTHOR = MAGIC Coll.
# CONFLEVE = 95.0
# EMAX = 500.0
# ZMIN = 35.0
# TELESCOP = MAGIC-SYSTEM
# REFPAPER = J. Aleksic et al., A&A 567, A41
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2011-06
# VERSION = 0.1
# RA = 194.046527375
# EMIN = 125.0
# DATE = 2014-07-18T08:13:24
# DEC = -5.789312417
#
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2014_4C+5517.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2014-07-24T08:22:37
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# VERSION = 0.1
# OBJECT = 4C +55.17
# TELESCOP = MAGIC-SYSTEM
# DATE-OBS = 2010-11--
# TOBS = 27.73
# ZMIN = 27.0
# ZMAX = 37.0
# REFPAPER = J. Aleksic et al., A&A 556 (2013) A67
# COMMENT = This is a MAGIC fits file containing the result of the observations of 4
# COMMENT = C +55.17.  Please conside it as VERY PRELIMINAR
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# ISINTEGR = F
# CONFLEVE = 95.0
# COMMENT = ['Differential upper limits from 27.73 h of 4C +55.17 observations.']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 16
# NAXIS2 = 4
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 2
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# ISINTEGR = F
# CONFLEVE = 95.0
# COMMENT = Differential upper limits from 27.73 h of 4C +55.17 observations.
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 4', 'C +55.17.  Please conside it as VERY PRELIMINAR', 'Differential upper limits from 27.73 h of 4C +55.17 observations.']
# ORIGIN = MAGIC
# OBJECT = 4C +55.17
# ZMAX = 37.0
# TOBS = 27.73
# AUTHOR = MAGIC Coll.
# CONFLEVE = 95.0
# ZMIN = 27.0
# TELESCOP = MAGIC-SYSTEM
# REFPAPER = J. Aleksic et al., A&A 556 (2013) A67
# EXTNAME = SPECTRUM
# DATE-OBS = 2010-11--
# VERSION = 0.1
# DATE = 2014-07-24T08:22:37
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a MAGIC fits file containing the result of the observations of 4', 'C +55.17.  Please conside it as VERY PRELIMINAR', 'Differential upper limits from 27.73 h of 4C +55.17 observations.']
# ORIGIN = MAGIC
# OBJECT = 4C +55.17
# ZMAX = 37.0
# TOBS = 27.73
# AUTHOR = MAGIC Coll.
# CONFLEVE = 95.0
# ZMIN = 27.0
# TELESCOP = MAGIC-SYSTEM
# REFPAPER = J. Aleksic et al., A&A 556 (2013) A67
# EXTNAME = SPECTRUM
# DATE-OBS = 2010-11--
# VERSION = 0.1
# RA = 149.409093792
# DATE = 2014-07-24T08:22:37
# DEC = 55.382703778
#
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2014_CrabPulsar.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2014-07-18T15:53:06
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# VERSION = 0.1
# OBJECT = Crab Pulsar
# TELESCOP = MAGIC-Stereo
# DATE-OBS = 2009-09--
# TOBS = 135.0
# ZMAX = 35.0
# COMMENT = Crab Pulsar observational campaign with MAGIC between September 2009 and
# COMMENT =  April 2013
# REFPAPER = J. Aleksic et al., A&A 565 (2014) 12
# COMMENT = This is a MAGIC fits file containing the result of the observations of C
# COMMENT = rab Pulsar.  Please consider it as VERY PRELIMINAR
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2009-09--
# EMIN = 50.0
# COMMENT = ['Differential energy spectrum above 50 GeV of Crab Nebula observations']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 17
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2009-09--
# EMIN = 50.0
# COMMENT = Differential energy spectrum above 50 GeV of Crab Nebula observations
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'Crab Pulsar observational campaign with MAGIC between September 2009 and', ' April 2013', 'This is a MAGIC fits file containing the result of the observations of C', 'rab Pulsar.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum above 50 GeV of Crab Nebula observations']
# ORIGIN = MAGIC
# OBJECT = Crab Pulsar
# ZMAX = 35.0
# TOBS = 135.0
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., A&A 565 (2014) 12
# EXTNAME = SPECTRUM
# DATE-OBS = 2009-09--
# VERSION = 0.1
# EMIN = 50.0
# DATE = 2014-07-18T15:53:06
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'Crab Pulsar observational campaign with MAGIC between September 2009 and', ' April 2013', 'This is a MAGIC fits file containing the result of the observations of C', 'rab Pulsar.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum above 50 GeV of Crab Nebula observations']
# ORIGIN = MAGIC
# OBJECT = Crab Pulsar
# ZMAX = 35.0
# TOBS = 135.0
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., A&A 565 (2014) 12
# EXTNAME = SPECTRUM
# DATE-OBS = 2009-09--
# VERSION = 0.1
# RA = 83.63307625
# EMIN = 50.0
# DATE = 2014-07-18T15:53:06
# DEC = 22.014493278
#
# Extension table metadata:
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# DATE-OBS = 2009-09--
# EMIN = 50.0
# COMMENT = ['Differential energy spectrum above 50 GeV of the significant peak P1 emi', 'ssion (phase -0.017 to 0.026)']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 6
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# DATE-OBS = 2009-09--
# EMIN = 50.0
# COMMENT = Differential energy spectrum above 50 GeV of the significant peak P1 emi
# COMMENT = ssion (phase -0.017 to 0.026)
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'Crab Pulsar observational campaign with MAGIC between September 2009 and', ' April 2013', 'This is a MAGIC fits file containing the result of the observations of C', 'rab Pulsar.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum above 50 GeV of the significant peak P1 emi', 'ssion (phase -0.017 to 0.026)']
# ORIGIN = MAGIC
# OBJECT = Crab Pulsar
# ZMAX = 35.0
# TOBS = 135.0
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., A&A 565 (2014) 12
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2009-09--
# VERSION = 0.1
# EMIN = 50.0
# DATE = 2014-07-18T15:53:06
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'Crab Pulsar observational campaign with MAGIC between September 2009 and', ' April 2013', 'This is a MAGIC fits file containing the result of the observations of C', 'rab Pulsar.  Please consider it as VERY PRELIMINAR', 'Differential energy spectrum above 50 GeV of the significant peak P1 emi', 'ssion (phase -0.017 to 0.026)']
# ORIGIN = MAGIC
# OBJECT = Crab Pulsar
# ZMAX = 35.0
# TOBS = 135.0
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-Stereo
# REFPAPER = J. Aleksic et al., A&A 565 (2014) 12
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2009-09--
# VERSION = 0.1
# RA = 83.63307625
# EMIN = 50.0
# DATE = 2014-07-18T15:53:06
# DEC = 22.014493278
#
# Extension table metadata:
# EXTNAME = SPECTRUM_2
# ISINTEGR = F
# DATE-OBS = 2009-09--
# EMIN = 50.0
# COMMENT = ['Differential energy spectrum above 50 GeV of the significant peak P2 emi', 'ssion (phase 0.377 to 0.422)']
#
# Extension SPECTRUM header:
# ...
# ORIGIN = MAGIC
# OBJECT = Markarian 421
# TOBS = 25.6
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-I
# REFPAPER = J. Albert et al., ApJ 663 (2007) 125
# EXTNAME = SPECTRUM_1
# DATE-OBS = 2004-11--
# VERSION = 0.1
# RA = 166.071
# DATE = 2011-02-16T14:48:41
# DEC = 38.1947
# SIZEMIN = 150.0
#
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2007_Arp220.fits  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2006_Mrk180.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2011-02-16T15:34:38
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-I
# VERSION = 0.1
# OBJECT = Mrk 180
# DATE-OBS = 2006-03-23
# SRCPOS1 = 174.1095
# SRCPOS2 = 70.1576
# TOBS = 11.1
# ZMIN = 39.0
# ZMAX = 44.0
# EFFICIEN = 50.0
# REFPAPER = J. Albert et al., ApJ Letters 648 (2006) L105-108
# COMMENT = This is a prototype of MAGIC fits file containig the result of the obser
# COMMENT = vations of Markarian 180. Please conside it as VERY PRELIMINAR
# COMMENT = The latest version of this data file and of the document explaining its
# COMMENT = content can be found at http://magic.pic.es/pub/fits.
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# ISINTEGR = F
# EMIN = 200.0
# COMMENT = ['The measured energy spectrum of Mrk180']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 4
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# ISINTEGR = F
# EMIN = 200.0
# COMMENT = The measured energy spectrum of Mrk180
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a prototype of MAGIC fits file containig the result of the obser', 'vations of Markarian 180. Please conside it as VERY PRELIMINAR', 'The latest version of this data file and of the document explaining its', 'content can be found at http://magic.pic.es/pub/fits.', 'The measured energy spectrum of Mrk180']
# ORIGIN = MAGIC
# OBJECT = Mrk 180
# ZMAX = 44.0
# TOBS = 11.1
# AUTHOR = MAGIC Coll.
# ZMIN = 39.0
# TELESCOP = MAGIC-I
# REFPAPER = J. Albert et al., ApJ Letters 648 (2006) L105-108
# EFFICIEN = 50.0
# DATE-OBS = 2006-03-23
# VERSION = 0.1
# EMIN = 200.0
# DATE = 2011-02-16T15:34:38
# EXTNAME = SPECTRUM
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a prototype of MAGIC fits file containig the result of the obser', 'vations of Markarian 180. Please conside it as VERY PRELIMINAR', 'The latest version of this data file and of the document explaining its', 'content can be found at http://magic.pic.es/pub/fits.', 'The measured energy spectrum of Mrk180']
# ORIGIN = MAGIC
# OBJECT = Mrk 180
# ZMAX = 44.0
# TOBS = 11.1
# AUTHOR = MAGIC Coll.
# ZMIN = 39.0
# TELESCOP = MAGIC-I
# REFPAPER = J. Albert et al., ApJ Letters 648 (2006) L105-108
# EFFICIEN = 50.0
# DATE-OBS = 2006-03-23
# VERSION = 0.1
# RA = 174.1095
# EMIN = 200.0
# DATE = 2011-02-16T15:34:38
# DEC = 70.1576
# EXTNAME = SPECTRUM
#
# Extension table metadata:
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# EMIN = 200.0
# COMMENT = ['The de-apsorbed energy spectrum of Mrk180']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 4
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM_1
# ISINTEGR = F
# EMIN = 200.0
# COMMENT = The de-apsorbed energy spectrum of Mrk180
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a prototype of MAGIC fits file containig the result of the obser', 'vations of Markarian 180. Please conside it as VERY PRELIMINAR', 'The latest version of this data file and of the document explaining its', 'content can be found at http://magic.pic.es/pub/fits.', 'The de-apsorbed energy spectrum of Mrk180']
# ORIGIN = MAGIC
# OBJECT = Mrk 180
# ZMAX = 44.0
# TOBS = 11.1
# AUTHOR = MAGIC Coll.
# ZMIN = 39.0
# TELESCOP = MAGIC-I
# REFPAPER = J. Albert et al., ApJ Letters 648 (2006) L105-108
# EFFICIEN = 50.0
# DATE-OBS = 2006-03-23
# VERSION = 0.1
# EMIN = 200.0
# DATE = 2011-02-16T15:34:38
# EXTNAME = SPECTRUM_1
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a prototype of MAGIC fits file containig the result of the obser', 'vations of Markarian 180. Please conside it as VERY PRELIMINAR', 'The latest version of this data file and of the document explaining its', 'content can be found at http://magic.pic.es/pub/fits.', 'The de-apsorbed energy spectrum of Mrk180']
# ORIGIN = MAGIC
# OBJECT = Mrk 180
# ZMAX = 44.0
# TOBS = 11.1
# AUTHOR = MAGIC Coll.
# ZMIN = 39.0
# TELESCOP = MAGIC-I
# REFPAPER = J. Albert et al., ApJ Letters 648 (2006) L105-108
# EFFICIEN = 50.0
# DATE-OBS = 2006-03-23
# VERSION = 0.1
# RA = 174.1095
# EMIN = 200.0
# DATE = 2011-02-16T15:34:38
# DEC = 70.1576
# EXTNAME = SPECTRUM_1
#
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2006_LSI61303.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2011-02-17T11:13:55
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-I
# VERSION = 0.1
# OBJECT = LS I +61 303
# SRCPOS1 = 2.67556
# SRCPOS2 = 61.229
# DATE-OBS = 2005-10-11
# TOBS = 54.0
# SIZEMIN = 200.0
# ZMIN = 31.0
# ZMAX = 56.0
# PERIOD = 26.496
# TZERO = 43366.27
# PHIMIN = 0.1
# PHIMAX = 0.8
# REFPAPER = J. Albert et al., Science 312, 1771 (2006)
# COMMENT = This is a prototype of MAGIC fits file containing the results of the obs
# COMMENT = ervations of LS I +61 303 acquired during cycle I observations. Please c
# COMMENT = onsider it as VERY PRELIMINAR
# COMMENT = The latest version of this data file and of the document explaining its
# COMMENT = content can be found at http://magic.pic.es/pub/fits.
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# TOBS = 10.7
# PHIMIN = 0.4
# PHIMAX = 0.7
# ISINTEGR = F
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 7
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# TOBS = 10.7
# PHIMIN = 0.4
# PHIMAX = 0.7
# ISINTEGR = F
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a prototype of MAGIC fits file containing the results of the obs', 'ervations of LS I +61 303 acquired during cycle I observations. Please c', 'onsider it as VERY PRELIMINAR', 'The latest version of this data file and of the document explaining its', 'content can be found at http://magic.pic.es/pub/fits.']
# ORIGIN = MAGIC
# DATE = 2011-02-17T11:13:55
# OBJECT = LS I +61 303
# ZMAX = 56.0
# TOBS = 10.7
# PHIMIN = 0.4
# ZMIN = 31.0
# TELESCOP = MAGIC-I
# PERIOD = 26.496
# TZERO = 43366.27
# DATE-OBS = 2005-10-11
# VERSION = 0.1
# REFPAPER = J. Albert et al., Science 312, 1771 (2006)
# EXTNAME = SPECTRUM
# AUTHOR = MAGIC Coll.
# SIZEMIN = 200.0
# PHIMAX = 0.7
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a prototype of MAGIC fits file containing the results of the obs', 'ervations of LS I +61 303 acquired during cycle I observations. Please c', 'onsider it as VERY PRELIMINAR', 'The latest version of this data file and of the document explaining its', 'content can be found at http://magic.pic.es/pub/fits.']
# ORIGIN = MAGIC
# DATE = 2011-02-17T11:13:55
# OBJECT = LS I +61 303
# ZMAX = 56.0
# TOBS = 10.7
# PHIMIN = 0.4
# ZMIN = 31.0
# TELESCOP = MAGIC-I
# PERIOD = 26.496
# TZERO = 43366.27
# DATE-OBS = 2005-10-11
# VERSION = 0.1
# RA = 2.67556
# REFPAPER = J. Albert et al., Science 312, 1771 (2006)
# DEC = 61.229
# EXTNAME = SPECTRUM
# AUTHOR = MAGIC Coll.
# SIZEMIN = 200.0
# PHIMAX = 0.7
#
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2006_HESS1834.fits  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2006_HESS1813.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2011-02-17T11:13:58
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-I
# VERSION = 0.1
# OBJECT = HESS J1813-178
# DATE-OBS = 2005-06--
# TOBS = 22.5
# ZMAX = 52.0
# EMIN = 400.0
# SRCPOS1 = 273.408
# SRCPOS2 = -17.8677
# EFFICIEN = 70.0
# REFPAPER = J. Albert et al., ApJ Letters 637, L41 (2006)
# COMMENT = This is a prototype of MAGIC fits file containig the result of the obser
# COMMENT = vations of HESS J1813-178. Please conside it as VERY PRELIMINAR
# COMMENT = The latest version of this data file and of the document explaining its
# COMMENT = content can be found at http://magic.pic.es/pub/fits.
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# EMIN = 400.0
# ISINTEGR = T
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 7
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# EMIN = 400.0
# ISINTEGR = T
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a prototype of MAGIC fits file containig the result of the obser', 'vations of HESS J1813-178. Please conside it as VERY PRELIMINAR', 'The latest version of this data file and of the document explaining its', 'content can be found at http://magic.pic.es/pub/fits.']
# ORIGIN = MAGIC
# OBJECT = HESS J1813-178
# ZMAX = 52.0
# TOBS = 22.5
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-I
# REFPAPER = J. Albert et al., ApJ Letters 637, L41 (2006)
# EFFICIEN = 70.0
# DATE-OBS = 2005-06--
# VERSION = 0.1
# EMIN = 400.0
# DATE = 2011-02-17T11:13:58
# EXTNAME = SPECTRUM
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a prototype of MAGIC fits file containig the result of the obser', 'vations of HESS J1813-178. Please conside it as VERY PRELIMINAR', 'The latest version of this data file and of the document explaining its', 'content can be found at http://magic.pic.es/pub/fits.']
# ORIGIN = MAGIC
# OBJECT = HESS J1813-178
# ZMAX = 52.0
# TOBS = 22.5
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-I
# REFPAPER = J. Albert et al., ApJ Letters 637, L41 (2006)
# EFFICIEN = 70.0
# DATE-OBS = 2005-06--
# VERSION = 0.1
# RA = 273.408
# EMIN = 400.0
# DATE = 2011-02-17T11:13:58
# DEC = -17.8677
# EXTNAME = SPECTRUM
#
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.
# ----------------------------------------------------------------------
#
# Processing file: FITS_pic/MAGIC_2006_GC.fits PrimaryHDU header:
# SIMPLE = True
# BITPIX = -32
# NAXIS = 0
# EXTEND = True
# COMMENT =   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT =   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE = 2011-02-17T11:14:00
# ORIGIN = MAGIC
# AUTHOR = MAGIC Coll.
# TELESCOP = MAGIC-I
# VERSION = 0.1
# OBJECT = Galactic Center
# DATE-OBS = 2004-09-01
# ZMIN = 58.0
# ZMAX = 68.0
# SRCPOS1 = 266.4
# SRCPOS2 = -28.93
# REFPAPER = J. Albert et al., ApJ Letters 638, L101 (2006)
# COMMENT = This is a prototype of MAGIC fits file containig the result of the obser
# COMMENT = vations of Galactic Center. Please conside it as VERY PRELIMINAR
# COMMENT = The latest version of this data file and of the document explaining its
# COMMENT = content can be found at http://magic.pic.es/pub/fits.
#
# Extension table metadata:
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2005-06-01
# TOBS = 17.0
# ZMIN = 58.0
# ZMAX = 62.0
# SIZEMIN = 200.0
# EFFICIEN = 50.0
# COMMENT = ['Reconstructed VHE gamma-ray energy spectrum of the GC (statistical error', 's only)']
#
# Extension SPECTRUM header:
# XTENSION = BINTABLE
# BITPIX = 8
# NAXIS = 2
# NAXIS1 = 24
# NAXIS2 = 5
# PCOUNT = 0
# GCOUNT = 1
# TFIELDS = 3
# TTYPE1 = energy
# TFORM1 = 1D
# TUNIT1 = GeV
# TTYPE2 = flux
# TFORM2 = 1D
# TUNIT2 = ph TeV-1 cm-2 s-1
# TTYPE3 = Dflux
# TFORM3 = 1D
# TUNIT3 = ph TeV-1 cm-2 s-1
# EXTNAME = SPECTRUM
# ISINTEGR = F
# DATE-OBS = 2005-06-01
# TOBS = 17.0
# ZMIN = 58.0
# ZMAX = 62.0
# SIZEMIN = 200.0
# EFFICIEN = 50.0
# COMMENT = Reconstructed VHE gamma-ray energy spectrum of the GC (statistical error
# COMMENT = s only)
#
# New header dictionary:
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a prototype of MAGIC fits file containig the result of the obser', 'vations of Galactic Center. Please conside it as VERY PRELIMINAR', 'The latest version of this data file and of the document explaining its', 'content can be found at http://magic.pic.es/pub/fits.', 'Reconstructed VHE gamma-ray energy spectrum of the GC (statistical error', 's only)']
# ORIGIN = MAGIC
# OBJECT = Galactic Center
# ZMAX = 62.0
# TOBS = 17.0
# AUTHOR = MAGIC Coll.
# ZMIN = 58.0
# TELESCOP = MAGIC-I
# REFPAPER = J. Albert et al., ApJ Letters 638, L101 (2006)
# EFFICIEN = 50.0
# DATE-OBS = 2005-06-01
# VERSION = 0.1
# DATE = 2011-02-17T11:14:00
# EXTNAME = SPECTRUM
# SIZEMIN = 200.0
#
# COMMENT = ["  FITS (Flexible Image Transport System) format is defined in 'Astronomy", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", 'This is a prototype of MAGIC fits file containig the result of the obser', 'vations of Galactic Center. Please conside it as VERY PRELIMINAR', 'The latest version of this data file and of the document explaining its', 'content can be found at http://magic.pic.es/pub/fits.', 'Reconstructed VHE gamma-ray energy spectrum of the GC (statistical error', 's only)']
# ORIGIN = MAGIC
# OBJECT = Galactic Center
# ZMAX = 62.0
# TOBS = 17.0
# AUTHOR = MAGIC Coll.
# ZMIN = 58.0
# TELESCOP = MAGIC-I
# REFPAPER = J. Albert et al., ApJ Letters 638, L101 (2006)
# EFFICIEN = 50.0
# DATE-OBS = 2005-06-01
# VERSION = 0.1
# RA = 266.4
# DATE = 2011-02-17T11:14:00
# DEC = -28.93
# EXTNAME = SPECTRUM
# SIZEMIN = 200.0
#
# ----------------------------------------------------------------------
#
# Processing file: nan  ..failed: to open.

# %%
def fix_degeneracy(group):
    row = group.irow(0)
    columns = row.to_dict()
    tdf = {}
    tabs = row['SPECTRUM']
    tdf['SPECTRUM'] = tabs
    del columns['SPECTRUM']
    tdf['OBJECT'] = [ t.meta['OBJECT'] for t in tabs ]
    tdf['RA'] = [ t.meta['RA'] for t in tabs ]
    tdf['DEC'] = [ t.meta['DEC'] for t in tabs ]
    for c in columns: tdf[c] = [row[c]]*len(tabs)
    return pd.DataFrame(tdf)

table_proc = table_pic.dropna().groupby('DOI',group_keys=False).apply(fix_degeneracy).reset_index(drop=True)
# Out:
# /home/chbrandt/.conda/envs/magic/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: irow(i) is deprecated. Please use .iloc[i]
#   app.launch_new_instance()

# %%
def dict_to_table(dict_tab):
    from astropy.table import Table,Column
    from astropy.units import Unit
    tab = dict_tab
    h_keys = ['filename','EXTNAME','OBJECT','SRCPOS1','SRCPOS2','DATE-OBS']
    t_cols = ['energy','Denergy','flux','Dflux']
    cols = []
    t = Table()
    for cname in t_cols:
        cdata = tab[cname]
        cunit = Unit(tab[cname+'_unit'])
        c = Column(data=cdata,name=cname,unit=cunit)
        cols.append(c)
    for c in cols:
        t.add_column(c)
    for kword in h_keys:
        t.meta[kword.upper()] = tab[kword]
    return t


#table_proc['SPECTRUM'] = table_proc.PROC.apply(dict_to_table)

def write_table(table,filename,odir):
    import os,re
    filename = os.path.basename(filename)
    filename = re.sub('[+]','p',filename)
    extname = '_' + table.meta['EXTNAME'] + '.fits'
    fitsfilename = os.path.join(odir,re.sub('.fits',extname,filename))
    table.write(fitsfilename,format='fits')
    votfilename = fitsfilename[:-5] + '.vot'
    table.write(votfilename,format='votable')
    return fitsfilename

outdir = 'FITS_out/'
clean_dir(outdir)

table_proc['FITS'] = table_proc.apply(lambda d:write_table(d.SPECTRUM,d.FITS_local,outdir),axis=1)
# Out:
# WARNING: UnitsWarning: The unit 'erg' has been deprecated in the FITS standard. Suggested: cm2 g s-2. [astropy.units.format.utils]
# WARNING:astropy:UnitsWarning: The unit 'erg' has been deprecated in the FITS standard. Suggested: cm2 g s-2.

# %%
pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',10)
pd.set_option('display.width',100)
#del table_proc['PROC']
#del table_proc['SPECTRUM']

#print table_proc.describe(include='all')
print table_proc
# Out:
#            DEC                                                DOI  \
# 0    22.014500      http://dx.doi.org/10.1016/j.jheap.2015.01.002
# 1    22.014500      http://dx.doi.org/10.1016/j.jheap.2015.01.002
# 2    16.148200      http://dx.doi.org/10.1051/0004-6361/200811326
# 3    16.148200      http://dx.doi.org/10.1051/0004-6361/200811326
# 4    16.148200      http://dx.doi.org/10.1051/0004-6361/200811326
# 5    11.190100      http://dx.doi.org/10.1051/0004-6361/200913607
# 6    38.666700      http://dx.doi.org/10.1051/0004-6361/200913945
# 7    38.666700      http://dx.doi.org/10.1051/0004-6361/200913945
# 8    38.666700      http://dx.doi.org/10.1051/0004-6361/200913945
# 9    38.666700      http://dx.doi.org/10.1051/0004-6361/200913945
# 10   38.666700      http://dx.doi.org/10.1051/0004-6361/200913945
# 11   38.666700      http://dx.doi.org/10.1051/0004-6361/200913945
# 12   38.666700      http://dx.doi.org/10.1051/0004-6361/200913945
# 13   38.666700      http://dx.doi.org/10.1051/0004-6361/200913945
# 14   38.666700      http://dx.doi.org/10.1051/0004-6361/200913945
# 15   12.391100      http://dx.doi.org/10.1051/0004-6361/201117827
# 16   38.410280      http://dx.doi.org/10.1051/0004-6361/201117967
# 17   38.410280      http://dx.doi.org/10.1051/0004-6361/201117967
# 18   41.513100      http://dx.doi.org/10.1051/0004-6361/201118502
# 19   41.513100      http://dx.doi.org/10.1051/0004-6361/201118502
# 20   22.014500      http://dx.doi.org/10.1051/0004-6361/201218796
# 21  -30.225600      http://dx.doi.org/10.1051/0004-6361/201218796
# 22   14.190000      http://dx.doi.org/10.1051/0004-6361/201218846
# 23   30.116800      http://dx.doi.org/10.1051/0004-6361/201219133
# 24   30.116800      http://dx.doi.org/10.1051/0004-6361/201219133
# 25   61.750900      http://dx.doi.org/10.1051/0004-6361/201220275
# 26   58.879000      http://dx.doi.org/10.1051/0004-6361/201220275
# 27   51.705000      http://dx.doi.org/10.1051/0004-6361/201220714
# 28   51.705000      http://dx.doi.org/10.1051/0004-6361/201220714
# 29   51.705000      http://dx.doi.org/10.1051/0004-6361/201220714
# 30   51.705000      http://dx.doi.org/10.1051/0004-6361/201220714
# 31         NaN      http://dx.doi.org/10.1051/0004-6361/201321197
# 32   41.324767      http://dx.doi.org/10.1051/0004-6361/201321938
# 33   41.324767      http://dx.doi.org/10.1051/0004-6361/201321938
# 34   41.324767      http://dx.doi.org/10.1051/0004-6361/201321938
# 35   41.324767      http://dx.doi.org/10.1051/0004-6361/201321938
# 36   41.511695      http://dx.doi.org/10.1051/0004-6361/201322951
# 37   41.511695      http://dx.doi.org/10.1051/0004-6361/201322951
# 38   -5.789312      http://dx.doi.org/10.1051/0004-6361/201323036
# 39   -5.789312      http://dx.doi.org/10.1051/0004-6361/201323036
# 40   23.800010      http://dx.doi.org/10.1051/0004-6361/201423364
#
52.316181             http://dx.doi.org/10.1093/mnras/stv895
# 121  52.316181             http://dx.doi.org/10.1093/mnras/stv895
# 122  20.108500           http://dx.doi.org/10.1093/pasj/61.5.1011
# 123  20.108500           http://dx.doi.org/10.1093/pasj/61.5.1011
# 124  61.229000          http://dx.doi.org/10.1126/science.1128177
# 125  41.324767          http://dx.doi.org/10.1126/science.1256183
# 126  41.324767          http://dx.doi.org/10.1126/science.1256183
# 127   5.789300  http://www.sciencemag.org/content/320/5884/175...
# 128   5.789300  http://www.sciencemag.org/content/320/5884/175...
# 129   5.789300  http://www.sciencemag.org/content/320/5884/175...
#
#                                                   FITS  \
# 0         FITS_out/MAGIC_2015_CrabNebula_SPECTRUM.fits
# 1       FITS_out/MAGIC_2015_CrabNebula_SPECTRUM_1.fits
# 2              FITS_out/MAGIC_2009_3C454_SPECTRUM.fits
# 3            FITS_out/MAGIC_2009_3C454_SPECTRUM_1.fits
# 4            FITS_out/MAGIC_2009_3C454_SPECTRUM_2.fits
# 5      FITS_out/MAGIC_2010_PG1553_mw2008_SPECTRUM.fits
# 6      FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM.fits
# 7    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_1.fits
# 8    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_2.fits
# 9    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_3.fits
# 10   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_4.fits
# 11   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_5.fits
# 12   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_6.fits
# 13   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_7.fits
# 14   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_8.fits
# 15               FITS_out/MAGIC_2012_M87_SPECTRUM.fits
# 16            FITS_out/MAGIC_2012_B32247_SPECTRUM.fits
# 17          FITS_out/MAGIC_2012_B32247_SPECTRUM_1.fits
# 18           FITS_out/MAGIC_2012_Perseus_SPECTRUM.fits
# 19         FITS_out/MAGIC_2012_Perseus_SPECTRUM_1.fits
# 20           FITS_out/MAGIC_2012_PKS2155_SPECTRUM.fits
# 21         FITS_out/MAGIC_2012_PKS2155_SPECTRUM_1.fits
# 22               FITS_out/MAGIC_2012_W51_SPECTRUM.fits
# 23           FITS_out/MAGIC_2012_1ES1215_SPECTRUM.fits
# 24         FITS_out/MAGIC_2012_1ES1215_SPECTRUM_1.fits
# 25       FITS_out/MAGIC_2013_Magnetars_SPECTRUM_1.fits
# 26       FITS_out/MAGIC_2013_Magnetars_SPECTRUM_3.fits
# 27       FITS_out/MAGIC_2013_1ES2344p514_SPECTRUM.fits
# 28     FITS_out/MAGIC_2013_1ES2344p514_SPECTRUM_1.fits
# 29     FITS_out/MAGIC_2013_1ES2344p514_SPECTRUM_2.fits
# 30     FITS_out/MAGIC_2013_1ES2344p514_SPECTRUM_3.fits
# 31          FITS_out/MAGIC_2013_J1644p57_SPECTRUM.fits
# 32             FITS_out/MAGIC_2014_IC310_SPECTRUM.fits
# 33           FITS_out/MAGIC_2014_IC310_SPECTRUM_1.fits
# 34           FITS_out/MAGIC_2014_IC310_SPECTRUM_2.fits
# 35           FITS_out/MAGIC_2014_IC310_SPECTRUM_3.fits
# 36           FITS_out/MAGIC_2014_NGC1275_SPECTRUM.fits
# 37         FITS_out/MAGIC_2014_NGC1275_SPECTRUM_1.fits
# 38             FITS_out/MAGIC_2014_3C279_SPECTRUM.fits
# 39           FITS_out/MAGIC_2014_3C279_SPECTRUM_1.fits
# 40       FITS_out/MAGIC_2014_PKS1424p240_SPECTRUM.fits
# 41     FITS_out/MAGIC_2014_PKS1424p240_SPECTRUM_1.fits
# 42     FITS_out/MAGIC_2014_PKS1424p240_SPECTRUM_2.fits
# 43     FITS_out/MAGIC_2014_PKS1424p240_SPECTRUM_3.fits
# 44        FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM.fits
# 45      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_1.fits
# 46      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_2.fits
# 47      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_3.fits
# 48      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_4.fits
# 49      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_5.fits
# 50      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_6.fits
# 51      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_7.fits
# 52      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_8.fits
# 53              FITS_out/MAGIC_2014_3C58_SPECTRUM.fits
# 54       FITS_out/MAGIC_2007_CassiopeiaA_SPECTRUM.fits
# 55          FITS_out/MAGIC_2006_HESS1813_SPECTRUM.fits
# 56                FITS_out/MAGIC_2006_GC_SPECTRUM.fits
# 57            FITS_out/MAGIC_2006_Mrk180_SPECTRUM.fits
# 58          FITS_out/MAGIC_2006_Mrk180_SPECTRUM_1.fits
# 59            FITS_out/MAGIC_2007_Mrk421_SPECTRUM.fits
# 60          FITS_out/MAGIC_2007_Mrk421_SPECTRUM_1.fits
# 61             FITS_out/MAGIC_2007_IC443_SPECTRUM.fits
# 62          FITS_out/MAGIC_2007_CygnusX1_SPECTRUM.fits
# 63        FITS_out/MAGIC_2007_CygnusX1_SPECTRUM_1.fits
# 64           FITS_out/MAGIC_2007_1ES1011_SPECTRUM.fits
# 65         FITS_out/MAGIC_2007_1ES1011_SPECTRUM_1.fits
# 66        FITS_out/MAGIC_2008_1ES1959_mw_SPECTRUM.fits
# 67       FITS_out/MAGIC_2008_LSI61303_mw_SPECTRUM.fits
# 68     FITS_out/MAGIC_2008_LSI61303_mw_SPECTRUM_1.fits
# 69               FITS_out/MAGIC_2008_M87_SPECTRUM.fits
# 70             FITS_out/MAGIC_2008_M87_SPECTRUM_1.fits
# 71             FITS_out/MAGIC_2008_M87_SPECTRUM_2.fits
# 72          FITS_out/MAGIC_2008_WRBinSys_SPECTRUM.fits
# 73        FITS_out/MAGIC_2008_WRBinSys_SPECTRUM_1.fits
# 74             FITS_out/MAGIC_2009_3C66A_SPECTRUM.fits
# 75          FITS_out/MAGIC_2009_LSI61303_SPECTRUM.fits
# 76        FITS_out/MAGIC_2009_LSI61303_SPECTRUM_1.fits
# 77               FITS_out/MAGIC_2009_M13_SPECTRUM.fits
# 78   FITS_out/MAGIC_2009_Mrk421_mw_outburst_SPECTRU...
# 79            FITS_out/MAGIC_2009_S50716_SPECTRUM.fits
# 80          FITS_out/MAGIC_2009_S50716_SPECTRUM_1.fits
# 81     FITS_out/MAGIC_2009_Mrk501_mw2006_SPECTRUM.fits
# 82           FITS_out/MAGIC_2010_Perseus_SPECTRUM.fits
# 83         FITS_out/MAGIC_2010_Perseus_SPECTRUM_1.fits
# 84         FITS_out/MAGIC_2010_Perseus_SPECTRUM_2.fits
# 85         FITS_out/MAGIC_2010_Perseus_SPECTRUM_3.fits
# 86          FITS_out/MAGIC_2010_CygnusX3_SPECTRUM.fits
# 87        FITS_out/MAGIC_2010_CygnusX3_SPECTRUM_1.fits
# 88        FITS_out/MAGIC_2010_CygnusX3_SPECTRUM_2.fits
# 89    FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM.fits
# 90   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_1....
# 91   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_2....
# 92   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_3....
# 93   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_4....
# 94   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_5....
# 95   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_6....
# 96   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_7....
# 97            FITS_out/MAGIC_2014_Segue1_SPECTRUM.fits
# 98          FITS_out/MAGIC_2014_Segue1_SPECTRUM_1.fits
# 99          FITS_out/MAGIC_2014_Segue1_SPECTRUM_2.fits
# 100         FITS_out/MAGIC_2014_Segue1_SPECTRUM_3.fits
# 101         FITS_out/MAGIC_2014_Segue1_SPECTRUM_4.fits
# 102         FITS_out/MAGIC_2014_Segue1_SPECTRUM_5.fits
# 103         FITS_out/MAGIC_2014_Segue1_SPECTRUM_6.fits
# 104         FITS_out/MAGIC_2014_Segue1_SPECTRUM_7.fits
# 105         FITS_out/MAGIC_2014_Segue1_SPECTRUM_8.fits
# 106         FITS_out/MAGIC_2014_Segue1_SPECTRUM_9.fits
# 107        FITS_out/MAGIC_2014_Segue1_SPECTRUM_10.fits
# 108        FITS_out/MAGIC_2014_Segue1_SPECTRUM_11.fits
# 109        FITS_out/MAGIC_2014_Segue1_SPECTRUM_12.fits
# 110        FITS_out/MAGIC_2014_Segue1_SPECTRUM_13.fits
# 111            FITS_out/MAGIC_2010_IC310_SPECTRUM.fits
# 112          FITS_out/MAGIC_2011_PKS1222_SPECTRUM.fits
# 113        FITS_out/MAGIC_2011_PKS1222_SPECTRUM_1.fits
# 114       FITS_out/MAGIC_2011_ScorpiusX1_SPECTRUM.fits
# 115     FITS_out/MAGIC_2011_ScorpiusX1_SPECTRUM_1.fits
# 116        FITS_out/MAGIC_2014_GRB090102_SPECTRUM.fits
# 117          FITS_out/MAGIC_2014_4Cp5517_SPECTRUM.fits
# 118          FITS_out/MAGIC_2015_1ES0806_SPECTRUM.fits
# 119        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_1.fits
# 120        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_2.fits
# 121        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_3.fits
# 122            FITS_out/MAGIC_2009_OJ287_SPECTRUM.fits
# 123          FITS_out/MAGIC_2009_OJ287_SPECTRUM_1.fits
# 124         FITS_out/MAGIC_2006_LSI61303_SPECTRUM.fits
# 125            FITS_out/MAGIC_2014_Ic310_SPECTRUM.fits
# 126          FITS_out/MAGIC_2014_Ic310_SPECTRUM_1.fits
# 127            FITS_out/MAGIC_2008_3C279_SPECTRUM.fits
# 128          FITS_out/MAGIC_2008_3C279_SPECTRUM_1.fits
# 129          FITS_out/MAGIC_2008_3C279_SPECTRUM_2.fits
#
#                                       FITS_local                  OBJECT  \
# 0            FITS_pic/MAGIC_2015_CrabNebula.fits             Crab Nebula
# 1            FITS_pic/MAGIC_2015_CrabNebula.fits             Crab Nebula
# 2                 FITS_pic/MAGIC_2009_3C454.fits                 3C454.3
# 3                 FITS_pic/MAGIC_2009_3C454.fits                 3C454.3
# 4                 FITS_pic/MAGIC_2009_3C454.fits                 3C454.3
# 5         FITS_pic/MAGIC_2010_PG1553_mw2008.fits             PG 1553+113
# 6         FITS_pic/MAGIC_2010_Mrk421_mw2006.fits           Markarian 421
# 7         FITS_pic/MAGIC_2010_Mrk421_mw2006.fits           Markarian 421
# 8         FITS_pic/MAGIC_2010_Mrk421_mw2006.fits           Markarian 421
# 9         FITS_pic/MAGIC_2010_Mrk421_mw2006.fits           Markarian 421
# 10        FITS_pic/MAGIC_2010_Mrk421_mw2006.fits           Markarian 421
# 11        FITS_pic/MAGIC_2010_Mrk421_mw2006.fits           Markarian 421
# 12        FITS_pic/MAGIC_2010_Mrk421_mw2006.fits           Markarian 421
# 13        FITS_pic/MAGIC_2010_Mrk421_mw2006.fits           Markarian 421
# 14        FITS_pic/MAGIC_2010_Mrk421_mw2006.fits           Markarian 421
# 15                  FITS_pic/MAGIC_2012_M87.fits                     M87
# 16               FITS_pic/MAGIC_2012_B32247.fits             B3 2247+381
# 17               FITS_pic/MAGIC_2012_B32247.fits             B3 2247+381
# 18              FITS_pic/MAGIC_2012_Perseus.fits         Perseus Cluster
# 19              FITS_pic/MAGIC_2012_Perseus.fits         Perseus Cluster
# 20              FITS_pic/MAGIC_2012_PKS2155.fits             Crab Nebula
# 21              FITS_pic/MAGIC_2012_PKS2155.fits            PKS 2155-304
# 22                  FITS_pic/MAGIC_2012_W51.fits              W51 region
# 23              FITS_pic/MAGIC_2012_1ES1215.fits            1ES 1215+303
# 24              FITS_pic/MAGIC_2012_1ES1215.fits            1ES 1215+303
# 25            FITS_pic/MAGIC_2013_Magnetars.fits              4U 0142+61
# 26            FITS_pic/MAGIC_2013_Magnetars.fits             1E 2259+586
# 27          FITS_pic/MAGIC_2013_1ES2344+514.fits             1E 2344+514
# 28          FITS_pic/MAGIC_2013_1ES2344+514.fits             1E 2344+514
# 29          FITS_pic/MAGIC_2013_1ES2344+514.fits             1E 2344+514
# 30          FITS_pic/MAGIC_2013_1ES2344+514.fits             1E 2344+514
# 31             FITS_pic/MAGIC_2013_J1644+57.fits             Sw J1644+57
# 32                FITS_pic/MAGIC_2014_IC310.fits                  IC 310
# 33                FITS_pic/MAGIC_2014_IC310.fits                  IC 310
# 34                FITS_pic/MAGIC_2014_IC310.fits                  IC 310
# 35                FITS_pic/MAGIC_2014_IC310.fits                  IC 310
# 36              FITS_pic/MAGIC_2014_NGC1275.fits                NGC 1275
# 37              FITS_pic/MAGIC_2014_NGC1275.fits                NGC 1275
# 38                FITS_pic/MAGIC_2014_3C279.fits                  3C 279
# 39                FITS_pic/MAGIC_2014_3C279.fits                  3C 279
# 40          FITS_pic/MAGIC_2014_PKS1424+240.fits            PKS 1424+240
# 41          FITS_pic/MAGIC_2014_PKS1424+240.fits            PKS 1424+240
# 42          FITS_pic/MAGIC_2014_PKS1424+240.fits            PKS 1424+240
# 43          FITS_pic/MAGIC_2014_PKS1424+240.fits            PKS 1424+240
# 44           FITS_pic/MAGIC_2014_CrabPulsar.fits             Crab Pulsar
# 45           FITS_pic/MAGIC_2014_CrabPulsar.fits             Crab Pulsar
# 46           FITS_pic/MAGIC_2014_CrabPulsar.fits             Crab Pulsar
# 47           FITS_pic/MAGIC_2014_CrabPulsar.fits             Crab Pulsar
# 48           FITS_pic/MAGIC_2014_CrabPulsar.fits             Crab Pulsar
# 49           FITS_pic/MAGIC_2014_CrabPulsar.fits             Crab Pulsar
# 50           FITS_pic/MAGIC_2014_CrabPulsar.fits             Crab Pulsar
# 51           FITS_pic/MAGIC_2014_CrabPulsar.fits             Crab Pulsar
# 52           FITS_pic/MAGIC_2014_CrabPulsar.fits             Crab Pulsar
# 53                 FITS_pic/MAGIC_2014_3C58.fits                    3C58
# 54          FITS_pic/MAGIC_2007_CassiopeiaA.fits            Cassiopeia A
# 55             FITS_pic/MAGIC_2006_HESS1813.fits          HESS J1813-178
# 56                   FITS_pic/MAGIC_2006_GC.fits         Galactic Center
# 57               FITS_pic/MAGIC_2006_Mrk180.fits                 Mrk 180
# 58               FITS_pic/MAGIC_2006_Mrk180.fits                 Mrk 180
# 59               FITS_pic/MAGIC_2007_Mrk421.fits           Markarian 421
# 60               FITS_pic/MAGIC_2007_Mrk421.fits           Markarian 421
# 61                FITS_pic/MAGIC_2007_IC443.fits                  IC 443
# 62             FITS_pic/MAGIC_2007_CygnusX1.fits               Cygnus-X1
# 63             FITS_pic/MAGIC_2007_CygnusX1.fits               Cygnus-X1
# 64              FITS_pic/MAGIC_2007_1ES1011.fits            1ES 1011+496
# 65              FITS_pic/MAGIC_2007_1ES1011.fits            1ES 1011+496
# 66           FITS_pic/MAGIC_2008_1ES1959_mw.fits            1ES 1959+650
# 67          FITS_pic/MAGIC_2008_LSI61303_mw.fits            LS I +61 303
# 68          FITS_pic/MAGIC_2008_LSI61303_mw.fits            LS I +61 303
# 69                  FITS_pic/MAGIC_2008_M87.fits                     M87
# 70                  FITS_pic/MAGIC_2008_M87.fits                     M87
# 71                  FITS_pic/MAGIC_2008_M87.fits                     M87
# 72             FITS_pic/MAGIC_2008_WRBinSys.fits                  WR 147
# 73             FITS_pic/MAGIC_2008_WRBinSys.fits                  WR 146
# 74                FITS_pic/MAGIC_2009_3C66A.fits                3C 66A/B
# 75             FITS_pic/MAGIC_2009_LSI61303.fits            LS I +61 303
# 76             FITS_pic/MAGIC_2009_LSI61303.fits            LS I +61 303
# 77                  FITS_pic/MAGIC_2009_M13.fits                     M13
# 78   FITS_pic/MAGIC_2009_Mrk421_mw_outburst.fits                  Mrk421
# 79               FITS_pic/MAGIC_2009_S50716.fits             S5 0716+714
# 80               FITS_pic/MAGIC_2009_S50716.fits             S5 0716+714
# 81        FITS_pic/MAGIC_2009_Mrk501_mw2006.fits           Markarian 501
# 82              FITS_pic/MAGIC_2010_Perseus.fits  Perseus Galaxy Cluster
# 83              FITS_pic/MAGIC_2010_Perseus.fits  Perseus Galaxy Cluster
# 84              FITS_pic/MAGIC_2010_Perseus.fits  Perseus Galaxy Cluster
# 85              FITS_pic/MAGIC_2010_Perseus.fits  Perseus Galaxy Cluster
# 86             FITS_pic/MAGIC_2010_CygnusX3.fits              Cygnus X-3
# 87             FITS_pic/MAGIC_2010_CygnusX3.fits              Cygnus X-3
# 88             FITS_pic/MAGIC_2010_CygnusX3.fits              Cygnus X-3
# 89       FITS_pic/MAGIC_2010_MilagroSNR_G65.fits       1FGL J1954.3+2836
# 90       FITS_pic/MAGIC_2010_MilagroSNR_G65.fits       1FGL J1954.3+2836
# 91       FITS_pic/MAGIC_2010_MilagroSNR_G65.fits       1FGL J1954.3+2836
# 92       FITS_pic/MAGIC_2010_MilagroSNR_G65.fits       1FGL J1954.3+2836
# 93       FITS_pic/MAGIC_2010_MilagroSNR_G65.fits       1FGL J1958.6+2845
# 94       FITS_pic/MAGIC_2010_MilagroSNR_G65.fits      1FGL J1958.63+2845
# 95       FITS_pic/MAGIC_2010_MilagroSNR_G65.fits      1FGL J1958.63+2845
# 96       FITS_pic/MAGIC_2010_MilagroSNR_G65.fits      1FGL J1958.63+2845
# 97               FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 98               FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 99               FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 100              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 101              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 102              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 103              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 104              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 105              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 106              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 107              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 108              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 109              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 110              FITS_pic/MAGIC_2014_Segue1.fits                 Segue 1
# 111               FITS_pic/MAGIC_2010_IC310.fits                  IC 310
# 112             FITS_pic/MAGIC_2011_PKS1222.fits             PKS 1222+21
# 113             FITS_pic/MAGIC_2011_PKS1222.fits             PKS 1222+21
# 114          FITS_pic/MAGIC_2011_ScorpiusX1.fits            Scorpius X-1
# 115          FITS_pic/MAGIC_2011_ScorpiusX1.fits            Scorpius X-1
# 116           FITS_pic/MAGIC_2014_GRB090102.fits              GRB 090102
# 117             FITS_pic/MAGIC_2014_4C+5517.fits               4C +55.17
# 118             FITS_pic/MAGIC_2015_1ES0806.fits            1ES 0806+524
# 119             FITS_pic/MAGIC_2015_1ES0806.fits            1ES 0806+524
# 120             FITS_pic/MAGIC_2015_1ES0806.fits            1ES 0806+524
# 121             FITS_pic/MAGIC_2015_1ES0806.fits            1ES 0806+524
# 122               FITS_pic/MAGIC_2009_OJ287.fits                  OJ 287
# 123               FITS_pic/MAGIC_2009_OJ287.fits                  OJ 287
# 124            FITS_pic/MAGIC_2006_LSI61303.fits            LS I +61 303
# 125               FITS_pic/MAGIC_2014_Ic310.fits                  IC 310
# 126               FITS_pic/MAGIC_2014_Ic310.fits                  IC 310
# 127               FITS_pic/MAGIC_2008_3C279.fits                  3C 279
# 128               FITS_pic/MAGIC_2008_3C279.fits                  3C 279
# 129               FITS_pic/MAGIC_2008_3C279.fits                  3C 279
#
#                                                   PROC          RA  \
# 0    [[[1.56025356963e+25, 3.62805869585e-13, 1.139...   83.633083
# 1    [[[1.56025356963e+25, 3.62805869585e-13, 1.139...   83.633083
# 2    [[[2.00693116017e+25, 8.6091678507e-14, -999, ...   22.899400
# 3    [[[2.00693116017e+25, 8.6091678507e-14, -999, ...   22.899400
# 4    [[[2.00693116017e+25, 8.6091678507e-14, -999, ...   22.899400
# 5    [[[2.02482428136e+25, 6.46354329444e-11, 1.536...  238.929000
# 6    [[[1.09293118602e+26, 3.82920199035e-07, 2.466...  165.250500
#
RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e8).any()
# /home/chbrandt/.conda/envs/magic/lib/python2.7/site-packages/pandas/core/format.py:2088: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) &
# /home/chbrandt/.conda/envs/magic/lib/python2.7/site-packages/pandas/core/format.py:2089: RuntimeWarning: invalid value encountered in greater
#   (abs_vals > 0)).any()

# %%
print_describe(table_proc,include=None)
# Out:
#               DEC          RA
# count  129.000000  129.000000
# mean    31.487762  164.916727
# std     19.756908   97.078276
# min    -30.225600    2.675560
# 25%     16.148200   83.633076
# 50%     35.201700  153.768000
# 75%     41.511695  216.751632
# max     71.343400  356.765000
#
# -> Has Nil?
# DEC            True
# DOI           False
# FITS          False
# FITS_local    False
# OBJECT        False
# PROC          False
# RA             True
# SOURCE        False
# SPECTRUM      False
# dtype: bool
#
# -> Indexes where column 'DEC' is null:
# [31]
#
# -> Indexes where column 'RA' is null:
# [31]

# %%
table_final = table_proc.dropna()[['OBJECT','RA','DEC','DOI','FITS']]

# %%
print_describe(table_final)
# Out:
#          OBJECT          RA         DEC                                              DOI  \
# count       129  129.000000  129.000000                                              129
# unique       47         NaN         NaN                                               50
# top     Segue 1         NaN         NaN  http://dx.doi.org/10.1088/1475-7516/2014/02/008
# freq         14         NaN         NaN                                               14
# mean        NaN  164.916727   31.487762                                              NaN
# std         NaN   97.078276   19.756908                                              NaN
# min         NaN    2.675560  -30.225600                                              NaN
# 25%         NaN   83.633076   16.148200                                              NaN
# 50%         NaN  153.768000   35.201700                                              NaN
# 75%         NaN  216.751632   41.511695                                              NaN
# max         NaN  356.765000   71.343400                                              NaN
#
#                                                      FITS
# count                                                 129
# unique                                                129
# top     FITS_out/MAGIC_2009_Mrk421_mw_outburst_SPECTRU...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
# -> Has Nil?
# OBJECT    False
# RA        False
# DEC       False
# DOI       False
# FITS      False
# dtype: bool

# %%
print table_final
# Out:
#                      OBJECT          RA        DEC  \
# 0               Crab Nebula   83.633083  22.014500
# 1               Crab Nebula   83.633083  22.014500
# 2                   3C454.3   22.899400  16.148200
# 3                   3C454.3   22.899400  16.148200
# 4                   3C454.3   22.899400  16.148200
# 5               PG 1553+113  238.929000  11.190100
# 6             Markarian 421  165.250500  38.666700
# 7             Markarian 421  165.250500  38.666700
# 8             Markarian 421  165.250500  38.666700
# 9             Markarian 421  165.250500  38.666700
# 10            Markarian 421  165.250500  38.666700
# 11            Markarian 421  165.250500  38.666700
# 12            Markarian 421  165.250500  38.666700
# 13            Markarian 421  165.250500  38.666700
# 14            Markarian 421  165.250500  38.666700
# 15                      M87  187.705500  12.391100
# 16              B3 2247+381  342.520800  38.410280
# 17              B3 2247+381  342.520800  38.410280
# 18          Perseus Cluster   49.947000  41.513100
# 19          Perseus Cluster   49.947000  41.513100
# 20              Crab Nebula   83.633100  22.014500
# 21             PKS 2155-304  329.716900 -30.225600
# 22               W51 region   19.385000  14.190000
# 23             1ES 1215+303  184.467000  30.116800
# 24             1ES 1215+303  184.467000  30.116800
# 25               4U 0142+61   26.593400  61.750900
# 26              1E 2259+586  345.284600  58.879000
# 27              1E 2344+514  356.765000  51.705000
http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 90      http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 91      http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 92      http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 93      http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 94      http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 95      http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 96      http://dx.doi.org/10.1088/0004-637X/725/2/1629
# 97     http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 98     http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 99     http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 100    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 101    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 102    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 103    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 104    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 105    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 106    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 107    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 108    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 109    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 110    http://dx.doi.org/10.1088/1475-7516/2014/02/008
# 111     http://dx.doi.org/10.1088/2041-8205/723/2/L207
# 112       http://dx.doi.org/10.1088/2041-8205/730/1/L8
# 113       http://dx.doi.org/10.1088/2041-8205/730/1/L8
# 114       http://dx.doi.org/10.1088/2041-8205/735/1/L5
# 115       http://dx.doi.org/10.1088/2041-8205/735/1/L5
# 116            http://dx.doi.org/10.1093/mnras/stt2041
# 117             http://dx.doi.org/10.1093/mnras/stu227
# 118             http://dx.doi.org/10.1093/mnras/stv895
# 119             http://dx.doi.org/10.1093/mnras/stv895
# 120             http://dx.doi.org/10.1093/mnras/stv895
# 121             http://dx.doi.org/10.1093/mnras/stv895
# 122           http://dx.doi.org/10.1093/pasj/61.5.1011
# 123           http://dx.doi.org/10.1093/pasj/61.5.1011
# 124          http://dx.doi.org/10.1126/science.1128177
# 125          http://dx.doi.org/10.1126/science.1256183
# 126          http://dx.doi.org/10.1126/science.1256183
# 127  http://www.sciencemag.org/content/320/5884/175...
# 128  http://www.sciencemag.org/content/320/5884/175...
# 129  http://www.sciencemag.org/content/320/5884/175...
#
#                                                   FITS
# 0         FITS_out/MAGIC_2015_CrabNebula_SPECTRUM.fits
# 1       FITS_out/MAGIC_2015_CrabNebula_SPECTRUM_1.fits
# 2              FITS_out/MAGIC_2009_3C454_SPECTRUM.fits
# 3            FITS_out/MAGIC_2009_3C454_SPECTRUM_1.fits
# 4            FITS_out/MAGIC_2009_3C454_SPECTRUM_2.fits
# 5      FITS_out/MAGIC_2010_PG1553_mw2008_SPECTRUM.fits
# 6      FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM.fits
# 7    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_1.fits
# 8    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_2.fits
# 9    FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_3.fits
# 10   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_4.fits
# 11   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_5.fits
# 12   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_6.fits
# 13   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_7.fits
# 14   FITS_out/MAGIC_2010_Mrk421_mw2006_SPECTRUM_8.fits
# 15               FITS_out/MAGIC_2012_M87_SPECTRUM.fits
# 16            FITS_out/MAGIC_2012_B32247_SPECTRUM.fits
# 17          FITS_out/MAGIC_2012_B32247_SPECTRUM_1.fits
# 18           FITS_out/MAGIC_2012_Perseus_SPECTRUM.fits
# 19         FITS_out/MAGIC_2012_Perseus_SPECTRUM_1.fits
# 20           FITS_out/MAGIC_2012_PKS2155_SPECTRUM.fits
# 21         FITS_out/MAGIC_2012_PKS2155_SPECTRUM_1.fits
# 22               FITS_out/MAGIC_2012_W51_SPECTRUM.fits
# 23           FITS_out/MAGIC_2012_1ES1215_SPECTRUM.fits
# 24         FITS_out/MAGIC_2012_1ES1215_SPECTRUM_1.fits
# 25       FITS_out/MAGIC_2013_Magnetars_SPECTRUM_1.fits
# 26       FITS_out/MAGIC_2013_Magnetars_SPECTRUM_3.fits
# 27       FITS_out/MAGIC_2013_1ES2344p514_SPECTRUM.fits
# 28     FITS_out/MAGIC_2013_1ES2344p514_SPECTRUM_1.fits
# 29     FITS_out/MAGIC_2013_1ES2344p514_SPECTRUM_2.fits
# 30     FITS_out/MAGIC_2013_1ES2344p514_SPECTRUM_3.fits
# 32             FITS_out/MAGIC_2014_IC310_SPECTRUM.fits
# 33           FITS_out/MAGIC_2014_IC310_SPECTRUM_1.fits
# 34           FITS_out/MAGIC_2014_IC310_SPECTRUM_2.fits
# 35           FITS_out/MAGIC_2014_IC310_SPECTRUM_3.fits
# 36           FITS_out/MAGIC_2014_NGC1275_SPECTRUM.fits
# 37         FITS_out/MAGIC_2014_NGC1275_SPECTRUM_1.fits
# 38             FITS_out/MAGIC_2014_3C279_SPECTRUM.fits
# 39           FITS_out/MAGIC_2014_3C279_SPECTRUM_1.fits
# 40       FITS_out/MAGIC_2014_PKS1424p240_SPECTRUM.fits
# 41     FITS_out/MAGIC_2014_PKS1424p240_SPECTRUM_1.fits
# 42     FITS_out/MAGIC_2014_PKS1424p240_SPECTRUM_2.fits
# 43     FITS_out/MAGIC_2014_PKS1424p240_SPECTRUM_3.fits
# 44        FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM.fits
# 45      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_1.fits
# 46      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_2.fits
# 47      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_3.fits
# 48      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_4.fits
# 49      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_5.fits
# 50      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_6.fits
# 51      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_7.fits
# 52      FITS_out/MAGIC_2014_CrabPulsar_SPECTRUM_8.fits
# 53              FITS_out/MAGIC_2014_3C58_SPECTRUM.fits
# 54       FITS_out/MAGIC_2007_CassiopeiaA_SPECTRUM.fits
# 55          FITS_out/MAGIC_2006_HESS1813_SPECTRUM.fits
# 56                FITS_out/MAGIC_2006_GC_SPECTRUM.fits
# 57            FITS_out/MAGIC_2006_Mrk180_SPECTRUM.fits
# 58          FITS_out/MAGIC_2006_Mrk180_SPECTRUM_1.fits
# 59            FITS_out/MAGIC_2007_Mrk421_SPECTRUM.fits
# 60          FITS_out/MAGIC_2007_Mrk421_SPECTRUM_1.fits
# 61             FITS_out/MAGIC_2007_IC443_SPECTRUM.fits
# 62          FITS_out/MAGIC_2007_CygnusX1_SPECTRUM.fits
# 63        FITS_out/MAGIC_2007_CygnusX1_SPECTRUM_1.fits
# 64           FITS_out/MAGIC_2007_1ES1011_SPECTRUM.fits
# 65         FITS_out/MAGIC_2007_1ES1011_SPECTRUM_1.fits
# 66        FITS_out/MAGIC_2008_1ES1959_mw_SPECTRUM.fits
# 67       FITS_out/MAGIC_2008_LSI61303_mw_SPECTRUM.fits
# 68     FITS_out/MAGIC_2008_LSI61303_mw_SPECTRUM_1.fits
# 69               FITS_out/MAGIC_2008_M87_SPECTRUM.fits
# 70             FITS_out/MAGIC_2008_M87_SPECTRUM_1.fits
# 71             FITS_out/MAGIC_2008_M87_SPECTRUM_2.fits
# 72          FITS_out/MAGIC_2008_WRBinSys_SPECTRUM.fits
# 73        FITS_out/MAGIC_2008_WRBinSys_SPECTRUM_1.fits
# 74             FITS_out/MAGIC_2009_3C66A_SPECTRUM.fits
# 75          FITS_out/MAGIC_2009_LSI61303_SPECTRUM.fits
# 76        FITS_out/MAGIC_2009_LSI61303_SPECTRUM_1.fits
# 77               FITS_out/MAGIC_2009_M13_SPECTRUM.fits
# 78   FITS_out/MAGIC_2009_Mrk421_mw_outburst_SPECTRU...
# 79            FITS_out/MAGIC_2009_S50716_SPECTRUM.fits
# 80          FITS_out/MAGIC_2009_S50716_SPECTRUM_1.fits
# 81     FITS_out/MAGIC_2009_Mrk501_mw2006_SPECTRUM.fits
# 82           FITS_out/MAGIC_2010_Perseus_SPECTRUM.fits
# 83         FITS_out/MAGIC_2010_Perseus_SPECTRUM_1.fits
# 84         FITS_out/MAGIC_2010_Perseus_SPECTRUM_2.fits
# 85         FITS_out/MAGIC_2010_Perseus_SPECTRUM_3.fits
# 86          FITS_out/MAGIC_2010_CygnusX3_SPECTRUM.fits
# 87        FITS_out/MAGIC_2010_CygnusX3_SPECTRUM_1.fits
# 88        FITS_out/MAGIC_2010_CygnusX3_SPECTRUM_2.fits
# 89    FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM.fits
# 90   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_1....
# 91   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_2....
# 92   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_3....
# 93   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_4....
# 94   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_5....
# 95   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_6....
# 96   FITS_out/MAGIC_2010_MilagroSNR_G65_SPECTRUM_7....
# 97            FITS_out/MAGIC_2014_Segue1_SPECTRUM.fits
# 98          FITS_out/MAGIC_2014_Segue1_SPECTRUM_1.fits
# 99          FITS_out/MAGIC_2014_Segue1_SPECTRUM_2.fits
# 100         FITS_out/MAGIC_2014_Segue1_SPECTRUM_3.fits
# 101         FITS_out/MAGIC_2014_Segue1_SPECTRUM_4.fits
# 102         FITS_out/MAGIC_2014_Segue1_SPECTRUM_5.fits
# 103         FITS_out/MAGIC_2014_Segue1_SPECTRUM_6.fits
# 104         FITS_out/MAGIC_2014_Segue1_SPECTRUM_7.fits
# 105         FITS_out/MAGIC_2014_Segue1_SPECTRUM_8.fits
# 106         FITS_out/MAGIC_2014_Segue1_SPECTRUM_9.fits
# 107        FITS_out/MAGIC_2014_Segue1_SPECTRUM_10.fits
# 108        FITS_out/MAGIC_2014_Segue1_SPECTRUM_11.fits
# 109        FITS_out/MAGIC_2014_Segue1_SPECTRUM_12.fits
# 110        FITS_out/MAGIC_2014_Segue1_SPECTRUM_13.fits
# 111            FITS_out/MAGIC_2010_IC310_SPECTRUM.fits
# 112          FITS_out/MAGIC_2011_PKS1222_SPECTRUM.fits
# 113        FITS_out/MAGIC_2011_PKS1222_SPECTRUM_1.fits
# 114       FITS_out/MAGIC_2011_ScorpiusX1_SPECTRUM.fits
# 115     FITS_out/MAGIC_2011_ScorpiusX1_SPECTRUM_1.fits
# 116        FITS_out/MAGIC_2014_GRB090102_SPECTRUM.fits
# 117          FITS_out/MAGIC_2014_4Cp5517_SPECTRUM.fits
# 118          FITS_out/MAGIC_2015_1ES0806_SPECTRUM.fits
# 119        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_1.fits
# 120        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_2.fits
# 121        FITS_out/MAGIC_2015_1ES0806_SPECTRUM_3.fits
# 122            FITS_out/MAGIC_2009_OJ287_SPECTRUM.fits
# 123          FITS_out/MAGIC_2009_OJ287_SPECTRUM_1.fits
# 124         FITS_out/MAGIC_2006_LSI61303_SPECTRUM.fits
# 125            FITS_out/MAGIC_2014_Ic310_SPECTRUM.fits
# 126          FITS_out/MAGIC_2014_Ic310_SPECTRUM_1.fits
# 127            FITS_out/MAGIC_2008_3C279_SPECTRUM.fits
# 128          FITS_out/MAGIC_2008_3C279_SPECTRUM_1.fits
# 129          FITS_out/MAGIC_2008_3C279_SPECTRUM_2.fits

# %%
table_final.to_csv('table_final_clean.csv')
