# %% [markdown]
# # Run the x-match again, but now using the code in 'booq'
#
# As a final stage, the code used in the past notebooks was transfered to ``booq``. Now we have to test it, looking for some erroneous reference or whatever bug eventualy to show up.

# %%
import booq

# %%
# let's define some parameters for our mock catalogs

# to be real fake, we have to fake evrything... :(
# let's start with the size of the supposed images
# from where the sources are coming from...
sx = 5000
sy = 5000

# number of sources to be relative to the size of the image
num_sources = int( 0.1 * (sx*sy)/(sx+sy) )

# and, say there is an error radius
error_radius = 20

# %%
from booq.data import mock
from booq import coordinates

# Generate catalog A
A_image_catalog = mock.D2.generate_catalog(num_sources, error_radius, (sy,sx))

A = A_image_catalog.rename(columns={'ID':'id'})
A.loc[:,'ra']  = coordinates.pixel_to_sky(A_image_catalog.x, 0, 1.0/sx)
A.loc[:,'dec'] = coordinates.pixel_to_sky(A_image_catalog.y, 0, 1.0/sy)

# Generate catalog B
B_image_catalog = mock.D2.generate_catalog_around(A_image_catalog, 0.75, (sy,sx))

B = B_image_catalog.rename(columns={'ID':'id'})
B.loc[:,'ra']  = coordinates.pixel_to_sky(B_image_catalog.x, 0, 1.0/sx)
B.loc[:,'dec'] = coordinates.pixel_to_sky(B_image_catalog.y, 0, 1.0/sy)

# %%
from booq.pipelines import xmatch_nn
# X-match the catalogs
matched_catalog_serial = xmatch_nn.xmatch(A, B)
# Out:
# /home/chbrandt/fido/repos/booq/booq/pipelines/xmatch_nn.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   B_matched['A_idx'] = df_matched_idx.index

# %%
from booq.pipelines import xmatch_nn
# X-match the catalogs
matched_catalog_parallel = xmatch_nn.xmatch(A, B, parallel_run=True)
# Out:
# Running in parallel
# Running in parallel

# %%
matched_catalog_parallel.equals(matched_catalog_serial)
# Out:
# True

# %%
from booq.table.atable import aTable
aTable.from_pandas(matched_catalog_parallel).show_in_notebook()
# Out:
# &lt;Table length=250&gt;
# <table id="table139797584121936-892127" class="table table-striped table-bordered table-condensed">
# <thead><tr><th>A_id</th><th>A_r</th><th>A_x</th><th>A_y</th><th>A_ra</th><th>A_dec</th><th>B_id</th><th>B_r</th><th>B_x</th><th>B_y</th><th>B_ra</th><th>B_dec</th><th>AB_dist</th></tr></thead>
# <tr><td>1.0</td><td>20.0</td><td>266.0</td><td>3799.0</td><td>0.0532</td><td>0.7598</td><td>1.0</td><td>20.0</td><td>259.0</td><td>3822.0</td><td>0.0518</td><td>0.7644</td><td>0.00480829005519</td></tr>
# <tr><td>2.0</td><td>20.0</td><td>2187.0</td><td>3320.0</td><td>0.4374</td><td>0.664</td><td>2.0</td><td>20.0</td><td>2173.0</td><td>3331.0</td><td>0.4346</td><td>0.6662</td><td>0.00356075042748</td></tr>
# <tr><td>3.0</td><td>20.0</td><td>3297.0</td><td>168.0</td><td>0.6594</td><td>0.0336</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr>
# <tr><td>4.0</td><td>20.0</td><td>2135.0</td><td>2927.0</td><td>0.427</td><td>0.5854</td><td>4.0</td><td>20.0</td><td>2125.0</td><td>2934.0</td><td>0.425</td><td>0.5868</td><td>0.00244122540007</td></tr>
# <tr><td>5.0</td><td>20.0</td><td>4792.0</td><td>4390.0</td><td>0.9584</td><td>0.878</td><td>5.0</td><td>20.0</td><td>4807.0</td><td>4353.0</td><td>0.9614</td><td>0.8706</td><td>0.00798485469516</td></tr>
# <tr><td>6.0</td><td>20.0</td><td>23.0</td><td>2189.0</td><td>0.0046</td><td>0.4378</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr>
# <tr><td